# %% [markdown]
# # 30. 층수에 따른 가격 이상치 탐지
# - 대부분 층수가 높아지면 가격이 상승한다.
# - 지하2층, 65층의 경우 형상이 조금 다르다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import gc
from sklearn.preprocessing import MinMaxScaler

# 맥에서 글씨 깨짐 방지
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('../data/preprocessed/29_2_area_target_outlier.csv')
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_3984/2352522197.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/preprocessed/29_2_area_target_outlier.csv')

# %%
df
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ... 아파트 카테고리  지하철 카테고리 구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리  \
# 0        1987  ...       기타       분당선    강남구       기타    5581.622466
# 1        1987  ...       기타       분당선    강남구       기타    5581.622466
# 2        1987  ...       기타       분당선    강남구       기타    5581.622466
# 3        1987  ...       기타       분당선    강남구       기타    5581.622466
# 4        1987  ...       기타       분당선    강남구       기타    5581.622466
# ...       ...  ...      ...       ...    ...      ...            ...
# 1128089  2014  ...       기타        기타     기타       기타    5918.624352
# 1128090  2014  ...       기타        기타     기타       기타    5918.624352
# 1128091  2014  ...       기타        기타     기타       기타    5918.624352
# 1128092  2014  ...       기타        기타     기타       기타    5918.624352
# 1128093  2014  ...       기타        기타     기타       기타    5918.624352
#
#         가장 가까운 다리 index 가장 가까운 다리 인근 한강다리 개수  인근 다리 개수 1개이상 3개 이하   학군
# 0                  17.0      청담대교        0.0                    0  8.0
# 1                  17.0      청담대교        0.0                    0  8.0
# 2                  17.0      청담대교        0.0                    0  8.0
# 3                  17.0      청담대교        0.0                    0  8.0
# 4                  17.0      청담대교        0.0                    0  8.0
# ...                 ...       ...        ...                  ...  ...
# 1128089            23.0    구리암사대교        0.0                    0  1.0
# 1128090            23.0    구리암사대교        0.0                    0  1.0
# 1128091            23.0    구리암사대교        0.0                    0  1.0
# 1128092            23.0    구리암사대교        0.0                    0  1.0
# 1128093            23.0    구리암사대교        0.0                    0  1.0
#
# [1128094 rows x 103 columns]

# %%
train_df = df[df['is_test']==0]
test_df = df[df['is_test']==1]

# %%
tmp = pd.DataFrame(train_df.groupby('층')['target'].mean())
tmp.reset_index(inplace=True)
tmp
# Out:
#      층         target
# 0   -4   61454.250000
# 1   -3   66876.200000
# 2   -2  199159.838710
# 3   -1   75713.920035
# 4    1   53406.719177
# ..  ..            ...
# 68  65  147660.000000
# 69  66  265531.250000
# 70  67  246083.333333
# 71  68  200208.333333
# 72  69  165000.000000
#
# [73 rows x 2 columns]

# %%
plt.figure(figsize=(10, 8))
plt.bar(tmp['층'], tmp['target'])
plt.grid(True)
plt.show()

# %%
# 이상치로 판단하여 제거가 필요한 인덱스 저장 리스트
need_drop = []

# %% [markdown]
# ## 지하 2층
# - 가격이 급격히 커진다.
# - '한남더힐'의 가격이 압도적이기 때문
# - test_df에도 '한남더힐'존재 -> 지하2층은 없고 지하 1층만 존재
# - '한남더힐' 중 지하2층 데이터 제거

# %%
tmp = train_df[train_df['층']==-2][['아파트명', '좌표Y', '좌표X', '층', '전용면적', '계약년월', 'target']]
tmp.reset_index(inplace=True)
tmp
# Out:
#       index             아파트명        좌표Y         좌표X  층      전용면적    계약년월  \
# 0     26438        천왕연지타운1단지  37.477355  126.837665 -2   84.9500  201805
# 1     87307             한남더힐  37.536978  127.009496 -2  240.2300  201804
# 2     87322             한남더힐  37.536978  127.009496 -2  240.3050  201806
# 3     91163  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.4800  201801
# 4     91188  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.4800  201808
# 5    216500  옥수파크힐스101동~116동  37.548477  127.013995 -2  107.9900  202305
# 6    321334        천왕연지타운2단지  37.482919  126.844790 -2   84.7800  202007
# 7    359292  옥수파크힐스101동~116동  37.548477  127.013995 -2   76.6600  202006
# 8    359304  옥수파크힐스101동~116동  37.548477  127.013995 -2  107.9900  202007
# 9    361709         롯데캐슬골든힐스  37.608918  127.015960 -2   59.8946  202006
# 10   385655  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  101.9900  202007
# 11   424573  옥수파크힐스101동~116동  37.548477  127.013995 -2   76.6600  201906
# 12   436831             한남더힐  37.536978  127.009496 -2  240.2300  201902
# 13   436888             한남더힐  37.536978  127.009496 -2  240.2300  201907
# 14   471359        천왕연지타운2단지  37.482919  126.844790 -2   84.8700  201610
# 15   534725             한남더힐  37.536978  127.009496 -2  240.2300  201612
# 16   534774             한남더힐  37.536978  127.009496 -2  212.5240  201705
# 17   572767        천왕연지타운2단지  37.482919  126.844790 -2   84.7100  201608
# 18   635919             한남더힐  37.536978  127.009496 -2  240.2300  201602
# 19   640348  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.7100  201512
# 20   640349  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  167.7500  201512
# 21   640370  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.7100  201607
# 22   755308  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  167.7500  201411
# 23   755311  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201411
# 24   755318  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201501
# 25   755326  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201503
# 26   785791        천왕연지타운2단지  37.482919  126.844790 -2   84.7800  201403
# 27   904804  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201211
# 28   904805  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.7100  201211
# 29   964897  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.6600  201108
# 30  1115466             옥인시민  37.582600  126.963645 -2   59.5000  200707
#
#       target
# 0    56500.0
# 1   600000.0
# 2   620000.0
# 3    60000.0
# 4    76000.0
# 5   290000.0
# 6    67700.0
# 7   167500.0
# 8   220000.0
# 9    74500.0
# 10   94700.0
# 11  151000.0
# 12  630000.0
# 13  630000.0
# 14   45500.0
# 15  543000.0
# 16  490000.0
# 17   47150.0
# 18  624000.0
# 19   57698.0
# 20   74466.0
# 21   58767.0
# 22   76533.0
# 23   55797.0
# 24   55181.0
# 25   56472.0
# 26   37000.0
# 27   58169.0
# 28   62403.0
# 29   65919.0
# 30   28000.0

# %%
tmp.sort_values('계약년월', inplace=True)
tmp.reset_index(drop=True, inplace=True)
tmp
# Out:
#       index             아파트명        좌표Y         좌표X  층      전용면적    계약년월  \
# 0   1115466             옥인시민  37.582600  126.963645 -2   59.5000  200707
# 1    964897  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.6600  201108
# 2    904805  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.7100  201211
# 3    904804  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201211
# 4    785791        천왕연지타운2단지  37.482919  126.844790 -2   84.7800  201403
# 5    755311  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201411
# 6    755308  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  167.7500  201411
# 7    755318  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201501
# 8    755326  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.5100  201503
# 9    640349  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  167.7500  201512
# 10   640348  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.7100  201512
# 11   635919             한남더힐  37.536978  127.009496 -2  240.2300  201602
# 12   640370  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.7100  201607
# 13   572767        천왕연지타운2단지  37.482919  126.844790 -2   84.7100  201608
# 14   471359        천왕연지타운2단지  37.482919  126.844790 -2   84.8700  201610
# 15   534725             한남더힐  37.536978  127.009496 -2  240.2300  201612
# 16   534774             한남더힐  37.536978  127.009496 -2  212.5240  201705
# 17    91163  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.4800  201801
# 18    87307             한남더힐  37.536978  127.009496 -2  240.2300  201804
# 19    26438        천왕연지타운1단지  37.477355  126.837665 -2   84.9500  201805
# 20    87322             한남더힐  37.536978  127.009496 -2  240.3050  201806
# 21    91188  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  134.4800  201808
# 22   436831             한남더힐  37.536978  127.009496 -2  240.2300  201902
# 23   424573  옥수파크힐스101동~116동  37.548477  127.013995 -2   76.6600  201906
# 24   436888             한남더힐  37.536978  127.009496 -2  240.2300  201907
# 25   361709         롯데캐슬골든힐스  37.608918  127.015960 -2   59.8946  202006
# 26   359292  옥수파크힐스101동~116동  37.548477  127.013995 -2   76.6600  202006
# 27   385655  우물골2단지두산위브BL2-7  37.636440  126.928783 -2  101.9900  202007
# 28   359304  옥수파크힐스101동~116동  37.548477  127.013995 -2  107.9900  202007
# 29   321334        천왕연지타운2단지  37.482919  126.844790 -2   84.7800  202007
# 30   216500  옥수파크힐스101동~116동  37.548477  127.013995 -2  107.9900  202305
#
#       target
# 0    28000.0
# 1    65919.0
# 2    62403.0
# 3    58169.0
# 4    37000.0
# 5    55797.0
# 6    76533.0
# 7    55181.0
# 8    56472.0
# 9    74466.0
# 10   57698.0
# 11  624000.0
# 12   58767.0
# 13   47150.0
# 14   45500.0
# 15  543000.0
# 16  490000.0
# 17   60000.0
# 18  600000.0
# 19   56500.0
# 20  620000.0
# 21   76000.0
# 22  630000.0
# 23  151000.0
# 24  630000.0
# 25   74500.0
# 26  167500.0
# 27   94700.0
# 28  220000.0
# 29   67700.0
# 30  290000.0

# %%
plt.figure(figsize=(15, 5))
tmp['target'].plot(marker='o')
plt.grid(True)
plt.show()

# %%
test_df[test_df['아파트명']=='한남더힐'][['층']]
# Out:
#          층
# 1127103  8
# 1127104  2
# 1127105  2
# 1127106  5
# 1127107 -1

# %%
need_drop.extend([635919, 534725, 534774, 87307, 87322, 436831, 436888])

# %%
need_drop
# Out:
# [635919, 534725, 534774, 87307, 87322, 436831, 436888]

# %% [markdown]
# ## 65층

# %%
tmp = train_df[train_df['층']==65][['아파트명', '좌표Y', '좌표X', '층', '전용면적', '계약년월', 'target']]
tmp.reset_index(inplace=True)
tmp
# Out:
#     index     아파트명        좌표Y         좌표X   층    전용면적    계약년월    target
# 0   78489  현대하이페리온  37.526854  126.875035  65  154.05  201804  171000.0
# 1  432534  현대하이페리온  37.526854  126.875035  65  138.20  201908  175000.0
# 2  626923  현대하이페리온  37.526854  126.875035  65  138.20  201604  117300.0
# 3  741029  현대하이페리온  37.526854  126.875035  65  154.05  201509  139000.0
# 4  998482  현대하이페리온  37.526854  126.875035  65  138.20  201002  136000.0

# %%
tmp.sort_values('계약년월', inplace=True)
tmp.reset_index(drop=True, inplace=True)
tmp
# Out:
#     index     아파트명        좌표Y         좌표X   층    전용면적    계약년월    target
# 0  998482  현대하이페리온  37.526854  126.875035  65  138.20  201002  136000.0
# 1  741029  현대하이페리온  37.526854  126.875035  65  154.05  201509  139000.0
# 2  626923  현대하이페리온  37.526854  126.875035  65  138.20  201604  117300.0
# 3   78489  현대하이페리온  37.526854  126.875035  65  154.05  201804  171000.0
# 4  432534  현대하이페리온  37.526854  126.875035  65  138.20  201908  175000.0

# %%
plt.figure(figsize=(5, 5))
tmp['target'].plot(marker='o')
plt.grid(True)
plt.show()

# %%
need_drop.append(626923)

# %% [markdown]
# ## 69층

# %%
tmp = train_df[train_df['층']==69][['아파트명', '좌표Y', '좌표X', '층', '전용면적', '계약년월', 'target']]
tmp.reset_index(inplace=True)
tmp
# Out:
#     index     아파트명        좌표Y         좌표X   층    전용면적    계약년월    target
# 0   78510  현대하이페리온  37.526854  126.875035  69  167.44  201809  183000.0
# 1  741018  현대하이페리온  37.526854  126.875035  69  154.05  201502  147000.0

# %% [markdown]
# # 원본에 적용
# - 이상치로 판단한 데이터 drop

# %%
df
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ... 아파트 카테고리  지하철 카테고리 구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리  \
# 0        1987  ...       기타       분당선    강남구       기타    5581.622466
# 1        1987  ...       기타       분당선    강남구       기타    5581.622466
# 2        1987  ...       기타       분당선    강남구       기타    5581.622466
# 3        1987  ...       기타       분당선    강남구       기타    5581.622466
# 4        1987  ...       기타       분당선    강남구       기타    5581.622466
# ...       ...  ...      ...       ...    ...      ...            ...
# 1128089  2014  ...       기타        기타     기타       기타    5918.624352
# 1128090  2014  ...       기타        기타     기타       기타    5918.624352
# 1128091  2014  ...       기타        기타     기타       기타    5918.624352
# 1128092  2014  ...       기타        기타     기타       기타    5918.624352
# 1128093  2014  ...       기타        기타     기타       기타    5918.624352
#
#         가장 가까운 다리 index 가장 가까운 다리 인근 한강다리 개수  인근 다리 개수 1개이상 3개 이하   학군
# 0                  17.0      청담대교        0.0                    0  8.0
# 1                  17.0      청담대교        0.0                    0  8.0
# 2                  17.0      청담대교        0.0                    0  8.0
# 3                  17.0      청담대교        0.0                    0  8.0
# 4                  17.0      청담대교        0.0                    0  8.0
# ...                 ...       ...        ...                  ...  ...
# 1128089            23.0    구리암사대교        0.0                    0  1.0
# 1128090            23.0    구리암사대교        0.0                    0  1.0
# 1128091            23.0    구리암사대교        0.0                    0  1.0
# 1128092            23.0    구리암사대교        0.0                    0  1.0
# 1128093            23.0    구리암사대교        0.0                    0  1.0
#
# [1128094 rows x 103 columns]

# %%
train_df
# Out:
#                    시군구     번지     본번    부번    아파트명   전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201801    8   2
# ...                ...    ...    ...   ...     ...    ...     ...  ...  ..
# 1118817  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  59.94  200707   12  11
# 1118818  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  59.94  200708   25  10
# 1118819  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  84.83  200708   31  20
# 1118820  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  84.83  200709   15   8
# 1118821   서울특별시 중구 묵정동  11-67   11.0  67.0      묵정  52.46  200701   10   5
#
#          건축년도  ... 아파트 카테고리  지하철 카테고리 구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리  \
# 0        1987  ...       기타       분당선    강남구       기타    5581.622466
# 1        1987  ...       기타       분당선    강남구       기타    5581.622466
# 2        1987  ...       기타       분당선    강남구       기타    5581.622466
# 3        1987  ...       기타       분당선    강남구       기타    5581.622466
# 4        1987  ...       기타       분당선    강남구       기타    5581.622466
# ...       ...  ...      ...       ...    ...      ...            ...
# 1118817  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118818  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118819  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118820  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118821  1981  ...       기타       3호선     기타       기타    3320.677588
#
#         가장 가까운 다리 index 가장 가까운 다리 인근 한강다리 개수  인근 다리 개수 1개이상 3개 이하   학군
# 0                  17.0      청담대교        0.0                    0  8.0
# 1                  17.0      청담대교        0.0                    0  8.0
# 2                  17.0      청담대교        0.0                    0  8.0
# 3                  17.0      청담대교        0.0                    0  8.0
# 4                  17.0      청담대교        0.0                    0  8.0
# ...                 ...       ...        ...                  ...  ...
# 1118817             2.0      가양대교        0.0                    0  2.0
# 1118818             2.0      가양대교        0.0                    0  2.0
# 1118819             2.0      가양대교        0.0                    0  2.0
# 1118820             2.0      가양대교        0.0                    0  2.0
# 1118821            14.0      동호대교        0.0                    0  5.0
#
# [1118822 rows x 103 columns]

# %%
print(len(need_drop))
train_df.drop(need_drop, inplace=True)
train_df
# Out:
# 8
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_3984/30688504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(need_drop, inplace=True)
#                    시군구     번지     본번    부번    아파트명   전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201801    8   2
# ...                ...    ...    ...   ...     ...    ...     ...  ...  ..
# 1118817  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  59.94  200707   12  11
# 1118818  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  59.94  200708   25  10
# 1118819  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  84.83  200708   31  20
# 1118820  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  84.83  200709   15   8
# 1118821   서울특별시 중구 묵정동  11-67   11.0  67.0      묵정  52.46  200701   10   5
#
#          건축년도  ... 아파트 카테고리  지하철 카테고리 구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리  \
# 0        1987  ...       기타       분당선    강남구       기타    5581.622466
# 1        1987  ...       기타       분당선    강남구       기타    5581.622466
# 2        1987  ...       기타       분당선    강남구       기타    5581.622466
# 3        1987  ...       기타       분당선    강남구       기타    5581.622466
# 4        1987  ...       기타       분당선    강남구       기타    5581.622466
# ...       ...  ...      ...       ...    ...      ...            ...
# 1118817  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118818  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118819  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118820  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118821  1981  ...       기타       3호선     기타       기타    3320.677588
#
#         가장 가까운 다리 index 가장 가까운 다리 인근 한강다리 개수  인근 다리 개수 1개이상 3개 이하   학군
# 0                  17.0      청담대교        0.0                    0  8.0
# 1                  17.0      청담대교        0.0                    0  8.0
# 2                  17.0      청담대교        0.0                    0  8.0
# 3                  17.0      청담대교        0.0                    0  8.0
# 4                  17.0      청담대교        0.0                    0  8.0
# ...                 ...       ...        ...                  ...  ...
# 1118817             2.0      가양대교        0.0                    0  2.0
# 1118818             2.0      가양대교        0.0                    0  2.0
# 1118819             2.0      가양대교        0.0                    0  2.0
# 1118820             2.0      가양대교        0.0                    0  2.0
# 1118821            14.0      동호대교        0.0                    0  5.0
#
# [1118814 rows x 103 columns]

# %%
train_df.reset_index(drop=True, inplace=True)
train_df
# Out:
#                    시군구     번지     본번    부번    아파트명   전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성  79.97  201801    8   2
# ...                ...    ...    ...   ...     ...    ...     ...  ...  ..
# 1118809  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  59.94  200707   12  11
# 1118810  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  59.94  200708   25  10
# 1118811  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  84.83  200708   31  20
# 1118812  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대  84.83  200709   15   8
# 1118813   서울특별시 중구 묵정동  11-67   11.0  67.0      묵정  52.46  200701   10   5
#
#          건축년도  ... 아파트 카테고리  지하철 카테고리 구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리  \
# 0        1987  ...       기타       분당선    강남구       기타    5581.622466
# 1        1987  ...       기타       분당선    강남구       기타    5581.622466
# 2        1987  ...       기타       분당선    강남구       기타    5581.622466
# 3        1987  ...       기타       분당선    강남구       기타    5581.622466
# 4        1987  ...       기타       분당선    강남구       기타    5581.622466
# ...       ...  ...      ...       ...    ...      ...            ...
# 1118809  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118810  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118811  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118812  1998  ...       기타       6호선     기타       현대    6109.517072
# 1118813  1981  ...       기타       3호선     기타       기타    3320.677588
#
#         가장 가까운 다리 index 가장 가까운 다리 인근 한강다리 개수  인근 다리 개수 1개이상 3개 이하   학군
# 0                  17.0      청담대교        0.0                    0  8.0
# 1                  17.0      청담대교        0.0                    0  8.0
# 2                  17.0      청담대교        0.0                    0  8.0
# 3                  17.0      청담대교        0.0                    0  8.0
# 4                  17.0      청담대교        0.0                    0  8.0
# ...                 ...       ...        ...                  ...  ...
# 1118809             2.0      가양대교        0.0                    0  2.0
# 1118810             2.0      가양대교        0.0                    0  2.0
# 1118811             2.0      가양대교        0.0                    0  2.0
# 1118812             2.0      가양대교        0.0                    0  2.0
# 1118813            14.0      동호대교        0.0                    0  5.0
#
# [1118814 rows x 103 columns]

# %%
re = pd.concat([train_df, test_df], axis=0)
re
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ... 아파트 카테고리  지하철 카테고리 구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리  \
# 0        1987  ...       기타       분당선    강남구       기타    5581.622466
# 1        1987  ...       기타       분당선    강남구       기타    5581.622466
# 2        1987  ...       기타       분당선    강남구       기타    5581.622466
# 3        1987  ...       기타       분당선    강남구       기타    5581.622466
# 4        1987  ...       기타       분당선    강남구       기타    5581.622466
# ...       ...  ...      ...       ...    ...      ...            ...
# 1128089  2014  ...       기타        기타     기타       기타    5918.624352
# 1128090  2014  ...       기타        기타     기타       기타    5918.624352
# 1128091  2014  ...       기타        기타     기타       기타    5918.624352
# 1128092  2014  ...       기타        기타     기타       기타    5918.624352
# 1128093  2014  ...       기타        기타     기타       기타    5918.624352
#
#         가장 가까운 다리 index 가장 가까운 다리 인근 한강다리 개수  인근 다리 개수 1개이상 3개 이하   학군
# 0                  17.0      청담대교        0.0                    0  8.0
# 1                  17.0      청담대교        0.0                    0  8.0
# 2                  17.0      청담대교        0.0                    0  8.0
# 3                  17.0      청담대교        0.0                    0  8.0
# 4                  17.0      청담대교        0.0                    0  8.0
# ...                 ...       ...        ...                  ...  ...
# 1128089            23.0    구리암사대교        0.0                    0  1.0
# 1128090            23.0    구리암사대교        0.0                    0  1.0
# 1128091            23.0    구리암사대교        0.0                    0  1.0
# 1128092            23.0    구리암사대교        0.0                    0  1.0
# 1128093            23.0    구리암사대교        0.0                    0  1.0
#
# [1128086 rows x 103 columns]

# %%
train_df = re[re['is_test']==0]

tmp = pd.DataFrame(train_df.groupby('층')['target'].mean())
tmp.reset_index(inplace=True)
tmp

plt.figure(figsize=(10, 8))
plt.bar(tmp['층'], tmp['target'])
plt.grid(True)
plt.show()

# %%
re.to_csv('../data/preprocessed/30_2_floor_target_outlier.csv', index=False)
