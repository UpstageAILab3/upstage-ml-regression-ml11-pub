# %% [markdown]
# # target이 30억 이상인 데이터에 대해서 따로 모델 구축

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import gc

from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error

import lightgbm as lgb

import joblib

# 맥에서 글씨 깨짐 방지
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # data load

# %%
df = pd.read_csv('../data/preprocessed/34_apart_price_mean.csv')
# Out:
# /tmp/ipykernel_637308/313617256.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/32_selling_point.csv')

# %% [markdown]
# # data 전처리

# %%
# 일부 feature 제거 - 기준은 내마음대로

df.drop(['해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)', 'k-전화번호',
         'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-복도유형', 'k-난방방식', 'k-전체동수', 'k-전체세대수',
         'k-사용검사일-사용승인일', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)', 'k-전용면적별세대현황(60~85이하)',
         'k-85~135이하', 'k-135초과', 'k-홈페이지', 'k-등록일자', 'k-수정일자', '고용보험관리번호', '경비비관리형태',
         '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드', '단지신청일'], axis=1, inplace=True)

# %%
# 추가로 제거가 필요한 feature 제거
df.drop(['시군구', '번지', '본번', '부번', '아파트명', '도로명', 'k-관리방식', 'k-건설사(시공사)', 'k-시행사', 'k-연면적', 'k-주거전용면적',
         '세대전기계약방법', '청소비관리형태', '건축면적', '주차대수', '시군구 번지', '좌표X,좌표Y', 'index', '역사_ID', '역사명', '위도', '경도',
         '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호', '가장 가까운 버스 정류소명',
         '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표', '가장 가까운 버스 정류장 Y좌표', '동', 
         '구', '호선'], axis=1, inplace=True)

# %%
# 계약월 변수 생성

df['계약월'] = df['계약년월'].astype(str).str[4:].astype(int)
df.drop(['계약년월', '계약일'], axis=1, inplace=True)
df['계약월_sin'] = np.sin(2 * np.pi * df['계약월'] / 12)
df.drop(['계약월'], axis=1, inplace=True)
df
# Out:
#            전용면적   층  건축년도        좌표X        좌표Y    target  is_test  \
# 0         79.97   3  1987  127.05721  37.476763  124000.0        0
# 1         79.97   4  1987  127.05721  37.476763  123500.0        0
# 2         54.98   5  1987  127.05721  37.476763   91500.0        0
# 3         79.97   4  1987  127.05721  37.476763  130000.0        0
# 4         79.97   2  1987  127.05721  37.476763  117000.0        0
# ...         ...  ..   ...        ...        ...       ...      ...
# 1128089   84.65  13  2014  127.10672  37.618870       NaN        1
# 1128090   84.62  12  2014  127.10672  37.618870       NaN        1
# 1128091  101.65  12  2014  127.10672  37.618870       NaN        1
# 1128092   84.94  18  2014  127.10672  37.618870       NaN        1
# 1128093   84.65  13  2014  127.10672  37.618870       NaN        1
#
#            가장 가까운 거리  인근 지하철 역 개수  가장 가까운 버스 정류장 거리  ...  구 카테고리  건설사 카테고리  \
# 0        1127.738351          2.0          61.89584  ...     강남구        기타
# 1        1127.738351          2.0          61.89584  ...     강남구        기타
# 2        1127.738351          2.0          61.89584  ...     강남구        기타
# 3        1127.738351          2.0          61.89584  ...     강남구        기타
# 4        1127.738351          2.0          61.89584  ...     강남구        기타
# ...              ...          ...               ...  ...     ...       ...
# 1128089   732.482898          4.0          59.47567  ...      기타        기타
# 1128090   732.482898          4.0          59.47567  ...      기타        기타
# 1128091   732.482898          4.0          59.47567  ...      기타        기타
# 1128092   732.482898          4.0          59.47567  ...      기타        기타
# 1128093   732.482898          4.0          59.47567  ...      기타        기타
#
#          가장 가까운 다리와의 거리  가장 가까운 다리 index  가장 가까운 다리  인근 한강다리 개수  \
# 0           5581.622466             17.0       청담대교         0.0
# 1           5581.622466             17.0       청담대교         0.0
# 2           5581.622466             17.0       청담대교         0.0
# 3           5581.622466             17.0       청담대교         0.0
# 4           5581.622466             17.0       청담대교         0.0
# ...                 ...              ...        ...         ...
# 1128089     5918.624352             23.0     구리암사대교         0.0
# 1128090     5918.624352             23.0     구리암사대교         0.0
# 1128091     5918.624352             23.0     구리암사대교         0.0
# 1128092     5918.624352             23.0     구리암사대교         0.0
# 1128093     5918.624352             23.0     구리암사대교         0.0
#
#          인근 다리 개수 1개이상 3개 이하   학군    매매가격 지수       계약월_sin
# 0                          0  8.0  67.392545 -2.449294e-16
# 1                          0  8.0  67.392545 -2.449294e-16
# 2                          0  8.0  67.392545 -2.449294e-16
# 3                          0  8.0  69.049924  5.000000e-01
# 4                          0  8.0  69.049924  5.000000e-01
# ...                      ...  ...        ...           ...
# 1128089                    0  1.0  91.623694 -5.000000e-01
# 1128090                    0  1.0  91.623694 -5.000000e-01
# 1128091                    0  1.0  91.066919 -8.660254e-01
# 1128092                    0  1.0  90.861265 -1.000000e+00
# 1128093                    0  1.0  90.861265 -1.000000e+00
#
# [1128094 rows x 41 columns]

# %% [markdown]
# # scaling

# %%
def scailing(col, scaler_type):
    if scaler_type == 'min_max': scaler = MinMaxScaler()
    else : scaler = StandardScaler()

    return scaler.fit_transform(df[[col]])

cols = ['전용면적', '층', '건축년도', '좌표X', '좌표Y', '가장 가까운 거리',
       '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP',
       '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양', '거래량',
       '구별 지가지수', '공시지가 평균', '매수우위지수', '건물나이', '구매력지수', '거래활발지수',
       '매매가격 지수 증감률', '매매 대비 전세가격 비율', '가장 가까운 다리와의 거리', '매매가격 지수', 
       '아파트 평균 가격', '계약월_sin']

for col in cols:
    print(col)
    scaler_type = 'min_max'
    if col == '계약월_sin': scaler_type = 'standard'

    df[[col]] = scailing(col, scaler_type)
# Out:
# 전용면적
# 층
# 건축년도
# 좌표X
# 좌표Y
# 가장 가까운 거리
# 인근 지하철 역 개수
# 가장 가까운 버스 정류장 거리
# 인근 버스 정류장 개수
# GDP
# 한국은행 기준금리
# 기대 인플레이션
# 지가지수
# 아파트 인허가
# 미분양
# 거래량
# 구별 지가지수
# 공시지가 평균
# 매수우위지수
# 건물나이
# 구매력지수
# 거래활발지수
# 매매가격 지수 증감률
# 매매 대비 전세가격 비율
# 가장 가까운 다리와의 거리
# 매매가격 지수
# 계약월_sin

# %% [markdown]
# # category

# %%
#df['30년이상50년이하'] = df['30년이상50년이하'].astype('category')
df['아파트 카테고리'] = df['아파트 카테고리'].astype('category')
df['지하철 카테고리'] = df['지하철 카테고리'].astype('category')
df['구 카테고리'] = df['구 카테고리'].astype('category')
df['건설사 카테고리'] = df['건설사 카테고리'].astype('category')
df['인근 다리 개수 1개이상 3개 이하'] = df['인근 다리 개수 1개이상 3개 이하'].astype('category')
df['학군'] = df['학군'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128094 entries, 0 to 1128093
# Data columns (total 41 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   전용면적                 1128094 non-null  float64
#  1   층                    1128094 non-null  float64
#  2   건축년도                 1128094 non-null  float64
#  3   좌표X                  1128094 non-null  float64
#  4   좌표Y                  1128094 non-null  float64
#  5   target               1118822 non-null  float64
#  6   is_test              1128094 non-null  int64
#  7   가장 가까운 거리            1128094 non-null  float64
#  8   인근 지하철 역 개수          1128094 non-null  float64
#  9   가장 가까운 버스 정류장 거리     1128094 non-null  float64
#  10  인근 버스 정류장 개수         1128094 non-null  float64
#  11  계약년                  1128094 non-null  int64
#  12  GDP                  1128094 non-null  float64
#  13  한국은행 기준금리            1128094 non-null  float64
#  14  기대 인플레이션             1128094 non-null  float64
#  15  지가지수                 1128094 non-null  float64
#  16  아파트 인허가              1128094 non-null  float64
#  17  미분양                  1128094 non-null  float64
#  18  거래량                  1128094 non-null  float64
#  19  건설사 랭킹               1128094 non-null  float64
#  20  구별 지가지수              1128094 non-null  float64
#  21  공시지가 평균              1128094 non-null  float64
#  22  매수우위지수               1128094 non-null  float64
#  23  건물나이                 1128094 non-null  float64
#  24  30년이상50년이하           1128094 non-null  int64
#  25  구매력지수                1128094 non-null  float64
#  26  거래활발지수               1128094 non-null  float64
#  27  매매가격 지수 증감률          1128094 non-null  float64
#  28  매매 대비 전세가격 비율        1128094 non-null  float64
#  29  아파트 카테고리             1128094 non-null  category
#  30  지하철 카테고리             1128094 non-null  category
#  31  구 카테고리               1128094 non-null  object
#  32  건설사 카테고리             1128094 non-null  object
#  33  가장 가까운 다리와의 거리       1128094 non-null  float64
#  34  가장 가까운 다리 index      1128094 non-null  float64
#  35  가장 가까운 다리            1128094 non-null  object
#  36  인근 한강다리 개수           1128094 non-null  float64
#  37  인근 다리 개수 1개이상 3개 이하  1128094 non-null  int64
#  38  학군                   1128094 non-null  category
#  39  매매가격 지수              1128094 non-null  float64
#  40  계약월_sin              1128094 non-null  float64
# dtypes: category(3), float64(31), int64(4), object(3)
# memory usage: 330.3+ MB

# %% [markdown]
# # train, test dataset

# %% [markdown]
# ## feature drop

# %%
train_df = df[df['is_test']==0]
test_df = df[df['is_test']==1]

# %%
train_df.drop(['is_test'], axis=1, inplace=True)
test_df.drop(['is_test'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_637308/1571330888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(['is_test'], axis=1, inplace=True)
# /tmp/ipykernel_637308/1571330888.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(['is_test'], axis=1, inplace=True)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (1118822, 40)
# (9272, 40)

# %%
train_df_1 = train_df
train_df_2 = train_df[train_df['target'] >= 300000]

# %% [markdown]
# ### target이 30억 이상인 데이터 분할

# %%
train_df_1_dropped = train_df_1.drop(['지가지수', '아파트 인허가', '미분양', '건설사 랭킹',
                      '구매력지수', '거래활발지수', '건물나이', '매매가격 지수 증감률',
                      '매매 대비 전세가격 비율', '구 카테고리',
                      '건설사 카테고리', '가장 가까운 다리 index', '가장 가까운 다리', '인근 한강다리 개수',
                      '인근 다리 개수 1개이상 3개 이하'], axis=1)

train_df_2_dropped = train_df_2.drop(['지가지수', '아파트 인허가', '미분양', '건설사 랭킹',
                      '구매력지수', '거래활발지수', '건물나이', '매매가격 지수 증감률',
                      '매매 대비 전세가격 비율', '구 카테고리',
                      '건설사 카테고리', '가장 가까운 다리 index', '가장 가까운 다리', '인근 한강다리 개수',
                      '인근 다리 개수 1개이상 3개 이하'], axis=1)

test_df_dropped = test_df.drop(['target', '지가지수', '아파트 인허가', '미분양', '건설사 랭킹',
                      '구매력지수', '거래활발지수', '건물나이', '매매가격 지수 증감률',
                      '매매 대비 전세가격 비율', '구 카테고리',
                      '건설사 카테고리', '가장 가까운 다리 index', '가장 가까운 다리', '인근 한강다리 개수',
                      '인근 다리 개수 1개이상 3개 이하'], axis=1)

# %%
train_df_1_dropped[['target']]
# Out:
#            target
# 0        124000.0
# 1        123500.0
# 2         91500.0
# 3        130000.0
# 4        117000.0
# ...           ...
# 1118817   20000.0
# 1118818   20000.0
# 1118819   28000.0
# 1118820   29000.0
# 1118821   13250.0
#
# [1118822 rows x 1 columns]

# %%
train_df_2_dropped[['target']]
# Out:
#            target
# 294      300000.0
# 647      300000.0
# 1308     395000.0
# 1309     390000.0
# 1310     443000.0
# ...           ...
# 1078852  301000.0
# 1078853  310500.0
# 1105621  400000.0
# 1105660  450000.0
# 1109922  300000.0
#
# [4951 rows x 1 columns]

# %%
X_1 = train_df_1_dropped.drop(['target'], axis=1)
y_1 = train_df_1_dropped[['target']]

X_2 = train_df_2_dropped.drop(['target'], axis=1)
y_2 = train_df_2_dropped[['target']]

X_1.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년', 'GDP', '한국은행 기준금리',
#        '기대 인플레이션', '거래량', '구별 지가지수', '공시지가 평균', '매수우위지수', '30년이상50년이하',
#        '아파트 카테고리', '지하철 카테고리', '가장 가까운 다리와의 거리', '학군', '매매가격 지수', '계약월_sin'],
#       dtype='object')

# %% [markdown]
# # model

# %% [markdown]
# ### 30억 이하

# %%
train_X_1, valid_X_1, train_y_1, valid_y_1 = train_test_split(X_1, y_1, train_size=0.95, test_size=0.05, random_state=74)

# %%
params = {
    'n_estimators': 100000,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'metric_freq': 20,
    'device': 'gpu',
    'verbosity': 0
}

model_1 = lgb.LGBMRegressor(n_estimators=100000,
                          metric='rmse', data_sample_strategy='goss'
                          )

model_1.fit(
    train_X_1, train_y_1,
    eval_set = [(train_X_1, train_y_1), (valid_X_1, valid_y_1)],
    eval_metric='rmse',
    callbacks=[lgb.early_stopping(stopping_rounds=60),
               lgb.log_evaluation(period=10, show_stdv=True)]
)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014521 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2972
# [LightGBM] [Info] Number of data points in the train set: 1062880, number of used features: 24
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 57982.908459
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 26249.5	valid_1's rmse: 26853.1
# [20]	training's rmse: 19122.6	valid_1's rmse: 19489.3
# [30]	training's rmse: 16084.7	valid_1's rmse: 16342.7
# [40]	training's rmse: 14533.8	valid_1's rmse: 14755.5
# [50]	training's rmse: 13569	valid_1's rmse: 13809.2
# [60]	training's rmse: 12970	valid_1's rmse: 13212.6
# [70]	training's rmse: 12466.7	valid_1's rmse: 12730.2
# [80]	training's rmse: 12077.3	valid_1's rmse: 12357.6
# [90]	training's rmse: 11718.5	valid_1's rmse: 11996.4
# [100]	training's rmse: 11418.5	valid_1's rmse: 11686.6
# [110]	training's rmse: 11160.7	valid_1's rmse: 11407
# [120]	training's rmse: 10913.6	valid_1's rmse: 11157.6
# [130]	training's rmse: 10686.6	valid_1's rmse: 10932.2
# [140]	training's rmse: 10489	valid_1's rmse: 10721.2
# [150]	training's rmse: 10315.8	valid_1's rmse: 10557.2
# [160]	training's rmse: 10164	valid_1's rmse: 10401.7
# [170]	training's rmse: 9998.5	valid_1's rmse: 10244.9
# [180]	training's rmse: 9886	valid_1's rmse: 10141
# [190]	training's rmse: 9770.55	valid_1's rmse: 10035.9
# [200]	training's rmse: 9645.44	valid_1's rmse: 9921.88
# [210]	training's rmse: 9539.07	valid_1's rmse: 9816.55
# [220]	training's rmse: 9423.8	valid_1's rmse: 9714.24
# [230]	training's rmse: 9334.49	valid_1's rmse: 9629.99
# [240]	training's rmse: 9235.93	valid_1's rmse: 9527.59
# [250]	training's rmse: 9133.99	valid_1's rmse: 9435.6
# [260]	training's rmse: 9057.29	valid_1's rmse: 9366.56
# [270]	training's rmse: 8975.72	valid_1's rmse: 9291.94
# [280]	training's rmse: 8900.83	valid_1's rmse: 9217.46
# [290]	training's rmse: 8821.76	valid_1's rmse: 9145.97
# [300]	training's rmse: 8755.8	valid_1's rmse: 9084.71
# [310]	training's rmse: 8683.61	valid_1's rmse: 9016.89
# [320]	training's rmse: 8621.49	valid_1's rmse: 8962.26
# [330]	training's rmse: 8553.86	valid_1's rmse: 8901.43
# [340]	training's rmse: 8489.6	valid_1's rmse: 8842.24
# [350]	training's rmse: 8429.59	valid_1's rmse: 8785.02
# [360]	training's rmse: 8371.84	valid_1's rmse: 8729.57
# [370]	training's rmse: 8305.82	valid_1's rmse: 8662.45
# [380]	training's rmse: 8266.33	valid_1's rmse: 8617.1
# [390]	training's rmse: 8207.19	valid_1's rmse: 8564.3
# [400]	training's rmse: 8156.8	valid_1's rmse: 8518.18
# [410]	training's rmse: 8108.18	valid_1's rmse: 8474.03
# [420]	training's rmse: 8061.91	valid_1's rmse: 8431.09
# [430]	training's rmse: 8016.65	valid_1's rmse: 8386.69
# [440]	training's rmse: 7971.21	valid_1's rmse: 8344.55
# [450]	training's rmse: 7924.86	valid_1's rmse: 8304.66
# [460]	training's rmse: 7870.33	valid_1's rmse: 8255.61
# [470]	training's rmse: 7830.69	valid_1's rmse: 8219.8
# [480]	training's rmse: 7782.85	valid_1's rmse: 8182.29
# [490]	training's rmse: 7739.89	valid_1's rmse: 8146.81
# [500]	training's rmse: 7705.92	valid_1's rmse: 8117.21
# [510]	training's rmse: 7670.6	valid_1's rmse: 8082.71
# [520]	training's rmse: 7626.89	valid_1's rmse: 8046.48
# [530]	training's rmse: 7586.36	valid_1's rmse: 8008.99
# [540]	training's rmse: 7552.1	valid_1's rmse: 7980.46
# [550]	training's rmse: 7521.75	valid_1's rmse: 7958.92
# [560]	training's rmse: 7494.27	valid_1's rmse: 7941.31
# [570]	training's rmse: 7460.11	valid_1's rmse: 7910.59
# [580]	training's rmse: 7424.2	valid_1's rmse: 7873.54
# [590]	training's rmse: 7392.62	valid_1's rmse: 7841.32
# [600]	training's rmse: 7367.48	valid_1's rmse: 7821.23
# [610]	training's rmse: 7337.95	valid_1's rmse: 7796.61
# [620]	training's rmse: 7311	valid_1's rmse: 7771.31
# [630]	training's rmse: 7285.96	valid_1's rmse: 7749.36
# [640]	training's rmse: 7255.09	valid_1's rmse: 7723.72
# [650]	training's rmse: 7221.92	valid_1's rmse: 7695.11
# [660]	training's rmse: 7198.61	valid_1's rmse: 7675.12
# [670]	training's rmse: 7175.64	valid_1's rmse: 7654
# [680]	training's rmse: 7152.3	valid_1's rmse: 7637.08
# [690]	training's rmse: 7129.65	valid_1's rmse: 7618.76
# [700]	training's rmse: 7105.51	valid_1's rmse: 7598.94
# [710]	training's rmse: 7076.79	valid_1's rmse: 7574.73
# [720]	training's rmse: 7047.66	valid_1's rmse: 7541.91
# [730]	training's rmse: 7024.39	valid_1's rmse: 7521.52
# [740]	training's rmse: 7000.03	valid_1's rmse: 7498.15
# [750]	training's rmse: 6974.13	valid_1's rmse: 7478.13
# [760]	training's rmse: 6945.26	valid_1's rmse: 7450.55
# [770]	training's rmse: 6920.45	valid_1's rmse: 7428.7
# [780]	training's rmse: 6894.86	valid_1's rmse: 7409.39
# [790]	training's rmse: 6873.9	valid_1's rmse: 7392.51
# [800]	training's rmse: 6851.34	valid_1's rmse: 7370.12
# [810]	training's rmse: 6832.04	valid_1's rmse: 7356.73
# [820]	training's rmse: 6809.43	valid_1's rmse: 7339.42
# [830]	training's rmse: 6787.54	valid_1's rmse: 7318.65
# [840]	training's rmse: 6767.49	valid_1's rmse: 7304.17
# [850]	training's rmse: 6744.41	valid_1's rmse: 7286.72
# [860]	training's rmse: 6724.91	valid_1's rmse: 7270.08
# [870]	training's rmse: 6707.93	valid_1's rmse: 7256.27
# [880]	training's rmse: 6690.26	valid_1's rmse: 7242.57
# [890]	training's rmse: 6668.4	valid_1's rmse: 7220.5
# [900]	training's rmse: 6648.82	valid_1's rmse: 7204.68
# [910]	training's rmse: 6628.54	valid_1's rmse: 7185.81
# [920]	training's rmse: 6611.81	valid_1's rmse: 7173.13
# [930]	training's rmse: 6591.65	valid_1's rmse: 7159.99
# [940]	training's rmse: 6575.07	valid_1's rmse: 7148.03
# [950]	training's rmse: 6556.36	valid_1's rmse: 7129.17
# [960]	training's rmse: 6539.21	valid_1's rmse: 7114.88
# [970]	training's rmse: 6519.3	valid_1's rmse: 7095.28
# [980]	training's rmse: 6504.68	valid_1's rmse: 7084.92
# [990]	training's rmse: 6489.61	valid_1's rmse: 7069.52
# [1000]	training's rmse: 6474.64	valid_1's rmse: 7056.58
# [1010]	training's rmse: 6457.98	valid_1's rmse: 7044.51
# [1020]	training's rmse: 6439.35	valid_1's rmse: 7030.44
# [1030]	training's rmse: 6424.14	valid_1's rmse: 7018.42
# [1040]	training's rmse: 6407.15	valid_1's rmse: 7005.18
# [1050]	training's rmse: 6389.47	valid_1's rmse: 6990.05
# [1060]	training's rmse: 6378.32	valid_1's rmse: 6984.39
# [1070]	training's rmse: 6360.99	valid_1's rmse: 6974.39
# [1080]	training's rmse: 6345.52	valid_1's rmse: 6961.88
# [1090]	training's rmse: 6332.81	valid_1's rmse: 6951.91
# [1100]	training's rmse: 6316.86	valid_1's rmse: 6940.78
# [1110]	training's rmse: 6301.65	valid_1's rmse: 6931.58
# [1120]	training's rmse: 6289.21	valid_1's rmse: 6920.1
# [1130]	training's rmse: 6278.79	valid_1's rmse: 6915.75
# [1140]	training's rmse: 6265.17	valid_1's rmse: 6906.71
# [1150]	training's rmse: 6251.02	valid_1's rmse: 6896.53
# [1160]	training's rmse: 6236.81	valid_1's rmse: 6882.91
# [1170]	training's rmse: 6223.82	valid_1's rmse: 6872.91
# [1180]	training's rmse: 6211.07	valid_1's rmse: 6862.18
# [1190]	training's rmse: 6196.46	valid_1's rmse: 6851.34
# [1200]	training's rmse: 6185.28	valid_1's rmse: 6841.71
# [1210]	training's rmse: 6170.56	valid_1's rmse: 6833.88
# [1220]	training's rmse: 6157.85	valid_1's rmse: 6823.25
# [1230]	training's rmse: 6144.39	valid_1's rmse: 6811.96
# [1240]	training's rmse: 6131.33	valid_1's rmse: 6800.63
# [1250]	training's rmse: 6120.5	valid_1's rmse: 6795.99
# [1260]	training's rmse: 6108.06	valid_1's rmse: 6786.34
# [1270]	training's rmse: 6096.84	valid_1's rmse: 6779.19
# [1280]	training's rmse: 6084.16	valid_1's rmse: 6772.15
# [1290]	training's rmse: 6073.14	valid_1's rmse: 6762.92
# [1300]	training's rmse: 6062.41	valid_1's rmse: 6756.1
# [1310]	training's rmse: 6048.66	valid_1's rmse: 6743.98
# [1320]	training's rmse: 6035.31	valid_1's rmse: 6730.52
# [1330]	training's rmse: 6023.59	valid_1's rmse: 6720.7
# [1340]	training's rmse: 6012.69	valid_1's rmse: 6712.26
# [1350]	training's rmse: 6000.99	valid_1's rmse: 6705.5
# [1360]	training's rmse: 5989.03	valid_1's rmse: 6697.32
# [1370]	training's rmse: 5976.59	valid_1's rmse: 6687.71
# [1380]	training's rmse: 5965.21	valid_1's rmse: 6679.02
# [1390]	training's rmse: 5955.75	valid_1's rmse: 6671.9
# [1400]	training's rmse: 5944.38	valid_1's rmse: 6664.17
# [1410]	training's rmse: 5934	valid_1's rmse: 6655.93
# [1420]	training's rmse: 5923.36	valid_1's rmse: 6649.34
# [1430]	training's rmse: 5912.79	valid_1's rmse: 6641.12
# [1440]	training's rmse: 5903.18	valid_1's rmse: 6634.59
# [1450]	training's rmse: 5892.63	valid_1's rmse: 6627.07
# [1460]	training's rmse: 5882.38	valid_1's rmse: 6620.19
# [1470]	training's rmse: 5871.44	valid_1's rmse: 6613.02
# [1480]	training's rmse: 5859.32	valid_1's rmse: 6604.84
# [1490]	training's rmse: 5848.2	valid_1's rmse: 6594.96
# [1500]	training's rmse: 5839.09	valid_1's rmse: 6589.81
# [1510]	training's rmse: 5828.89	valid_1's rmse: 6583.57
# [1520]	training's rmse: 5820.5	valid_1's rmse: 6575.87
# [1530]	training's rmse: 5811.24	valid_1's rmse: 6567.6
# [1540]	training's rmse: 5802.07	valid_1's rmse: 6560.59
# [1550]	training's rmse: 5791.76	valid_1's rmse: 6553.05
# [1560]	training's rmse: 5780.12	valid_1's rmse: 6543.2
# [1570]	training's rmse: 5770.72	valid_1's rmse: 6541.84
# [1580]	training's rmse: 5761.1	valid_1's rmse: 6533.24
# [1590]	training's rmse: 5751.91	valid_1's rmse: 6525.52
# [1600]	training's rmse: 5741.55	valid_1's rmse: 6517.04
# [1610]	training's rmse: 5730.91	valid_1's rmse: 6511.71
# [1620]	training's rmse: 5721.1	valid_1's rmse: 6505.77
# [1630]	training's rmse: 5710.92	valid_1's rmse: 6500.68
# [1640]	training's rmse: 5703.27	valid_1's rmse: 6496.55
# [1650]	training's rmse: 5695.2	valid_1's rmse: 6490.81
# [1660]	training's rmse: 5688.58	valid_1's rmse: 6486.03
# [1670]	training's rmse: 5679.63	valid_1's rmse: 6480.69
# [1680]	training's rmse: 5669.88	valid_1's rmse: 6472.37
# [1690]	training's rmse: 5659.41	valid_1's rmse: 6464.26
# [1700]	training's rmse: 5651.61	valid_1's rmse: 6458.47
# [1710]	training's rmse: 5643.39	valid_1's rmse: 6454.15
# [1720]	training's rmse: 5634.71	valid_1's rmse: 6449.3
# [1730]	training's rmse: 5625.9	valid_1's rmse: 6443.49
# [1740]	training's rmse: 5618.12	valid_1's rmse: 6437.16
# [1750]	training's rmse: 5610.22	valid_1's rmse: 6433.23
# [1760]	training's rmse: 5603.78	valid_1's rmse: 6429.81
# [1770]	training's rmse: 5594.51	valid_1's rmse: 6425.83
# [1780]	training's rmse: 5585.53	valid_1's rmse: 6417.92
# [1790]	training's rmse: 5578.26	valid_1's rmse: 6412.11
# [1800]	training's rmse: 5569.84	valid_1's rmse: 6403.27
# [1810]	training's rmse: 5560.7	valid_1's rmse: 6400.33
# [1820]	training's rmse: 5552.99	valid_1's rmse: 6397.62
# [1830]	training's rmse: 5544.48	valid_1's rmse: 6391.02
# [1840]	training's rmse: 5537.06	valid_1's rmse: 6385
# [1850]	training's rmse: 5529.35	valid_1's rmse: 6379.15
# [1860]	training's rmse: 5522.04	valid_1's rmse: 6374.95
# [1870]	training's rmse: 5515.63	valid_1's rmse: 6369.4
# [1880]	training's rmse: 5507.08	valid_1's rmse: 6364.36
# [1890]	training's rmse: 5501.85	valid_1's rmse: 6360.83
# [1900]	training's rmse: 5494.3	valid_1's rmse: 6354.7
# [1910]	training's rmse: 5486.75	valid_1's rmse: 6348.66
# [1920]	training's rmse: 5479.29	valid_1's rmse: 6342.3
# [1930]	training's rmse: 5470.31	valid_1's rmse: 6333.88
# [1940]	training's rmse: 5463.36	valid_1's rmse: 6328.26
# [1950]	training's rmse: 5457.12	valid_1's rmse: 6323.49
# [1960]	training's rmse: 5448.97	valid_1's rmse: 6319.05
# [1970]	training's rmse: 5442.72	valid_1's rmse: 6314.02
# [1980]	training's rmse: 5436.12	valid_1's rmse: 6311.03
# [1990]	training's rmse: 5429.54	valid_1's rmse: 6306.57
# [2000]	training's rmse: 5422.97	valid_1's rmse: 6301.76
# [2010]	training's rmse: 5416.48	valid_1's rmse: 6298.41
# [2020]	training's rmse: 5409.49	valid_1's rmse: 6293.89
# [2030]	training's rmse: 5402.69	valid_1's rmse: 6290.64
# [2040]	training's rmse: 5395.7	valid_1's rmse: 6287.12
# [2050]	training's rmse: 5389.57	valid_1's rmse: 6282.76
# [2060]	training's rmse: 5381.51	valid_1's rmse: 6275.98
# [2070]	training's rmse: 5375.27	valid_1's rmse: 6272.55
# [2080]	training's rmse: 5368.67	valid_1's rmse: 6268.89
# [2090]	training's rmse: 5362.1	valid_1's rmse: 6263.95
# [2100]	training's rmse: 5355.01	valid_1's rmse: 6259.62
# [2110]	training's rmse: 5347.99	valid_1's rmse: 6253.78
# [2120]	training's rmse: 5341.74	valid_1's rmse: 6251.26
# [2130]	training's rmse: 5336.26	valid_1's rmse: 6247.74
# [2140]	training's rmse: 5330.86	valid_1's rmse: 6245.96
# [2150]	training's rmse: 5323.67	valid_1's rmse: 6241.43
# [2160]	training's rmse: 5316.27	valid_1's rmse: 6236
# [2170]	training's rmse: 5309.76	valid_1's rmse: 6232.93
# [2180]	training's rmse: 5303.84	valid_1's rmse: 6229.2
# [2190]	training's rmse: 5297.97	valid_1's rmse: 6227.52
# [2200]	training's rmse: 5292.34	valid_1's rmse: 6223.23
# [2210]	training's rmse: 5286.11	valid_1's rmse: 6219.92
# [2220]	training's rmse: 5279.96	valid_1's rmse: 6217.37
# [2230]	training's rmse: 5274.82	valid_1's rmse: 6213.73
# [2240]	training's rmse: 5268.85	valid_1's rmse: 6209.82
# [2250]	training's rmse: 5262.89	valid_1's rmse: 6205.99
# [2260]	training's rmse: 5257.43	valid_1's rmse: 6201.57
# [2270]	training's rmse: 5251	valid_1's rmse: 6198.76
# [2280]	training's rmse: 5245	valid_1's rmse: 6194.98
# [2290]	training's rmse: 5239.28	valid_1's rmse: 6193.04
# [2300]	training's rmse: 5232.46	valid_1's rmse: 6186.98
# [2310]	training's rmse: 5226.91	valid_1's rmse: 6182.61
# [2320]	training's rmse: 5218.94	valid_1's rmse: 6177.03
# [2330]	training's rmse: 5212.59	valid_1's rmse: 6175.58
# [2340]	training's rmse: 5207.25	valid_1's rmse: 6171.76
# [2350]	training's rmse: 5201.78	valid_1's rmse: 6166.98
# [2360]	training's rmse: 5196.54	valid_1's rmse: 6164.81
# [2370]	training's rmse: 5191.18	valid_1's rmse: 6162.03
# [2380]	training's rmse: 5185.4	valid_1's rmse: 6158.5
# [2390]	training's rmse: 5180	valid_1's rmse: 6151.72
# [2400]	training's rmse: 5175.12	valid_1's rmse: 6148.8
# [2410]	training's rmse: 5169.54	valid_1's rmse: 6144.69
# [2420]	training's rmse: 5164.36	valid_1's rmse: 6140.45
# [2430]	training's rmse: 5159.21	valid_1's rmse: 6138.92
# [2440]	training's rmse: 5153.37	valid_1's rmse: 6135.47
# [2450]	training's rmse: 5148.57	valid_1's rmse: 6132.94
# [2460]	training's rmse: 5144.36	valid_1's rmse: 6130.43
# [2470]	training's rmse: 5139.97	valid_1's rmse: 6128.54
# [2480]	training's rmse: 5133.63	valid_1's rmse: 6125.97
# [2490]	training's rmse: 5128.45	valid_1's rmse: 6122.05
# [2500]	training's rmse: 5123.27	valid_1's rmse: 6120.47
# [2510]	training's rmse: 5118.33	valid_1's rmse: 6116.99
# [2520]	training's rmse: 5112.55	valid_1's rmse: 6112.41
# [2530]	training's rmse: 5107.09	valid_1's rmse: 6109.24
# [2540]	training's rmse: 5102.37	valid_1's rmse: 6105.81
# [2550]	training's rmse: 5097.08	valid_1's rmse: 6104.92
# [2560]	training's rmse: 5091.85	valid_1's rmse: 6102.04
# [2570]	training's rmse: 5087.91	valid_1's rmse: 6100.8
# [2580]	training's rmse: 5083.12	valid_1's rmse: 6098.21
# [2590]	training's rmse: 5078.7	valid_1's rmse: 6095.16
# [2600]	training's rmse: 5074.65	valid_1's rmse: 6091.99
# [2610]	training's rmse: 5067.93	valid_1's rmse: 6087.19
# [2620]	training's rmse: 5062.56	valid_1's rmse: 6083.3
# [2630]	training's rmse: 5057.78	valid_1's rmse: 6080.18
# [2640]	training's rmse: 5052.89	valid_1's rmse: 6078.04
# [2650]	training's rmse: 5048.33	valid_1's rmse: 6073.99
# [2660]	training's rmse: 5044.04	valid_1's rmse: 6071.65
# [2670]	training's rmse: 5038.86	valid_1's rmse: 6069.07
# [2680]	training's rmse: 5034.91	valid_1's rmse: 6066.6
# [2690]	training's rmse: 5029.33	valid_1's rmse: 6064.77
# [2700]	training's rmse: 5024.24	valid_1's rmse: 6061.64
# [2710]	training's rmse: 5019.63	valid_1's rmse: 6059.83
# [2720]	training's rmse: 5014.3	valid_1's rmse: 6054.88
# [2730]	training's rmse: 5009.76	valid_1's rmse: 6051.72
# [2740]	training's rmse: 5005.02	valid_1's rmse: 6050.12
# [2750]	training's rmse: 5000.35	valid_1's rmse: 6048.55
# [2760]	training's rmse: 4996.31	valid_1's rmse: 6046.52
# [2770]	training's rmse: 4992.21	valid_1's rmse: 6044.23
# [2780]	training's rmse: 4988.04	valid_1's rmse: 6044.25
# [2790]	training's rmse: 4983.73	valid_1's rmse: 6041.9
# [2800]	training's rmse: 4979.03	valid_1's rmse: 6040.49
# [2810]	training's rmse: 4975.06	valid_1's rmse: 6038.26
# [2820]	training's rmse: 4971.1	valid_1's rmse: 6037.03
# [2830]	training's rmse: 4967.25	valid_1's rmse: 6034.07
# [2840]	training's rmse: 4962.79	valid_1's rmse: 6029.88
# [2850]	training's rmse: 4958.3	valid_1's rmse: 6029.94
# [2860]	training's rmse: 4953.48	valid_1's rmse: 6027.19
# [2870]	training's rmse: 4949.11	valid_1's rmse: 6024.8
# [2880]	training's rmse: 4943.46	valid_1's rmse: 6022.42
# [2890]	training's rmse: 4939.08	valid_1's rmse: 6019.46
# [2900]	training's rmse: 4934.67	valid_1's rmse: 6016.77
# [2910]	training's rmse: 4930.05	valid_1's rmse: 6014.63
# [2920]	training's rmse: 4925.83	valid_1's rmse: 6011.39
# [2930]	training's rmse: 4922.04	valid_1's rmse: 6010.04
# [2940]	training's rmse: 4916.93	valid_1's rmse: 6007.24
# [2950]	training's rmse: 4912.76	valid_1's rmse: 6005.51
# [2960]	training's rmse: 4909.35	valid_1's rmse: 6003.76
# [2970]	training's rmse: 4905.33	valid_1's rmse: 6000.94
# [2980]	training's rmse: 4902.22	valid_1's rmse: 5999.63
# [2990]	training's rmse: 4898.09	valid_1's rmse: 5997.18
# [3000]	training's rmse: 4894.42	valid_1's rmse: 5995.5
# [3010]	training's rmse: 4890.2	valid_1's rmse: 5992.85
# [3020]	training's rmse: 4885.78	valid_1's rmse: 5990.79
# [3030]	training's rmse: 4881.46	valid_1's rmse: 5987.65
# [3040]	training's rmse: 4876.59	valid_1's rmse: 5985.27
# [3050]	training's rmse: 4871.26	valid_1's rmse: 5981.6
# [3060]	training's rmse: 4866.66	valid_1's rmse: 5979.71
# [3070]	training's rmse: 4861.87	valid_1's rmse: 5978.56
# [3080]	training's rmse: 4858.05	valid_1's rmse: 5976.56
# [3090]	training's rmse: 4854.37	valid_1's rmse: 5975.59
# [3100]	training's rmse: 4850.58	valid_1's rmse: 5975.88
# [3110]	training's rmse: 4846.42	valid_1's rmse: 5972.19
# [3120]	training's rmse: 4842.36	valid_1's rmse: 5971.03
# [3130]	training's rmse: 4838.37	valid_1's rmse: 5968.92
# [3140]	training's rmse: 4833.59	valid_1's rmse: 5966.76
# [3150]	training's rmse: 4829.8	valid_1's rmse: 5964.42
# [3160]	training's rmse: 4825.73	valid_1's rmse: 5962.17
# [3170]	training's rmse: 4821.96	valid_1's rmse: 5960.77
# [3180]	training's rmse: 4817.46	valid_1's rmse: 5957.42
# [3190]	training's rmse: 4812.79	valid_1's rmse: 5954.07
# [3200]	training's rmse: 4808.23	valid_1's rmse: 5952.85
# [3210]	training's rmse: 4804.1	valid_1's rmse: 5950.47
# [3220]	training's rmse: 4800.08	valid_1's rmse: 5947.11
# [3230]	training's rmse: 4795.8	valid_1's rmse: 5946.44
# [3240]	training's rmse: 4792.12	valid_1's rmse: 5945.72
# [3250]	training's rmse: 4788.46	valid_1's rmse: 5944.03
# [3260]	training's rmse: 4785.11	valid_1's rmse: 5941.38
# [3270]	training's rmse: 4782.05	valid_1's rmse: 5938.63
# [3280]	training's rmse: 4778.46	valid_1's rmse: 5937.65
# [3290]	training's rmse: 4775	valid_1's rmse: 5936.34
# [3300]	training's rmse: 4771.43	valid_1's rmse: 5934.05
# [3310]	training's rmse: 4768.29	valid_1's rmse: 5931.42
# [3320]	training's rmse: 4764.13	valid_1's rmse: 5929.06
# [3330]	training's rmse: 4759.82	valid_1's rmse: 5926.09
# [3340]	training's rmse: 4755.76	valid_1's rmse: 5924.06
# [3350]	training's rmse: 4752.87	valid_1's rmse: 5922.51
# [3360]	training's rmse: 4748.82	valid_1's rmse: 5919.58
# [3370]	training's rmse: 4745.15	valid_1's rmse: 5917.92
# [3380]	training's rmse: 4742.21	valid_1's rmse: 5916.78
# [3390]	training's rmse: 4739.03	valid_1's rmse: 5915.5
# [3400]	training's rmse: 4735.53	valid_1's rmse: 5914.42
# [3410]	training's rmse: 4732.58	valid_1's rmse: 5913.27
# [3420]	training's rmse: 4728.85	valid_1's rmse: 5912.56
# [3430]	training's rmse: 4725.32	valid_1's rmse: 5910.72
# [3440]	training's rmse: 4721.75	valid_1's rmse: 5909.84
# [3450]	training's rmse: 4718.4	valid_1's rmse: 5907.56
# [3460]	training's rmse: 4714.56	valid_1's rmse: 5905.54
# [3470]	training's rmse: 4711.03	valid_1's rmse: 5904.07
# [3480]	training's rmse: 4707.05	valid_1's rmse: 5902.44
# [3490]	training's rmse: 4703.07	valid_1's rmse: 5901.6
# [3500]	training's rmse: 4699.31	valid_1's rmse: 5899.99
# [3510]	training's rmse: 4696.62	valid_1's rmse: 5899.38
# [3520]	training's rmse: 4692.13	valid_1's rmse: 5894.33
# [3530]	training's rmse: 4687.99	valid_1's rmse: 5891.99
# [3540]	training's rmse: 4684.52	valid_1's rmse: 5890.47
# [3550]	training's rmse: 4680.97	valid_1's rmse: 5887.58
# [3560]	training's rmse: 4677.67	valid_1's rmse: 5886.72
# [3570]	training's rmse: 4673.95	valid_1's rmse: 5885.93
# [3580]	training's rmse: 4669.77	valid_1's rmse: 5884.26
# [3590]	training's rmse: 4665.67	valid_1's rmse: 5883
# [3600]	training's rmse: 4662.54	valid_1's rmse: 5883
# [3610]	training's rmse: 4658.49	valid_1's rmse: 5881.32
# [3620]	training's rmse: 4654.91	valid_1's rmse: 5880.41
# [3630]	training's rmse: 4651.56	valid_1's rmse: 5879.2
# [3640]	training's rmse: 4648.4	valid_1's rmse: 5877.42
# [3650]	training's rmse: 4644.65	valid_1's rmse: 5875.64
# [3660]	training's rmse: 4641.51	valid_1's rmse: 5873.47
# [3670]	training's rmse: 4637.53	valid_1's rmse: 5873.56
# [3680]	training's rmse: 4634.24	valid_1's rmse: 5873.35
# [3690]	training's rmse: 4631.47	valid_1's rmse: 5871.94
# [3700]	training's rmse: 4627.6	valid_1's rmse: 5871.94
# [3710]	training's rmse: 4624.43	valid_1's rmse: 5871.84
# [3720]	training's rmse: 4621.14	valid_1's rmse: 5869.91
# [3730]	training's rmse: 4618.69	valid_1's rmse: 5868.57
# [3740]	training's rmse: 4616.2	valid_1's rmse: 5867.08
# [3750]	training's rmse: 4613.46	valid_1's rmse: 5865.76
# [3760]	training's rmse: 4609.94	valid_1's rmse: 5864.44
# [3770]	training's rmse: 4606.98	valid_1's rmse: 5864.12
# [3780]	training's rmse: 4603.64	valid_1's rmse: 5861.49
# [3790]	training's rmse: 4599.91	valid_1's rmse: 5857.85
# [3800]	training's rmse: 4596.76	valid_1's rmse: 5856.46
# [3810]	training's rmse: 4593.44	valid_1's rmse: 5855.74
# [3820]	training's rmse: 4589.79	valid_1's rmse: 5854.21
# [3830]	training's rmse: 4586.34	valid_1's rmse: 5853.3
# [3840]	training's rmse: 4583.37	valid_1's rmse: 5852.45
# [3850]	training's rmse: 4579.92	valid_1's rmse: 5850.08
# [3860]	training's rmse: 4577.29	valid_1's rmse: 5848.48
# [3870]	training's rmse: 4573.99	valid_1's rmse: 5845.82
# [3880]	training's rmse: 4571.2	valid_1's rmse: 5844.31
# [3890]	training's rmse: 4568.17	valid_1's rmse: 5842.52
# [3900]	training's rmse: 4565.07	valid_1's rmse: 5841.04
# [3910]	training's rmse: 4561.94	valid_1's rmse: 5840.44
# [3920]	training's rmse: 4558.68	valid_1's rmse: 5838.78
# [3930]	training's rmse: 4556.3	valid_1's rmse: 5838.09
# [3940]	training's rmse: 4553.27	valid_1's rmse: 5837.54
# [3950]	training's rmse: 4549.84	valid_1's rmse: 5837.8
# [3960]	training's rmse: 4546.77	valid_1's rmse: 5838.17
# [3970]	training's rmse: 4543.58	valid_1's rmse: 5836.43
# [3980]	training's rmse: 4540.21	valid_1's rmse: 5834.49
# [3990]	training's rmse: 4537.47	valid_1's rmse: 5832.93
# [4000]	training's rmse: 4535.09	valid_1's rmse: 5832.39
# [4010]	training's rmse: 4531.93	valid_1's rmse: 5829.15
# [4020]	training's rmse: 4529.38	valid_1's rmse: 5828.12
# [4030]	training's rmse: 4525.93	valid_1's rmse: 5827.13
# [4040]	training's rmse: 4523.29	valid_1's rmse: 5825.39
# [4050]	training's rmse: 4520.33	valid_1's rmse: 5823.79
# [4060]	training's rmse: 4517.45	valid_1's rmse: 5821.57
# [4070]	training's rmse: 4514.36	valid_1's rmse: 5820.05
# [4080]	training's rmse: 4510.91	valid_1's rmse: 5819.51
# [4090]	training's rmse: 4507.9	valid_1's rmse: 5817.26
# [4100]	training's rmse: 4504.94	valid_1's rmse: 5815.51
# [4110]	training's rmse: 4501.7	valid_1's rmse: 5814.5
# [4120]	training's rmse: 4498.71	valid_1's rmse: 5811.19
# [4130]	training's rmse: 4496.05	valid_1's rmse: 5809.34
# [4140]	training's rmse: 4493.06	valid_1's rmse: 5807.07
# [4150]	training's rmse: 4490.12	valid_1's rmse: 5805.17
# [4160]	training's rmse: 4487.3	valid_1's rmse: 5803.35
# [4170]	training's rmse: 4484.52	valid_1's rmse: 5802.91
# [4180]	training's rmse: 4482.35	valid_1's rmse: 5801.01
# [4190]	training's rmse: 4479.75	valid_1's rmse: 5800.89
# [4200]	training's rmse: 4477.15	valid_1's rmse: 5798.88
# [4210]	training's rmse: 4474.69	valid_1's rmse: 5797.66
# [4220]	training's rmse: 4470.27	valid_1's rmse: 5794.5
# [4230]	training's rmse: 4467.54	valid_1's rmse: 5793.02
# [4240]	training's rmse: 4464.86	valid_1's rmse: 5791.25
# [4250]	training's rmse: 4461.87	valid_1's rmse: 5790.93
# [4260]	training's rmse: 4459.02	valid_1's rmse: 5788.49
# [4270]	training's rmse: 4456.33	valid_1's rmse: 5787.94
# [4280]	training's rmse: 4453.25	valid_1's rmse: 5787.59
# [4290]	training's rmse: 4450.33	valid_1's rmse: 5785.71
# [4300]	training's rmse: 4448.16	valid_1's rmse: 5785.24
# [4310]	training's rmse: 4445.67	valid_1's rmse: 5783.92
# [4320]	training's rmse: 4442.81	valid_1's rmse: 5782.7
# [4330]	training's rmse: 4440.23	valid_1's rmse: 5780.94
# [4340]	training's rmse: 4437.64	valid_1's rmse: 5780.38
# [4350]	training's rmse: 4435.13	valid_1's rmse: 5778.02
# [4360]	training's rmse: 4432.18	valid_1's rmse: 5778.48
# [4370]	training's rmse: 4429.64	valid_1's rmse: 5776.59
# [4380]	training's rmse: 4427.24	valid_1's rmse: 5775.95
# [4390]	training's rmse: 4424.69	valid_1's rmse: 5774.73
# [4400]	training's rmse: 4422.05	valid_1's rmse: 5774.94
# [4410]	training's rmse: 4419.96	valid_1's rmse: 5773.82
# [4420]	training's rmse: 4417.35	valid_1's rmse: 5773.05
# [4430]	training's rmse: 4414.85	valid_1's rmse: 5771.86
# [4440]	training's rmse: 4412.11	valid_1's rmse: 5770.86
# [4450]	training's rmse: 4409.62	valid_1's rmse: 5770.36
# [4460]	training's rmse: 4406.45	valid_1's rmse: 5770.5
# [4470]	training's rmse: 4403.86	valid_1's rmse: 5768.99
# [4480]	training's rmse: 4401.4	valid_1's rmse: 5768.89
# [4490]	training's rmse: 4399.07	valid_1's rmse: 5767.68
# [4500]	training's rmse: 4396.7	valid_1's rmse: 5765.83
# [4510]	training's rmse: 4393.88	valid_1's rmse: 5765.04
# [4520]	training's rmse: 4391.26	valid_1's rmse: 5763.11
# [4530]	training's rmse: 4388.91	valid_1's rmse: 5760.96
# [4540]	training's rmse: 4386.65	valid_1's rmse: 5759.24
# [4550]	training's rmse: 4384.14	valid_1's rmse: 5758.32
# [4560]	training's rmse: 4381.52	valid_1's rmse: 5757.19
# [4570]	training's rmse: 4378.87	valid_1's rmse: 5756.41
# [4580]	training's rmse: 4376.76	valid_1's rmse: 5756.26
# [4590]	training's rmse: 4374.21	valid_1's rmse: 5754.93
# [4600]	training's rmse: 4372	valid_1's rmse: 5755.16
# [4610]	training's rmse: 4369.13	valid_1's rmse: 5754.55
# [4620]	training's rmse: 4366.39	valid_1's rmse: 5754.22
# [4630]	training's rmse: 4364.19	valid_1's rmse: 5753.03
# [4640]	training's rmse: 4361.78	valid_1's rmse: 5752.25
# [4650]	training's rmse: 4359.44	valid_1's rmse: 5751.9
# [4660]	training's rmse: 4357.23	valid_1's rmse: 5750.29
# [4670]	training's rmse: 4354.7	valid_1's rmse: 5750.23
# [4680]	training's rmse: 4352.26	valid_1's rmse: 5749.06
# [4690]	training's rmse: 4350.3	valid_1's rmse: 5748.4
# [4700]	training's rmse: 4348.38	valid_1's rmse: 5747.23
# [4710]	training's rmse: 4346.31	valid_1's rmse: 5746.44
# [4720]	training's rmse: 4344.22	valid_1's rmse: 5746.46
# [4730]	training's rmse: 4341.67	valid_1's rmse: 5745.09
# [4740]	training's rmse: 4339.08	valid_1's rmse: 5744.33
# [4750]	training's rmse: 4336.17	valid_1's rmse: 5743.58
# [4760]	training's rmse: 4334.12	valid_1's rmse: 5742.58
# [4770]	training's rmse: 4331.75	valid_1's rmse: 5741.9
# [4780]	training's rmse: 4329.9	valid_1's rmse: 5741.22
# [4790]	training's rmse: 4327.09	valid_1's rmse: 5738.47
# [4800]	training's rmse: 4324.47	valid_1's rmse: 5738.09
# [4810]	training's rmse: 4321.79	valid_1's rmse: 5736.79
# [4820]	training's rmse: 4319.54	valid_1's rmse: 5735.58
# [4830]	training's rmse: 4317.56	valid_1's rmse: 5734.56
# [4840]	training's rmse: 4315.53	valid_1's rmse: 5733.82
# [4850]	training's rmse: 4313.55	valid_1's rmse: 5732.25
# [4860]	training's rmse: 4311.67	valid_1's rmse: 5731.34
# [4870]	training's rmse: 4309.7	valid_1's rmse: 5730.37
# [4880]	training's rmse: 4307.18	valid_1's rmse: 5730.11
# [4890]	training's rmse: 4305.14	valid_1's rmse: 5730.06
# [4900]	training's rmse: 4302.92	valid_1's rmse: 5729.34
# [4910]	training's rmse: 4300.07	valid_1's rmse: 5728.85
# [4920]	training's rmse: 4298.38	valid_1's rmse: 5728.34
# [4930]	training's rmse: 4296.56	valid_1's rmse: 5728.23
# [4940]	training's rmse: 4294.8	valid_1's rmse: 5727.59
# [4950]	training's rmse: 4292.42	valid_1's rmse: 5727.23
# [4960]	training's rmse: 4290.62	valid_1's rmse: 5726.65
# [4970]	training's rmse: 4288.77	valid_1's rmse: 5725.55
# [4980]	training's rmse: 4286.65	valid_1's rmse: 5724.67
# [4990]	training's rmse: 4283.73	valid_1's rmse: 5723.99
# [5000]	training's rmse: 4281.94	valid_1's rmse: 5723.47
# [5010]	training's rmse: 4279.91	valid_1's rmse: 5722.4
# [5020]	training's rmse: 4277.72	valid_1's rmse: 5721.93
# [5030]	training's rmse: 4275.81	valid_1's rmse: 5721.23
# [5040]	training's rmse: 4274.03	valid_1's rmse: 5720.72
# [5050]	training's rmse: 4271.85	valid_1's rmse: 5719.71
# [5060]	training's rmse: 4269.53	valid_1's rmse: 5717.58
# [5070]	training's rmse: 4267.72	valid_1's rmse: 5716.73
# [5080]	training's rmse: 4265.49	valid_1's rmse: 5715.47
# [5090]	training's rmse: 4263.44	valid_1's rmse: 5715.1
# [5100]	training's rmse: 4261.56	valid_1's rmse: 5713.92
# [5110]	training's rmse: 4259.71	valid_1's rmse: 5713.76
# [5120]	training's rmse: 4257.42	valid_1's rmse: 5713.18
# [5130]	training's rmse: 4255.03	valid_1's rmse: 5710.79
# [5140]	training's rmse: 4252.99	valid_1's rmse: 5709.44
# [5150]	training's rmse: 4250.84	valid_1's rmse: 5709.31
# [5160]	training's rmse: 4249.08	valid_1's rmse: 5708.01
# [5170]	training's rmse: 4246.9	valid_1's rmse: 5706.62
# [5180]	training's rmse: 4244.75	valid_1's rmse: 5705.84
# [5190]	training's rmse: 4242.52	valid_1's rmse: 5704.72
# [5200]	training's rmse: 4240.79	valid_1's rmse: 5704.5
# [5210]	training's rmse: 4238.37	valid_1's rmse: 5703.42
# [5220]	training's rmse: 4235.93	valid_1's rmse: 5703.53
# [5230]	training's rmse: 4233.01	valid_1's rmse: 5702.75
# [5240]	training's rmse: 4231.08	valid_1's rmse: 5701.17
# [5250]	training's rmse: 4229.1	valid_1's rmse: 5700.71
# [5260]	training's rmse: 4227.48	valid_1's rmse: 5700.57
# [5270]	training's rmse: 4225.38	valid_1's rmse: 5700.14
# [5280]	training's rmse: 4223.38	valid_1's rmse: 5699.66
# [5290]	training's rmse: 4221.27	valid_1's rmse: 5699.5
# [5300]	training's rmse: 4218.08	valid_1's rmse: 5697.75
# [5310]	training's rmse: 4216.15	valid_1's rmse: 5697.02
# [5320]	training's rmse: 4214.03	valid_1's rmse: 5696.36
# [5330]	training's rmse: 4212.08	valid_1's rmse: 5697.41
# [5340]	training's rmse: 4209.98	valid_1's rmse: 5696.64
# [5350]	training's rmse: 4208.23	valid_1's rmse: 5696.01
# [5360]	training's rmse: 4206.12	valid_1's rmse: 5695.42
# [5370]	training's rmse: 4203.96	valid_1's rmse: 5695.66
# [5380]	training's rmse: 4201.86	valid_1's rmse: 5695.73
# [5390]	training's rmse: 4199.27	valid_1's rmse: 5695.13
# [5400]	training's rmse: 4197.14	valid_1's rmse: 5694.52
# [5410]	training's rmse: 4194.59	valid_1's rmse: 5694.05
# [5420]	training's rmse: 4192.4	valid_1's rmse: 5692.65
# [5430]	training's rmse: 4190.73	valid_1's rmse: 5692.6
# [5440]	training's rmse: 4188.76	valid_1's rmse: 5691.36
# [5450]	training's rmse: 4186.61	valid_1's rmse: 5690.45
# [5460]	training's rmse: 4184.54	valid_1's rmse: 5689.81
# [5470]	training's rmse: 4182.47	valid_1's rmse: 5689.25
# [5480]	training's rmse: 4180.65	valid_1's rmse: 5688.91
# [5490]	training's rmse: 4178.73	valid_1's rmse: 5688.14
# [5500]	training's rmse: 4176.97	valid_1's rmse: 5688.39
# [5510]	training's rmse: 4174.49	valid_1's rmse: 5687.05
# [5520]	training's rmse: 4172.26	valid_1's rmse: 5687.03
# [5530]	training's rmse: 4170.52	valid_1's rmse: 5686.34
# [5540]	training's rmse: 4168.64	valid_1's rmse: 5685.49
# [5550]	training's rmse: 4166.47	valid_1's rmse: 5684.58
# [5560]	training's rmse: 4164.76	valid_1's rmse: 5684.16
# [5570]	training's rmse: 4163.03	valid_1's rmse: 5683.64
# [5580]	training's rmse: 4161.08	valid_1's rmse: 5683.26
# [5590]	training's rmse: 4158.94	valid_1's rmse: 5681.68
# [5600]	training's rmse: 4157.07	valid_1's rmse: 5680.68
# [5610]	training's rmse: 4155.34	valid_1's rmse: 5679.92
# [5620]	training's rmse: 4153.14	valid_1's rmse: 5678.93
# [5630]	training's rmse: 4151.41	valid_1's rmse: 5678.37
# [5640]	training's rmse: 4149.8	valid_1's rmse: 5677.97
# [5650]	training's rmse: 4148.04	valid_1's rmse: 5678.13
# [5660]	training's rmse: 4146.2	valid_1's rmse: 5677.54
# [5670]	training's rmse: 4144.56	valid_1's rmse: 5676.89
# [5680]	training's rmse: 4142.54	valid_1's rmse: 5675.51
# [5690]	training's rmse: 4140.66	valid_1's rmse: 5674.79
# [5700]	training's rmse: 4138.53	valid_1's rmse: 5673.32
# [5710]	training's rmse: 4136.47	valid_1's rmse: 5672.36
# [5720]	training's rmse: 4134.51	valid_1's rmse: 5672.16
# [5730]	training's rmse: 4132.46	valid_1's rmse: 5671.83
# [5740]	training's rmse: 4130.91	valid_1's rmse: 5671.17
# [5750]	training's rmse: 4128.82	valid_1's rmse: 5671.39
# [5760]	training's rmse: 4127.45	valid_1's rmse: 5671.09
# [5770]	training's rmse: 4124.96	valid_1's rmse: 5669.75
# [5780]	training's rmse: 4123.53	valid_1's rmse: 5669.17
# [5790]	training's rmse: 4121.82	valid_1's rmse: 5668.6
# [5800]	training's rmse: 4119.94	valid_1's rmse: 5668.19
# [5810]	training's rmse: 4118.36	valid_1's rmse: 5667.75
# [5820]	training's rmse: 4116.7	valid_1's rmse: 5667.1
# [5830]	training's rmse: 4115.13	valid_1's rmse: 5666.6
# [5840]	training's rmse: 4113.49	valid_1's rmse: 5665.51
# [5850]	training's rmse: 4111.66	valid_1's rmse: 5666.15
# [5860]	training's rmse: 4110	valid_1's rmse: 5665.5
# [5870]	training's rmse: 4108.07	valid_1's rmse: 5664.79
# [5880]	training's rmse: 4106.23	valid_1's rmse: 5664.92
# [5890]	training's rmse: 4104.75	valid_1's rmse: 5664.14
# [5900]	training's rmse: 4102.27	valid_1's rmse: 5662.39
# [5910]	training's rmse: 4100.66	valid_1's rmse: 5661.29
# [5920]	training's rmse: 4098.94	valid_1's rmse: 5661.05
# [5930]	training's rmse: 4097.37	valid_1's rmse: 5660.01
# [5940]	training's rmse: 4095.9	valid_1's rmse: 5659.63
# [5950]	training's rmse: 4094.25	valid_1's rmse: 5658.99
# [5960]	training's rmse: 4092.85	valid_1's rmse: 5658.5
# [5970]	training's rmse: 4091.38	valid_1's rmse: 5659.06
# [5980]	training's rmse: 4089.77	valid_1's rmse: 5658.33
# [5990]	training's rmse: 4088.21	valid_1's rmse: 5656.95
# [6000]	training's rmse: 4086.5	valid_1's rmse: 5656.42
# [6010]	training's rmse: 4084.79	valid_1's rmse: 5655.87
# [6020]	training's rmse: 4083.37	valid_1's rmse: 5655.8
# [6030]	training's rmse: 4081.65	valid_1's rmse: 5655.32
# [6040]	training's rmse: 4079.9	valid_1's rmse: 5654.75
# [6050]	training's rmse: 4077.93	valid_1's rmse: 5654.08
# [6060]	training's rmse: 4076.33	valid_1's rmse: 5653.55
# [6070]	training's rmse: 4074.61	valid_1's rmse: 5652.81
# [6080]	training's rmse: 4072.93	valid_1's rmse: 5651.53
# [6090]	training's rmse: 4071.48	valid_1's rmse: 5650.86
# [6100]	training's rmse: 4069.58	valid_1's rmse: 5651
# [6110]	training's rmse: 4067.56	valid_1's rmse: 5650.71
# [6120]	training's rmse: 4065.68	valid_1's rmse: 5650.38
# [6130]	training's rmse: 4064.09	valid_1's rmse: 5648.96
# [6140]	training's rmse: 4062.77	valid_1's rmse: 5648.71
# [6150]	training's rmse: 4061.05	valid_1's rmse: 5648.77
# [6160]	training's rmse: 4059.18	valid_1's rmse: 5648.05
# [6170]	training's rmse: 4057.62	valid_1's rmse: 5647.47
# [6180]	training's rmse: 4055.91	valid_1's rmse: 5647.2
# [6190]	training's rmse: 4054.16	valid_1's rmse: 5646.38
# [6200]	training's rmse: 4052.59	valid_1's rmse: 5645.5
# [6210]	training's rmse: 4050.97	valid_1's rmse: 5644.62
# [6220]	training's rmse: 4049.62	valid_1's rmse: 5644.16
# [6230]	training's rmse: 4048.02	valid_1's rmse: 5643.54
# [6240]	training's rmse: 4046.24	valid_1's rmse: 5642.55
# [6250]	training's rmse: 4044.83	valid_1's rmse: 5641.93
# [6260]	training's rmse: 4042.97	valid_1's rmse: 5641.1
# [6270]	training's rmse: 4041.16	valid_1's rmse: 5640.3
# [6280]	training's rmse: 4039.62	valid_1's rmse: 5639.28
# [6290]	training's rmse: 4038.16	valid_1's rmse: 5638.99
# [6300]	training's rmse: 4036.71	valid_1's rmse: 5638.5
# [6310]	training's rmse: 4035.1	valid_1's rmse: 5638.4
# [6320]	training's rmse: 4033.4	valid_1's rmse: 5637.64
# [6330]	training's rmse: 4031.99	valid_1's rmse: 5636.85
# [6340]	training's rmse: 4029.39	valid_1's rmse: 5635.03
# [6350]	training's rmse: 4027.57	valid_1's rmse: 5634.29
# [6360]	training's rmse: 4025.93	valid_1's rmse: 5632.8
# [6370]	training's rmse: 4024.14	valid_1's rmse: 5631.84
# [6380]	training's rmse: 4022.3	valid_1's rmse: 5630.18
# [6390]	training's rmse: 4020.46	valid_1's rmse: 5629.75
# [6400]	training's rmse: 4018.86	valid_1's rmse: 5629.21
# [6410]	training's rmse: 4016.96	valid_1's rmse: 5627.91
# [6420]	training's rmse: 4015.13	valid_1's rmse: 5627.95
# [6430]	training's rmse: 4013.86	valid_1's rmse: 5627.32
# [6440]	training's rmse: 4012.17	valid_1's rmse: 5627.09
# [6450]	training's rmse: 4010.59	valid_1's rmse: 5626.27
# [6460]	training's rmse: 4009	valid_1's rmse: 5626
# [6470]	training's rmse: 4007.23	valid_1's rmse: 5625.17
# [6480]	training's rmse: 4005.49	valid_1's rmse: 5624.54
# [6490]	training's rmse: 4003.75	valid_1's rmse: 5623.99
# [6500]	training's rmse: 4002.05	valid_1's rmse: 5624
# [6510]	training's rmse: 4000.34	valid_1's rmse: 5623.73
# [6520]	training's rmse: 3999.04	valid_1's rmse: 5623.32
# [6530]	training's rmse: 3997.42	valid_1's rmse: 5622.77
# [6540]	training's rmse: 3995.74	valid_1's rmse: 5622.6
# [6550]	training's rmse: 3994.2	valid_1's rmse: 5622.38
# [6560]	training's rmse: 3992.69	valid_1's rmse: 5621.25
# [6570]	training's rmse: 3991.11	valid_1's rmse: 5620.64
# [6580]	training's rmse: 3989.26	valid_1's rmse: 5620.48
# [6590]	training's rmse: 3986.67	valid_1's rmse: 5617.84
# [6600]	training's rmse: 3985.05	valid_1's rmse: 5617.86
# [6610]	training's rmse: 3983.59	valid_1's rmse: 5617.94
# [6620]	training's rmse: 3982.16	valid_1's rmse: 5617.35
# [6630]	training's rmse: 3980.71	valid_1's rmse: 5616.62
# [6640]	training's rmse: 3979.3	valid_1's rmse: 5616.46
# [6650]	training's rmse: 3977.77	valid_1's rmse: 5616.47
# [6660]	training's rmse: 3976.51	valid_1's rmse: 5615.78
# [6670]	training's rmse: 3974.9	valid_1's rmse: 5612.51
# [6680]	training's rmse: 3973.17	valid_1's rmse: 5613.05
# [6690]	training's rmse: 3971.9	valid_1's rmse: 5612.6
# [6700]	training's rmse: 3970.53	valid_1's rmse: 5612.17
# [6710]	training's rmse: 3969.21	valid_1's rmse: 5611.95
# [6720]	training's rmse: 3967.71	valid_1's rmse: 5611.33
# [6730]	training's rmse: 3966.25	valid_1's rmse: 5611.43
# [6740]	training's rmse: 3964.72	valid_1's rmse: 5610.97
# [6750]	training's rmse: 3963.45	valid_1's rmse: 5610.51
# [6760]	training's rmse: 3961.77	valid_1's rmse: 5610.22
# [6770]	training's rmse: 3960.22	valid_1's rmse: 5610.19
# [6780]	training's rmse: 3958.77	valid_1's rmse: 5609.65
# [6790]	training's rmse: 3957.09	valid_1's rmse: 5609.39
# [6800]	training's rmse: 3955.69	valid_1's rmse: 5608.58
# [6810]	training's rmse: 3954.01	valid_1's rmse: 5608.12
# [6820]	training's rmse: 3952.39	valid_1's rmse: 5607.75
# [6830]	training's rmse: 3950.98	valid_1's rmse: 5607.49
# [6840]	training's rmse: 3949.72	valid_1's rmse: 5607.24
# [6850]	training's rmse: 3948.26	valid_1's rmse: 5607.47
# [6860]	training's rmse: 3946.72	valid_1's rmse: 5607.01
# [6870]	training's rmse: 3944.51	valid_1's rmse: 5605.96
# [6880]	training's rmse: 3942.81	valid_1's rmse: 5605.53
# [6890]	training's rmse: 3941.28	valid_1's rmse: 5604.67
# [6900]	training's rmse: 3939.64	valid_1's rmse: 5604.5
# [6910]	training's rmse: 3938.03	valid_1's rmse: 5603.77
# [6920]	training's rmse: 3936.73	valid_1's rmse: 5603.33
# [6930]	training's rmse: 3934.95	valid_1's rmse: 5601.29
# [6940]	training's rmse: 3933.56	valid_1's rmse: 5601.16
# [6950]	training's rmse: 3932.21	valid_1's rmse: 5600.83
# [6960]	training's rmse: 3930.83	valid_1's rmse: 5600.74
# [6970]	training's rmse: 3929.56	valid_1's rmse: 5600.47
# [6980]	training's rmse: 3928.37	valid_1's rmse: 5600.39
# [6990]	training's rmse: 3926.95	valid_1's rmse: 5599.87
# [7000]	training's rmse: 3925.63	valid_1's rmse: 5599.3
# [7010]	training's rmse: 3924.56	valid_1's rmse: 5598.9
# [7020]	training's rmse: 3923.1	valid_1's rmse: 5598.02
# [7030]	training's rmse: 3921.91	valid_1's rmse: 5597.82
# [7040]	training's rmse: 3920.8	valid_1's rmse: 5597.67
# [7050]	training's rmse: 3919.59	valid_1's rmse: 5597.96
# [7060]	training's rmse: 3918.14	valid_1's rmse: 5598.36
# [7070]	training's rmse: 3916.83	valid_1's rmse: 5597.92
# [7080]	training's rmse: 3915.45	valid_1's rmse: 5598.16
# [7090]	training's rmse: 3914.07	valid_1's rmse: 5598.21
# [7100]	training's rmse: 3912.83	valid_1's rmse: 5597.22
# [7110]	training's rmse: 3911.65	valid_1's rmse: 5597.05
# [7120]	training's rmse: 3910.23	valid_1's rmse: 5596.73
# [7130]	training's rmse: 3908.88	valid_1's rmse: 5597.06
# [7140]	training's rmse: 3907.5	valid_1's rmse: 5597.07
# [7150]	training's rmse: 3906.08	valid_1's rmse: 5597.13
# [7160]	training's rmse: 3904.79	valid_1's rmse: 5596.43
# [7170]	training's rmse: 3903.34	valid_1's rmse: 5595.67
# [7180]	training's rmse: 3901.62	valid_1's rmse: 5596.05
# [7190]	training's rmse: 3900.19	valid_1's rmse: 5596.13
# [7200]	training's rmse: 3898.69	valid_1's rmse: 5595.62
# [7210]	training's rmse: 3896.59	valid_1's rmse: 5595.43
# [7220]	training's rmse: 3895.32	valid_1's rmse: 5594.62
# [7230]	training's rmse: 3893.82	valid_1's rmse: 5594.77
# [7240]	training's rmse: 3892.55	valid_1's rmse: 5594.46
# [7250]	training's rmse: 3891.31	valid_1's rmse: 5593.76
# [7260]	training's rmse: 3889.96	valid_1's rmse: 5593.88
# [7270]	training's rmse: 3888.28	valid_1's rmse: 5593.67
# [7280]	training's rmse: 3886.92	valid_1's rmse: 5592.88
# [7290]	training's rmse: 3885.19	valid_1's rmse: 5593.46
# [7300]	training's rmse: 3883.83	valid_1's rmse: 5593.1
# [7310]	training's rmse: 3882.75	valid_1's rmse: 5593.17
# [7320]	training's rmse: 3881.26	valid_1's rmse: 5594.21
# [7330]	training's rmse: 3879.78	valid_1's rmse: 5594.07
# [7340]	training's rmse: 3878.51	valid_1's rmse: 5593.61
# Early stopping, best iteration is:
# [7282]	training's rmse: 3886.56	valid_1's rmse: 5592.78
# LGBMRegressor(data_sample_strategy='goss', metric='rmse', n_estimators=100000)

# %% [markdown]
# ### 30억 이상

# %%
train_X_2, valid_X_2, train_y_2, valid_y_2 = train_test_split(X_2, y_2, train_size=0.95, test_size=0.05, random_state=74)

# %%
params = {
    'n_estimators': 100000,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'metric_freq': 20,
    'device': 'gpu',
    'verbosity': 0
}

model_2 = lgb.LGBMRegressor(n_estimators=100000,
                          metric='rmse', data_sample_strategy='goss'
                          )

model_2.fit(
    train_X_2, train_y_2,
    eval_set = [(train_X_2, train_y_2), (valid_X_2, valid_y_2)],
    eval_metric='rmse',
    callbacks=[lgb.early_stopping(stopping_rounds=90),
               lgb.log_evaluation(period=10, show_stdv=True)]
)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000424 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2441
# [LightGBM] [Info] Number of data points in the train set: 4703, number of used features: 24
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 389272.251967
# Training until validation scores don't improve for 90 rounds
# [10]	training's rmse: 62148.1	valid_1's rmse: 72386.9
# [20]	training's rmse: 46172.1	valid_1's rmse: 56977
# [30]	training's rmse: 38664.5	valid_1's rmse: 50123.8
# [40]	training's rmse: 34790.4	valid_1's rmse: 46042.8
# [50]	training's rmse: 32342.1	valid_1's rmse: 44317
# [60]	training's rmse: 30537.9	valid_1's rmse: 43445.1
# [70]	training's rmse: 29109.8	valid_1's rmse: 42666.4
# [80]	training's rmse: 27809.1	valid_1's rmse: 42173.9
# [90]	training's rmse: 26766.5	valid_1's rmse: 41818.3
# [100]	training's rmse: 25770.7	valid_1's rmse: 41600.7
# [110]	training's rmse: 25003.2	valid_1's rmse: 41295.9
# [120]	training's rmse: 24228.1	valid_1's rmse: 41321.6
# [130]	training's rmse: 23585.6	valid_1's rmse: 41245.8
# [140]	training's rmse: 22919	valid_1's rmse: 41126.8
# [150]	training's rmse: 22402.1	valid_1's rmse: 41018
# [160]	training's rmse: 21824.9	valid_1's rmse: 40761.1
# [170]	training's rmse: 21365.8	valid_1's rmse: 40616.2
# [180]	training's rmse: 20921.4	valid_1's rmse: 40451.7
# [190]	training's rmse: 20527.2	valid_1's rmse: 40373.8
# [200]	training's rmse: 20142.1	valid_1's rmse: 40479.9
# [210]	training's rmse: 19734.8	valid_1's rmse: 40468.1
# [220]	training's rmse: 19390.6	valid_1's rmse: 40461.8
# [230]	training's rmse: 19033	valid_1's rmse: 40211.6
# [240]	training's rmse: 18725.4	valid_1's rmse: 40213.3
# [250]	training's rmse: 18405.6	valid_1's rmse: 40159.8
# [260]	training's rmse: 18105.4	valid_1's rmse: 40190.1
# [270]	training's rmse: 17814.5	valid_1's rmse: 40308.2
# [280]	training's rmse: 17549.4	valid_1's rmse: 40248
# [290]	training's rmse: 17292.3	valid_1's rmse: 40161.9
# [300]	training's rmse: 17038.6	valid_1's rmse: 40192.6
# [310]	training's rmse: 16811.6	valid_1's rmse: 40189.3
# [320]	training's rmse: 16562.6	valid_1's rmse: 40160.2
# [330]	training's rmse: 16331.8	valid_1's rmse: 40177.3
# [340]	training's rmse: 16117.5	valid_1's rmse: 40109.3
# [350]	training's rmse: 15896	valid_1's rmse: 39977
# [360]	training's rmse: 15691.9	valid_1's rmse: 39956.5
# [370]	training's rmse: 15492.8	valid_1's rmse: 40048.1
# [380]	training's rmse: 15297.9	valid_1's rmse: 39977.3
# [390]	training's rmse: 15107	valid_1's rmse: 39880
# [400]	training's rmse: 14912.4	valid_1's rmse: 39787.1
# [410]	training's rmse: 14738.5	valid_1's rmse: 39721.8
# [420]	training's rmse: 14543.6	valid_1's rmse: 39706.7
# [430]	training's rmse: 14374.8	valid_1's rmse: 39672.4
# [440]	training's rmse: 14211.1	valid_1's rmse: 39623.1
# [450]	training's rmse: 14077.4	valid_1's rmse: 39619.9
# [460]	training's rmse: 13942.2	valid_1's rmse: 39415.9
# [470]	training's rmse: 13801.9	valid_1's rmse: 39430.5
# [480]	training's rmse: 13664.9	valid_1's rmse: 39366.6
# [490]	training's rmse: 13544.1	valid_1's rmse: 39388.8
# [500]	training's rmse: 13405.7	valid_1's rmse: 39329.2
# [510]	training's rmse: 13274.7	valid_1's rmse: 39333.4
# [520]	training's rmse: 13134.6	valid_1's rmse: 39370
# [530]	training's rmse: 13002.5	valid_1's rmse: 39374.6
# [540]	training's rmse: 12878.8	valid_1's rmse: 39360.7
# [550]	training's rmse: 12769.1	valid_1's rmse: 39370.4
# [560]	training's rmse: 12642.5	valid_1's rmse: 39294.7
# [570]	training's rmse: 12523.8	valid_1's rmse: 39192.3
# [580]	training's rmse: 12428.8	valid_1's rmse: 39165.3
# [590]	training's rmse: 12329.6	valid_1's rmse: 39102
# [600]	training's rmse: 12230.9	valid_1's rmse: 39148.2
# [610]	training's rmse: 12117.4	valid_1's rmse: 39142
# [620]	training's rmse: 12018.1	valid_1's rmse: 39113.7
# [630]	training's rmse: 11911	valid_1's rmse: 39322.1
# [640]	training's rmse: 11814.7	valid_1's rmse: 39355.1
# [650]	training's rmse: 11721.4	valid_1's rmse: 39328.7
# [660]	training's rmse: 11630.1	valid_1's rmse: 39276.2
# [670]	training's rmse: 11536.5	valid_1's rmse: 39287.5
# Early stopping, best iteration is:
# [586]	training's rmse: 12375.3	valid_1's rmse: 39064.2
# LGBMRegressor(data_sample_strategy='goss', metric='rmse', n_estimators=100000)

# %%
valid_X_2.shape
# Out:
# (248, 24)

# %%
preds_1 = model_1.predict(test_df_dropped)

# %%
preds_2 = model_2.predict(test_df_dropped)

# %%
preds_1
# Out:
# array([187367.39534053, 301817.77561001, 345225.44560216, ...,
#         80885.08856464,  74841.30189952,  72799.11421885])

# %%
preds_2
# Out:
# array([276729.14655557, 363433.80153425, 354964.35626491, ...,
#        246924.8924215 , 234714.02040978, 237670.87017157])

# %%
preds_1 = np.round(preds_1).astype(int)
preds_2 = np.round(preds_2).astype(int)

# %%
joblib.dump(model_1, './v_32_5_1.pkl')
joblib.dump(model_2, './v_32_5_2.pkl')
# Out:
# ['./v_32_5_2.pkl']

# %%
preds_1_df = pd.DataFrame(preds_1, columns=['target'])
preds_2_df = pd.DataFrame(preds_2, columns=['target'])

preds_1_df.to_csv('../preds/v_32_5_1_preds.csv', index=False)
preds_2_df.to_csv('../preds/v_32_5_2_preds.csv', index=False)
