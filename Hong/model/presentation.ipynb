# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import gc

from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error

import lightgbm as lgb

import joblib

# 맥에서 글씨 깨짐 방지
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 12.0.1. Please consider upgrading.
#   warnings.warn(

# %% [markdown]
# # data preprocess

# %%
df = pd.read_csv('../data/preprocessed/34_apart_price_mean.csv')
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_48363/3919769212.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/preprocessed/34_apart_price_mean.csv')

# %%
df.shape
# Out:
# (1128094, 105)

# %%
# 일부 feature 제거 - 기준은 내마음대로

df.drop(['해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)', 'k-전화번호',
         'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-복도유형', 'k-난방방식', 'k-전체동수', 'k-전체세대수',
         'k-사용검사일-사용승인일', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)', 'k-전용면적별세대현황(60~85이하)',
         'k-85~135이하', 'k-135초과', 'k-홈페이지', 'k-등록일자', 'k-수정일자', '고용보험관리번호', '경비비관리형태',
         '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드', '단지신청일'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도',
#        '도로명', 'k-관리방식', 'k-건설사(시공사)', 'k-시행사', 'k-연면적', 'k-주거전용면적', '세대전기계약방법',
#        '청소비관리형태', '건축면적', '주차대수', '좌표X', '좌표Y', 'target', 'is_test', '시군구 번지',
#        '좌표X,좌표Y', '가장 가까운 거리', 'index', '역사_ID', '역사명', '호선', '위도', '경도',
#        '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '가장 가까운 버스 정류장 index',
#        '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호', '가장 가까운 버스 정류소명',
#        '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표', '가장 가까운 버스 정류장 Y좌표',
#        '인근 버스 정류장 개수', '계약년', '계약월', 'GDP', '한국은행 기준금리', '기대 인플레이션', '지가지수',
#        '아파트 인허가', '미분양', '거래량', '건설사 랭킹', '구', '동', '구별 지가지수', '공시지가 평균',
#        '매수우위지수', '건물나이', '30년이상50년이하', '구매력지수', '거래활발지수', '매매가격 지수 증감률',
#        '매매 대비 전세가격 비율', '아파트 카테고리', '지하철 카테고리', '구 카테고리', '건설사 카테고리',
#        '가장 가까운 다리와의 거리', '가장 가까운 다리 index', '가장 가까운 다리', '인근 한강다리 개수',
#        '인근 다리 개수 1개이상 3개 이하', '학군', '매매가격 지수', '아파트 평균 가격'],
#       dtype='object')

# %%
# 추가로 제거가 필요한 feature 제거
df.drop(['시군구', '번지', '본번', '부번', '아파트명', '도로명', 'k-관리방식', 'k-건설사(시공사)', 'k-시행사', 'k-연면적', 'k-주거전용면적',
         '세대전기계약방법', '청소비관리형태', '건축면적', '주차대수', '시군구 번지', '좌표X,좌표Y', 'index', '역사_ID', '역사명', '위도', '경도',
         '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호', '가장 가까운 버스 정류소명',
         '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표', '가장 가까운 버스 정류장 Y좌표', '동', 
         '구', '호선'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['전용면적', '계약년월', '계약일', '층', '건축년도', '좌표X', '좌표Y', 'target', 'is_test',
#        '가장 가까운 거리', '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년',
#        '계약월', 'GDP', '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양', '거래량',
#        '건설사 랭킹', '구별 지가지수', '공시지가 평균', '매수우위지수', '건물나이', '30년이상50년이하', '구매력지수',
#        '거래활발지수', '매매가격 지수 증감률', '매매 대비 전세가격 비율', '아파트 카테고리', '지하철 카테고리',
#        '구 카테고리', '건설사 카테고리', '가장 가까운 다리와의 거리', '가장 가까운 다리 index', '가장 가까운 다리',
#        '인근 한강다리 개수', '인근 다리 개수 1개이상 3개 이하', '학군', '매매가격 지수', '아파트 평균 가격'],
#       dtype='object')

# %%
df.shape
# Out:
# (1128094, 44)

# %%
# 계약월 변수 생성
df['계약월'] = df['계약년월'].astype(str).str[4:].astype(int)

# 계약년월, 계약일, 건축년도, 계약년 변수 제거
df.drop(['계약년월', '계약일'], axis=1, inplace=True)

df['계약월_sin'] = np.sin(2 * np.pi * df['계약월'] / 12)
df.drop(['계약월'], axis=1, inplace=True)
df
# Out:
#            전용면적   층  건축년도        좌표X        좌표Y    target  is_test  \
# 0         79.97   3  1987  127.05721  37.476763  124000.0        0
# 1         79.97   4  1987  127.05721  37.476763  123500.0        0
# 2         54.98   5  1987  127.05721  37.476763   91500.0        0
# 3         79.97   4  1987  127.05721  37.476763  130000.0        0
# 4         79.97   2  1987  127.05721  37.476763  117000.0        0
# ...         ...  ..   ...        ...        ...       ...      ...
# 1128089   84.65  13  2014  127.10672  37.618870       NaN        1
# 1128090   84.62  12  2014  127.10672  37.618870       NaN        1
# 1128091  101.65  12  2014  127.10672  37.618870       NaN        1
# 1128092   84.94  18  2014  127.10672  37.618870       NaN        1
# 1128093   84.65  13  2014  127.10672  37.618870       NaN        1
#
#            가장 가까운 거리  인근 지하철 역 개수  가장 가까운 버스 정류장 거리  ...  건설사 카테고리  \
# 0        1127.738351          2.0          61.89584  ...        기타
# 1        1127.738351          2.0          61.89584  ...        기타
# 2        1127.738351          2.0          61.89584  ...        기타
# 3        1127.738351          2.0          61.89584  ...        기타
# 4        1127.738351          2.0          61.89584  ...        기타
# ...              ...          ...               ...  ...       ...
# 1128089   732.482898          4.0          59.47567  ...        기타
# 1128090   732.482898          4.0          59.47567  ...        기타
# 1128091   732.482898          4.0          59.47567  ...        기타
# 1128092   732.482898          4.0          59.47567  ...        기타
# 1128093   732.482898          4.0          59.47567  ...        기타
#
#          가장 가까운 다리와의 거리  가장 가까운 다리 index  가장 가까운 다리  인근 한강다리 개수  \
# 0           5581.622466             17.0       청담대교         0.0
# 1           5581.622466             17.0       청담대교         0.0
# 2           5581.622466             17.0       청담대교         0.0
# 3           5581.622466             17.0       청담대교         0.0
# 4           5581.622466             17.0       청담대교         0.0
# ...                 ...              ...        ...         ...
# 1128089     5918.624352             23.0     구리암사대교         0.0
# 1128090     5918.624352             23.0     구리암사대교         0.0
# 1128091     5918.624352             23.0     구리암사대교         0.0
# 1128092     5918.624352             23.0     구리암사대교         0.0
# 1128093     5918.624352             23.0     구리암사대교         0.0
#
#          인근 다리 개수 1개이상 3개 이하   학군    매매가격 지수      아파트 평균 가격       계약월_sin
# 0                          0  8.0  67.392545  104403.465347 -2.449294e-16
# 1                          0  8.0  67.392545  104403.465347 -2.449294e-16
# 2                          0  8.0  67.392545  104403.465347 -2.449294e-16
# 3                          0  8.0  69.049924  104403.465347  5.000000e-01
# 4                          0  8.0  69.049924  104403.465347  5.000000e-01
# ...                      ...  ...        ...            ...           ...
# 1128089                    0  1.0  91.623694   40355.229672 -5.000000e-01
# 1128090                    0  1.0  91.623694   40355.229672 -5.000000e-01
# 1128091                    0  1.0  91.066919   40355.229672 -8.660254e-01
# 1128092                    0  1.0  90.861265   40355.229672 -1.000000e+00
# 1128093                    0  1.0  90.861265   40355.229672 -1.000000e+00
#
# [1128094 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', 'target', 'is_test', '가장 가까운 거리',
#        '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년', 'GDP',
#        '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양', '거래량', '건설사 랭킹',
#        '구별 지가지수', '공시지가 평균', '매수우위지수', '건물나이', '30년이상50년이하', '구매력지수', '거래활발지수',
#        '매매가격 지수 증감률', '매매 대비 전세가격 비율', '아파트 카테고리', '지하철 카테고리', '구 카테고리',
#        '건설사 카테고리', '가장 가까운 다리와의 거리', '가장 가까운 다리 index', '가장 가까운 다리',
#        '인근 한강다리 개수', '인근 다리 개수 1개이상 3개 이하', '학군', '매매가격 지수', '아파트 평균 가격',
#        '계약월_sin'],
#       dtype='object')

# %% [markdown]
# # scaling

# %%
def scailing(col, scaler_type):
    if scaler_type == 'min_max': scaler = MinMaxScaler()
    else : scaler = StandardScaler()

    return scaler.fit_transform(df[[col]])

cols = ['전용면적', '층', '건축년도', '좌표X', '좌표Y', '가장 가까운 거리',
       '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP',
       '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양', '거래량',
       '구별 지가지수', '공시지가 평균', '매수우위지수', '건물나이', '구매력지수', '거래활발지수',
       '매매가격 지수 증감률', '매매 대비 전세가격 비율', '가장 가까운 다리와의 거리', '매매가격 지수',
       '아파트 평균 가격', '계약월_sin']

for col in cols:
    print(col)
    scaler_type = 'min_max'
    if col == '계약월_sin': scaler_type = 'standard'

    df[[col]] = scailing(col, scaler_type)
# Out:
# 전용면적
# 층
# 건축년도
# 좌표X
# 좌표Y
# 가장 가까운 거리
# 인근 지하철 역 개수
# 가장 가까운 버스 정류장 거리
# 인근 버스 정류장 개수
# GDP
# 한국은행 기준금리
# 기대 인플레이션
# 지가지수
# 아파트 인허가
# 미분양
# 거래량
# 구별 지가지수
# 공시지가 평균
# 매수우위지수
# 건물나이
# 구매력지수
# 거래활발지수
# 매매가격 지수 증감률
# 매매 대비 전세가격 비율
# 가장 가까운 다리와의 거리
# 매매가격 지수
# 아파트 평균 가격
# 계약월_sin

# %%
df.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', 'target', 'is_test', '가장 가까운 거리',
#        '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년', 'GDP',
#        '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양', '거래량', '건설사 랭킹',
#        '구별 지가지수', '공시지가 평균', '매수우위지수', '건물나이', '30년이상50년이하', '구매력지수', '거래활발지수',
#        '매매가격 지수 증감률', '매매 대비 전세가격 비율', '아파트 카테고리', '지하철 카테고리', '구 카테고리',
#        '건설사 카테고리', '가장 가까운 다리와의 거리', '가장 가까운 다리 index', '가장 가까운 다리',
#        '인근 한강다리 개수', '인근 다리 개수 1개이상 3개 이하', '학군', '매매가격 지수', '아파트 평균 가격',
#        '계약월_sin'],
#       dtype='object')

# %% [markdown]
# # category

# %%
#df['30년이상50년이하'] = df['30년이상50년이하'].astype('category')
df['아파트 카테고리'] = df['아파트 카테고리'].astype('category')
df['지하철 카테고리'] = df['지하철 카테고리'].astype('category')
df['구 카테고리'] = df['구 카테고리'].astype('category')
df['건설사 카테고리'] = df['건설사 카테고리'].astype('category')
df['인근 다리 개수 1개이상 3개 이하'] = df['인근 다리 개수 1개이상 3개 이하'].astype('category')
df['학군'] = df['학군'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128094 entries, 0 to 1128093
# Data columns (total 42 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   전용면적                 1128094 non-null  float64
#  1   층                    1128094 non-null  float64
#  2   건축년도                 1128094 non-null  float64
#  3   좌표X                  1128094 non-null  float64
#  4   좌표Y                  1128094 non-null  float64
#  5   target               1118822 non-null  float64
#  6   is_test              1128094 non-null  int64
#  7   가장 가까운 거리            1128094 non-null  float64
#  8   인근 지하철 역 개수          1128094 non-null  float64
#  9   가장 가까운 버스 정류장 거리     1128094 non-null  float64
#  10  인근 버스 정류장 개수         1128094 non-null  float64
#  11  계약년                  1128094 non-null  int64
#  12  GDP                  1128094 non-null  float64
#  13  한국은행 기준금리            1128094 non-null  float64
#  14  기대 인플레이션             1128094 non-null  float64
#  15  지가지수                 1128094 non-null  float64
#  16  아파트 인허가              1128094 non-null  float64
#  17  미분양                  1128094 non-null  float64
#  18  거래량                  1128094 non-null  float64
#  19  건설사 랭킹               1128094 non-null  float64
#  20  구별 지가지수              1128094 non-null  float64
#  21  공시지가 평균              1128094 non-null  float64
#  22  매수우위지수               1128094 non-null  float64
#  23  건물나이                 1128094 non-null  float64
#  24  30년이상50년이하           1128094 non-null  int64
#  25  구매력지수                1128094 non-null  float64
#  26  거래활발지수               1128094 non-null  float64
#  27  매매가격 지수 증감률          1128094 non-null  float64
#  28  매매 대비 전세가격 비율        1128094 non-null  float64
#  29  아파트 카테고리             1128094 non-null  category
#  30  지하철 카테고리             1128094 non-null  category
#  31  구 카테고리               1128094 non-null  category
#  32  건설사 카테고리             1128094 non-null  category
#  33  가장 가까운 다리와의 거리       1128094 non-null  float64
#  34  가장 가까운 다리 index      1128094 non-null  float64
#  35  가장 가까운 다리            1128094 non-null  object
#  36  인근 한강다리 개수           1128094 non-null  float64
#  37  인근 다리 개수 1개이상 3개 이하  1128094 non-null  category
#  38  학군                   1128094 non-null  category
#  39  매매가격 지수              1128094 non-null  float64
#  40  아파트 평균 가격            1128094 non-null  float64
#  41  계약월_sin              1128094 non-null  float64
# dtypes: category(6), float64(32), int64(3), object(1)
# memory usage: 316.3+ MB

# %% [markdown]
# # train, test dataset

# %% [markdown]
# ## feature drop

# %%
train_df = df[df['is_test']==0]
test_df = df[df['is_test']==1]

# %%
train_df.shape
# Out:
# (1118822, 42)

# %%
train_df.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', 'target', 'is_test', '가장 가까운 거리',
#        '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년', 'GDP',
#        '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양', '거래량', '건설사 랭킹',
#        '구별 지가지수', '공시지가 평균', '매수우위지수', '건물나이', '30년이상50년이하', '구매력지수', '거래활발지수',
#        '매매가격 지수 증감률', '매매 대비 전세가격 비율', '아파트 카테고리', '지하철 카테고리', '구 카테고리',
#        '건설사 카테고리', '가장 가까운 다리와의 거리', '가장 가까운 다리 index', '가장 가까운 다리',
#        '인근 한강다리 개수', '인근 다리 개수 1개이상 3개 이하', '학군', '매매가격 지수', '아파트 평균 가격',
#        '계약월_sin'],
#       dtype='object')

# %%
train_df_dropped = train_df.drop(['is_test', '지가지수', '아파트 인허가', '미분양', '건설사 랭킹',
                                  '건물나이', '구매력지수', '거래활발지수', '매매가격 지수 증감률', 
                                  '매매 대비 전세가격 비율', '구 카테고리', '건설사 카테고리', '가장 가까운 다리와의 거리',
                                  '가장 가까운 다리 index', '가장 가까운 다리', '인근 한강다리 개수', 
                                  '인근 다리 개수 1개이상 3개 이하', '학군', '매매가격 지수'], axis=1)

test_X = test_df.drop(['is_test', 'target', '지가지수', '아파트 인허가', '미분양', '건설사 랭킹',
                                '건물나이', '구매력지수', '거래활발지수', '매매가격 지수 증감률', 
                                '매매 대비 전세가격 비율', '구 카테고리', '건설사 카테고리', '가장 가까운 다리와의 거리',
                                '가장 가까운 다리 index', '가장 가까운 다리', '인근 한강다리 개수', 
                                '인근 다리 개수 1개이상 3개 이하', '학군', '매매가격 지수'], axis=1)

X = train_df_dropped.drop(['target'], axis=1)
y = train_df_dropped[['target']]

train_X, valid_X, train_y, valid_y = train_test_split(X, y, train_size=0.95, test_size=0.05, random_state=74)

train_X.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년', 'GDP', '한국은행 기준금리',
#        '기대 인플레이션', '거래량', '구별 지가지수', '공시지가 평균', '매수우위지수', '30년이상50년이하',
#        '아파트 카테고리', '지하철 카테고리', '아파트 평균 가격', '계약월_sin'],
#       dtype='object')

# %%
params = {
    'n_estimators': 100000,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'metric_freq': 20,
    'device': 'gpu',
    'verbosity': 0
}

model = lgb.LGBMRegressor(n_estimators=100000,
                          metric='rmse', data_sample_strategy='goss'
                          )

model.fit(
    train_X, train_y,
    eval_set = [(train_X, train_y), (valid_X, valid_y)],
    eval_metric='rmse',
    callbacks=[lgb.early_stopping(stopping_rounds=60),
               lgb.log_evaluation(period=10, show_stdv=True)]
)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2705
# [LightGBM] [Info] Number of data points in the train set: 1062880, number of used features: 22
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 57982.908459
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 23611.4	valid_1's rmse: 24208.7
# [20]	training's rmse: 16295.5	valid_1's rmse: 16769.1
# [30]	training's rmse: 13750.6	valid_1's rmse: 14164
# [40]	training's rmse: 12570.7	valid_1's rmse: 12986.6
# [50]	training's rmse: 11847.2	valid_1's rmse: 12237.2
# [60]	training's rmse: 11306.6	valid_1's rmse: 11687
# [70]	training's rmse: 10884.5	valid_1's rmse: 11256.6
# [80]	training's rmse: 10508.6	valid_1's rmse: 10885.2
# [90]	training's rmse: 10213.8	valid_1's rmse: 10598.6
# [100]	training's rmse: 9968.5	valid_1's rmse: 10357.7
# [110]	training's rmse: 9751.18	valid_1's rmse: 10133.2
# [120]	training's rmse: 9541.52	valid_1's rmse: 9920.99
# [130]	training's rmse: 9377.3	valid_1's rmse: 9752.15
# [140]	training's rmse: 9227.92	valid_1's rmse: 9590.68
# [150]	training's rmse: 9082.61	valid_1's rmse: 9444.59
# [160]	training's rmse: 8942.95	valid_1's rmse: 9295.16
# [170]	training's rmse: 8838.96	valid_1's rmse: 9189.12
# [180]	training's rmse: 8729.37	valid_1's rmse: 9088.63
# [190]	training's rmse: 8623.39	valid_1's rmse: 8985.93
# [200]	training's rmse: 8520.4	valid_1's rmse: 8874.49
# [210]	training's rmse: 8431.57	valid_1's rmse: 8792.45
# [220]	training's rmse: 8356.99	valid_1's rmse: 8720.67
# [230]	training's rmse: 8271.32	valid_1's rmse: 8648.01
# [240]	training's rmse: 8174.8	valid_1's rmse: 8557.92
# [250]	training's rmse: 8101.46	valid_1's rmse: 8486.08
# [260]	training's rmse: 8028.39	valid_1's rmse: 8421.03
# [270]	training's rmse: 7948.43	valid_1's rmse: 8343.36
# [280]	training's rmse: 7880.78	valid_1's rmse: 8285.88
# [290]	training's rmse: 7813.9	valid_1's rmse: 8224.29
# [300]	training's rmse: 7762.06	valid_1's rmse: 8172.7
# [310]	training's rmse: 7694.6	valid_1's rmse: 8105.49
# [320]	training's rmse: 7644.94	valid_1's rmse: 8060.53
# [330]	training's rmse: 7588.42	valid_1's rmse: 8007.98
# [340]	training's rmse: 7539	valid_1's rmse: 7965.84
# [350]	training's rmse: 7492.07	valid_1's rmse: 7924.98
# [360]	training's rmse: 7440.08	valid_1's rmse: 7877.92
# [370]	training's rmse: 7400.24	valid_1's rmse: 7840.18
# [380]	training's rmse: 7359.82	valid_1's rmse: 7804.87
# [390]	training's rmse: 7314.62	valid_1's rmse: 7764.73
# [400]	training's rmse: 7265.53	valid_1's rmse: 7716.58
# [410]	training's rmse: 7215.77	valid_1's rmse: 7672.94
# [420]	training's rmse: 7184.53	valid_1's rmse: 7648.93
# [430]	training's rmse: 7141.63	valid_1's rmse: 7612.66
# [440]	training's rmse: 7111.8	valid_1's rmse: 7595.15
# [450]	training's rmse: 7077.3	valid_1's rmse: 7561.77
# [460]	training's rmse: 7041.91	valid_1's rmse: 7530.81
# [470]	training's rmse: 7001.69	valid_1's rmse: 7501.99
# [480]	training's rmse: 6964.52	valid_1's rmse: 7471.38
# [490]	training's rmse: 6933.27	valid_1's rmse: 7450.16
# [500]	training's rmse: 6903.08	valid_1's rmse: 7424.57
# [510]	training's rmse: 6865.79	valid_1's rmse: 7393.53
# [520]	training's rmse: 6840.36	valid_1's rmse: 7371.16
# [530]	training's rmse: 6811.8	valid_1's rmse: 7344.38
# [540]	training's rmse: 6788.58	valid_1's rmse: 7328.45
# [550]	training's rmse: 6763.56	valid_1's rmse: 7304.53
# [560]	training's rmse: 6733.27	valid_1's rmse: 7277.24
# [570]	training's rmse: 6704.19	valid_1's rmse: 7252.15
# [580]	training's rmse: 6679.67	valid_1's rmse: 7231.24
# [590]	training's rmse: 6656.92	valid_1's rmse: 7209.98
# [600]	training's rmse: 6625.76	valid_1's rmse: 7183.17
# [610]	training's rmse: 6602.17	valid_1's rmse: 7157.5
# [620]	training's rmse: 6577.75	valid_1's rmse: 7135.39
# [630]	training's rmse: 6558.16	valid_1's rmse: 7120.59
# [640]	training's rmse: 6537.26	valid_1's rmse: 7102.65
# [650]	training's rmse: 6518.28	valid_1's rmse: 7088.85
# [660]	training's rmse: 6499.3	valid_1's rmse: 7076.83
# [670]	training's rmse: 6479.55	valid_1's rmse: 7061.71
# [680]	training's rmse: 6460.36	valid_1's rmse: 7047.71
# [690]	training's rmse: 6434.17	valid_1's rmse: 7025.03
# [700]	training's rmse: 6415.95	valid_1's rmse: 7009.16
# [710]	training's rmse: 6396.09	valid_1's rmse: 6992.06
# [720]	training's rmse: 6374.09	valid_1's rmse: 6976.72
# [730]	training's rmse: 6354.15	valid_1's rmse: 6961.79
# [740]	training's rmse: 6333.94	valid_1's rmse: 6940.65
# [750]	training's rmse: 6317.66	valid_1's rmse: 6928.5
# [760]	training's rmse: 6299.43	valid_1's rmse: 6910.5
# [770]	training's rmse: 6281.67	valid_1's rmse: 6898.03
# [780]	training's rmse: 6266.93	valid_1's rmse: 6889.64
# [790]	training's rmse: 6250.78	valid_1's rmse: 6876.29
# [800]	training's rmse: 6230.48	valid_1's rmse: 6860.3
# [810]	training's rmse: 6210.49	valid_1's rmse: 6842.33
# [820]	training's rmse: 6195.34	valid_1's rmse: 6825.35
# [830]	training's rmse: 6177.66	valid_1's rmse: 6813.24
# [840]	training's rmse: 6157.88	valid_1's rmse: 6795.72
# [850]	training's rmse: 6140.36	valid_1's rmse: 6782.08
# [860]	training's rmse: 6122.84	valid_1's rmse: 6768.21
# [870]	training's rmse: 6105.98	valid_1's rmse: 6756.54
# [880]	training's rmse: 6091.13	valid_1's rmse: 6746.1
# [890]	training's rmse: 6076.19	valid_1's rmse: 6734.48
# [900]	training's rmse: 6061.03	valid_1's rmse: 6720.69
# [910]	training's rmse: 6048.08	valid_1's rmse: 6711.76
# [920]	training's rmse: 6033.16	valid_1's rmse: 6697.46
# [930]	training's rmse: 6019.51	valid_1's rmse: 6686.54
# [940]	training's rmse: 6004.13	valid_1's rmse: 6674.28
# [950]	training's rmse: 5990.53	valid_1's rmse: 6664.84
# [960]	training's rmse: 5974.71	valid_1's rmse: 6650.67
# [970]	training's rmse: 5960.96	valid_1's rmse: 6640.47
# [980]	training's rmse: 5946.86	valid_1's rmse: 6633.54
# [990]	training's rmse: 5934.92	valid_1's rmse: 6624.54
# [1000]	training's rmse: 5921.59	valid_1's rmse: 6613.57
# [1010]	training's rmse: 5905.95	valid_1's rmse: 6603.5
# [1020]	training's rmse: 5892.74	valid_1's rmse: 6592.42
# [1030]	training's rmse: 5880.18	valid_1's rmse: 6581.27
# [1040]	training's rmse: 5866.59	valid_1's rmse: 6569.67
# [1050]	training's rmse: 5852.21	valid_1's rmse: 6559.29
# [1060]	training's rmse: 5841.51	valid_1's rmse: 6551.99
# [1070]	training's rmse: 5829.23	valid_1's rmse: 6540.78
# [1080]	training's rmse: 5816.79	valid_1's rmse: 6530.55
# [1090]	training's rmse: 5805.36	valid_1's rmse: 6521.89
# [1100]	training's rmse: 5794.17	valid_1's rmse: 6511.71
# [1110]	training's rmse: 5780.15	valid_1's rmse: 6500.69
# [1120]	training's rmse: 5767.43	valid_1's rmse: 6490.15
# [1130]	training's rmse: 5754.14	valid_1's rmse: 6477.71
# [1140]	training's rmse: 5743.17	valid_1's rmse: 6469.16
# [1150]	training's rmse: 5731.51	valid_1's rmse: 6461.29
# [1160]	training's rmse: 5722	valid_1's rmse: 6456.34
# [1170]	training's rmse: 5710.69	valid_1's rmse: 6449.14
# [1180]	training's rmse: 5699.04	valid_1's rmse: 6441.26
# [1190]	training's rmse: 5689.14	valid_1's rmse: 6433.95
# [1200]	training's rmse: 5680.35	valid_1's rmse: 6429.56
# [1210]	training's rmse: 5668.87	valid_1's rmse: 6421.36
# [1220]	training's rmse: 5658.39	valid_1's rmse: 6412.58
# [1230]	training's rmse: 5647.55	valid_1's rmse: 6402.21
# [1240]	training's rmse: 5637.52	valid_1's rmse: 6394.41
# [1250]	training's rmse: 5625.95	valid_1's rmse: 6386.98
# [1260]	training's rmse: 5614.55	valid_1's rmse: 6379.12
# [1270]	training's rmse: 5604.67	valid_1's rmse: 6371.59
# [1280]	training's rmse: 5595.22	valid_1's rmse: 6365.64
# [1290]	training's rmse: 5586.95	valid_1's rmse: 6360.77
# [1300]	training's rmse: 5575.19	valid_1's rmse: 6351.84
# [1310]	training's rmse: 5564.96	valid_1's rmse: 6343.32
# [1320]	training's rmse: 5556.93	valid_1's rmse: 6338.33
# [1330]	training's rmse: 5548.55	valid_1's rmse: 6333.58
# [1340]	training's rmse: 5538.23	valid_1's rmse: 6322.41
# [1350]	training's rmse: 5529.69	valid_1's rmse: 6314.72
# [1360]	training's rmse: 5522.23	valid_1's rmse: 6309.95
# [1370]	training's rmse: 5512.09	valid_1's rmse: 6304.32
# [1380]	training's rmse: 5502.14	valid_1's rmse: 6298.83
# [1390]	training's rmse: 5493.79	valid_1's rmse: 6294.75
# [1400]	training's rmse: 5483.83	valid_1's rmse: 6284.5
# [1410]	training's rmse: 5475.79	valid_1's rmse: 6280.31
# [1420]	training's rmse: 5468.17	valid_1's rmse: 6278.31
# [1430]	training's rmse: 5460.63	valid_1's rmse: 6272.65
# [1440]	training's rmse: 5450.89	valid_1's rmse: 6265.31
# [1450]	training's rmse: 5443.61	valid_1's rmse: 6264.95
# [1460]	training's rmse: 5435.12	valid_1's rmse: 6259.63
# [1470]	training's rmse: 5426.29	valid_1's rmse: 6251.55
# [1480]	training's rmse: 5416.5	valid_1's rmse: 6244.6
# [1490]	training's rmse: 5410.48	valid_1's rmse: 6242.01
# [1500]	training's rmse: 5403.24	valid_1's rmse: 6236.22
# [1510]	training's rmse: 5395.73	valid_1's rmse: 6232.63
# [1520]	training's rmse: 5386.82	valid_1's rmse: 6225.41
# [1530]	training's rmse: 5379.15	valid_1's rmse: 6221.44
# [1540]	training's rmse: 5371.41	valid_1's rmse: 6216.52
# [1550]	training's rmse: 5363.45	valid_1's rmse: 6211.44
# [1560]	training's rmse: 5355.25	valid_1's rmse: 6204.78
# [1570]	training's rmse: 5348.6	valid_1's rmse: 6202.07
# [1580]	training's rmse: 5341.28	valid_1's rmse: 6196.74
# [1590]	training's rmse: 5333.62	valid_1's rmse: 6191.85
# [1600]	training's rmse: 5325.69	valid_1's rmse: 6187.57
# [1610]	training's rmse: 5319.42	valid_1's rmse: 6184.16
# [1620]	training's rmse: 5311.97	valid_1's rmse: 6180.91
# [1630]	training's rmse: 5305.54	valid_1's rmse: 6176.45
# [1640]	training's rmse: 5299.11	valid_1's rmse: 6172.04
# [1650]	training's rmse: 5292.27	valid_1's rmse: 6168.06
# [1660]	training's rmse: 5283.46	valid_1's rmse: 6163.07
# [1670]	training's rmse: 5275.37	valid_1's rmse: 6156.21
# [1680]	training's rmse: 5269.02	valid_1's rmse: 6152.25
# [1690]	training's rmse: 5261.45	valid_1's rmse: 6145.95
# [1700]	training's rmse: 5254.27	valid_1's rmse: 6139.36
# [1710]	training's rmse: 5248.39	valid_1's rmse: 6135.95
# [1720]	training's rmse: 5241.12	valid_1's rmse: 6130.26
# [1730]	training's rmse: 5233.32	valid_1's rmse: 6128.24
# [1740]	training's rmse: 5225.33	valid_1's rmse: 6121.18
# [1750]	training's rmse: 5218.42	valid_1's rmse: 6116.74
# [1760]	training's rmse: 5210.83	valid_1's rmse: 6112.27
# [1770]	training's rmse: 5204.87	valid_1's rmse: 6107.44
# [1780]	training's rmse: 5197.84	valid_1's rmse: 6103.39
# [1790]	training's rmse: 5192.43	valid_1's rmse: 6098.08
# [1800]	training's rmse: 5186.82	valid_1's rmse: 6093.71
# [1810]	training's rmse: 5180.69	valid_1's rmse: 6089.41
# [1820]	training's rmse: 5174.14	valid_1's rmse: 6084.94
# [1830]	training's rmse: 5167.15	valid_1's rmse: 6078.51
# [1840]	training's rmse: 5160.76	valid_1's rmse: 6075.85
# [1850]	training's rmse: 5154.16	valid_1's rmse: 6070.22
# [1860]	training's rmse: 5147.67	valid_1's rmse: 6065.69
# [1870]	training's rmse: 5141.91	valid_1's rmse: 6062.54
# [1880]	training's rmse: 5135.38	valid_1's rmse: 6057.43
# [1890]	training's rmse: 5127.42	valid_1's rmse: 6048.84
# [1900]	training's rmse: 5121.58	valid_1's rmse: 6044.89
# [1910]	training's rmse: 5115.37	valid_1's rmse: 6041.04
# [1920]	training's rmse: 5109.84	valid_1's rmse: 6037.74
# [1930]	training's rmse: 5103.76	valid_1's rmse: 6034.36
# [1940]	training's rmse: 5098.24	valid_1's rmse: 6029.5
# [1950]	training's rmse: 5093.21	valid_1's rmse: 6025.4
# [1960]	training's rmse: 5087.09	valid_1's rmse: 6020.65
# [1970]	training's rmse: 5080.29	valid_1's rmse: 6018.07
# [1980]	training's rmse: 5074.73	valid_1's rmse: 6014.92
# [1990]	training's rmse: 5069.09	valid_1's rmse: 6010.95
# [2000]	training's rmse: 5063.34	valid_1's rmse: 6007.08
# [2010]	training's rmse: 5057.62	valid_1's rmse: 6005.01
# [2020]	training's rmse: 5052.39	valid_1's rmse: 6002.15
# [2030]	training's rmse: 5047.12	valid_1's rmse: 5998.07
# [2040]	training's rmse: 5041.63	valid_1's rmse: 5994.42
# [2050]	training's rmse: 5034.94	valid_1's rmse: 5990.53
# [2060]	training's rmse: 5029.09	valid_1's rmse: 5988.24
# [2070]	training's rmse: 5023.61	valid_1's rmse: 5984.4
# [2080]	training's rmse: 5018.26	valid_1's rmse: 5983.19
# [2090]	training's rmse: 5012.52	valid_1's rmse: 5979.38
# [2100]	training's rmse: 5007.39	valid_1's rmse: 5975.31
# [2110]	training's rmse: 5001.88	valid_1's rmse: 5974.18
# [2120]	training's rmse: 4997.32	valid_1's rmse: 5971.76
# [2130]	training's rmse: 4992.12	valid_1's rmse: 5968.1
# [2140]	training's rmse: 4985.61	valid_1's rmse: 5963.88
# [2150]	training's rmse: 4980.32	valid_1's rmse: 5960.51
# [2160]	training's rmse: 4974.26	valid_1's rmse: 5956.71
# [2170]	training's rmse: 4969.21	valid_1's rmse: 5955.49
# [2180]	training's rmse: 4964.53	valid_1's rmse: 5954.82
# [2190]	training's rmse: 4959.41	valid_1's rmse: 5951.22
# [2200]	training's rmse: 4954.01	valid_1's rmse: 5948.71
# [2210]	training's rmse: 4949.05	valid_1's rmse: 5944.82
# [2220]	training's rmse: 4943.13	valid_1's rmse: 5941.51
# [2230]	training's rmse: 4937.33	valid_1's rmse: 5938.26
# [2240]	training's rmse: 4932.99	valid_1's rmse: 5934.99
# [2250]	training's rmse: 4927.26	valid_1's rmse: 5932.94
# [2260]	training's rmse: 4922.74	valid_1's rmse: 5930.18
# [2270]	training's rmse: 4917.64	valid_1's rmse: 5927.85
# [2280]	training's rmse: 4912.81	valid_1's rmse: 5924.88
# [2290]	training's rmse: 4908.71	valid_1's rmse: 5922.6
# [2300]	training's rmse: 4903.23	valid_1's rmse: 5918.68
# [2310]	training's rmse: 4899.23	valid_1's rmse: 5916.54
# [2320]	training's rmse: 4893.88	valid_1's rmse: 5915.87
# [2330]	training's rmse: 4888.99	valid_1's rmse: 5913.1
# [2340]	training's rmse: 4884.66	valid_1's rmse: 5910.36
# [2350]	training's rmse: 4879.28	valid_1's rmse: 5907.21
# [2360]	training's rmse: 4875.09	valid_1's rmse: 5906.14
# [2370]	training's rmse: 4870.94	valid_1's rmse: 5903.52
# [2380]	training's rmse: 4865.98	valid_1's rmse: 5901.45
# [2390]	training's rmse: 4862.17	valid_1's rmse: 5900.47
# [2400]	training's rmse: 4858.37	valid_1's rmse: 5897.91
# [2410]	training's rmse: 4854.16	valid_1's rmse: 5896.97
# [2420]	training's rmse: 4849.72	valid_1's rmse: 5895.06
# [2430]	training's rmse: 4844.79	valid_1's rmse: 5892.13
# [2440]	training's rmse: 4840.9	valid_1's rmse: 5890.01
# [2450]	training's rmse: 4836.02	valid_1's rmse: 5889.72
# [2460]	training's rmse: 4831.67	valid_1's rmse: 5887.5
# [2470]	training's rmse: 4827.81	valid_1's rmse: 5886.12
# [2480]	training's rmse: 4822.86	valid_1's rmse: 5882.11
# [2490]	training's rmse: 4818.52	valid_1's rmse: 5880.18
# [2500]	training's rmse: 4814.29	valid_1's rmse: 5878.67
# [2510]	training's rmse: 4810.28	valid_1's rmse: 5876.62
# [2520]	training's rmse: 4805.57	valid_1's rmse: 5874.1
# [2530]	training's rmse: 4800.65	valid_1's rmse: 5870.58
# [2540]	training's rmse: 4796.35	valid_1's rmse: 5868.55
# [2550]	training's rmse: 4791.9	valid_1's rmse: 5865.19
# [2560]	training's rmse: 4787.88	valid_1's rmse: 5861.83
# [2570]	training's rmse: 4783.8	valid_1's rmse: 5857.78
# [2580]	training's rmse: 4779.68	valid_1's rmse: 5855.37
# [2590]	training's rmse: 4775.54	valid_1's rmse: 5852.75
# [2600]	training's rmse: 4771.04	valid_1's rmse: 5848.98
# [2610]	training's rmse: 4765.73	valid_1's rmse: 5845.1
# [2620]	training's rmse: 4761.94	valid_1's rmse: 5843.58
# [2630]	training's rmse: 4758.57	valid_1's rmse: 5841.86
# [2640]	training's rmse: 4754	valid_1's rmse: 5838.93
# [2650]	training's rmse: 4749.09	valid_1's rmse: 5835.94
# [2660]	training's rmse: 4744.47	valid_1's rmse: 5833.96
# [2670]	training's rmse: 4740.79	valid_1's rmse: 5832.23
# [2680]	training's rmse: 4736.21	valid_1's rmse: 5832.54
# [2690]	training's rmse: 4731.82	valid_1's rmse: 5830.73
# [2700]	training's rmse: 4728.08	valid_1's rmse: 5829.22
# [2710]	training's rmse: 4723.69	valid_1's rmse: 5827.83
# [2720]	training's rmse: 4719.87	valid_1's rmse: 5826.51
# [2730]	training's rmse: 4716.91	valid_1's rmse: 5824.24
# [2740]	training's rmse: 4713.16	valid_1's rmse: 5822.24
# [2750]	training's rmse: 4709.76	valid_1's rmse: 5820.71
# [2760]	training's rmse: 4705.78	valid_1's rmse: 5819.25
# [2770]	training's rmse: 4702.47	valid_1's rmse: 5818
# [2780]	training's rmse: 4698.85	valid_1's rmse: 5816.08
# [2790]	training's rmse: 4695.79	valid_1's rmse: 5814.46
# [2800]	training's rmse: 4691.11	valid_1's rmse: 5811.92
# [2810]	training's rmse: 4687.44	valid_1's rmse: 5810.69
# [2820]	training's rmse: 4683.09	valid_1's rmse: 5807.45
# [2830]	training's rmse: 4680.09	valid_1's rmse: 5806.07
# [2840]	training's rmse: 4675.33	valid_1's rmse: 5801.3
# [2850]	training's rmse: 4671.85	valid_1's rmse: 5799
# [2860]	training's rmse: 4668.5	valid_1's rmse: 5797.25
# [2870]	training's rmse: 4664.67	valid_1's rmse: 5796.68
# [2880]	training's rmse: 4660.41	valid_1's rmse: 5793.25
# [2890]	training's rmse: 4656.53	valid_1's rmse: 5790.61
# [2900]	training's rmse: 4653.09	valid_1's rmse: 5788.49
# [2910]	training's rmse: 4650.03	valid_1's rmse: 5786.65
# [2920]	training's rmse: 4646.03	valid_1's rmse: 5784.94
# [2930]	training's rmse: 4642.73	valid_1's rmse: 5782.79
# [2940]	training's rmse: 4637.98	valid_1's rmse: 5782.21
# [2950]	training's rmse: 4635.28	valid_1's rmse: 5780.57
# [2960]	training's rmse: 4630.77	valid_1's rmse: 5778.1
# [2970]	training's rmse: 4627.66	valid_1's rmse: 5776.44
# [2980]	training's rmse: 4624.24	valid_1's rmse: 5774.18
# [2990]	training's rmse: 4621.06	valid_1's rmse: 5772.71
# [3000]	training's rmse: 4618.01	valid_1's rmse: 5769.45
# [3010]	training's rmse: 4614.03	valid_1's rmse: 5769.85
# [3020]	training's rmse: 4609.9	valid_1's rmse: 5768.72
# [3030]	training's rmse: 4606.26	valid_1's rmse: 5767.18
# [3040]	training's rmse: 4602.85	valid_1's rmse: 5765.08
# [3050]	training's rmse: 4599.07	valid_1's rmse: 5762.98
# [3060]	training's rmse: 4595.54	valid_1's rmse: 5762.79
# [3070]	training's rmse: 4591.54	valid_1's rmse: 5760.92
# [3080]	training's rmse: 4588.62	valid_1's rmse: 5759.28
# [3090]	training's rmse: 4586.03	valid_1's rmse: 5759.35
# [3100]	training's rmse: 4581.88	valid_1's rmse: 5756.8
# [3110]	training's rmse: 4577.78	valid_1's rmse: 5754.19
# [3120]	training's rmse: 4575.5	valid_1's rmse: 5753.1
# [3130]	training's rmse: 4572.25	valid_1's rmse: 5751
# [3140]	training's rmse: 4568.29	valid_1's rmse: 5749.96
# [3150]	training's rmse: 4564.69	valid_1's rmse: 5749.22
# [3160]	training's rmse: 4561.86	valid_1's rmse: 5747.74
# [3170]	training's rmse: 4558.27	valid_1's rmse: 5745.69
# [3180]	training's rmse: 4554.53	valid_1's rmse: 5744.88
# [3190]	training's rmse: 4551.58	valid_1's rmse: 5744.34
# [3200]	training's rmse: 4548.73	valid_1's rmse: 5741.57
# [3210]	training's rmse: 4545.11	valid_1's rmse: 5739.4
# [3220]	training's rmse: 4541.96	valid_1's rmse: 5738.89
# [3230]	training's rmse: 4538.73	valid_1's rmse: 5737.13
# [3240]	training's rmse: 4535.76	valid_1's rmse: 5735.41
# [3250]	training's rmse: 4532.99	valid_1's rmse: 5734.97
# [3260]	training's rmse: 4529.59	valid_1's rmse: 5733.95
# [3270]	training's rmse: 4526.69	valid_1's rmse: 5733.57
# [3280]	training's rmse: 4523.52	valid_1's rmse: 5730.34
# [3290]	training's rmse: 4520.55	valid_1's rmse: 5729.41
# [3300]	training's rmse: 4517.78	valid_1's rmse: 5728.44
# [3310]	training's rmse: 4515.12	valid_1's rmse: 5728.09
# [3320]	training's rmse: 4511.74	valid_1's rmse: 5728.65
# [3330]	training's rmse: 4508.12	valid_1's rmse: 5726.35
# [3340]	training's rmse: 4505.06	valid_1's rmse: 5723.89
# [3350]	training's rmse: 4502.11	valid_1's rmse: 5722.66
# [3360]	training's rmse: 4499.67	valid_1's rmse: 5722.56
# [3370]	training's rmse: 4496.62	valid_1's rmse: 5722.14
# [3380]	training's rmse: 4493.85	valid_1's rmse: 5720.94
# [3390]	training's rmse: 4490.86	valid_1's rmse: 5718.95
# [3400]	training's rmse: 4488.07	valid_1's rmse: 5717.84
# [3410]	training's rmse: 4485.14	valid_1's rmse: 5716.75
# [3420]	training's rmse: 4482.88	valid_1's rmse: 5715.84
# [3430]	training's rmse: 4479.92	valid_1's rmse: 5714.14
# [3440]	training's rmse: 4476.9	valid_1's rmse: 5712.3
# [3450]	training's rmse: 4474.09	valid_1's rmse: 5711.17
# [3460]	training's rmse: 4471.12	valid_1's rmse: 5709.31
# [3470]	training's rmse: 4468.51	valid_1's rmse: 5708.24
# [3480]	training's rmse: 4465.46	valid_1's rmse: 5706.91
# [3490]	training's rmse: 4461.72	valid_1's rmse: 5705.33
# [3500]	training's rmse: 4458.46	valid_1's rmse: 5704.84
# [3510]	training's rmse: 4455.83	valid_1's rmse: 5702.67
# [3520]	training's rmse: 4453.69	valid_1's rmse: 5701.49
# [3530]	training's rmse: 4450.86	valid_1's rmse: 5700.74
# [3540]	training's rmse: 4447.36	valid_1's rmse: 5699.64
# [3550]	training's rmse: 4444.32	valid_1's rmse: 5697.93
# [3560]	training's rmse: 4441.1	valid_1's rmse: 5697.15
# [3570]	training's rmse: 4438.13	valid_1's rmse: 5695.59
# [3580]	training's rmse: 4434.83	valid_1's rmse: 5694.45
# [3590]	training's rmse: 4432.24	valid_1's rmse: 5692.51
# [3600]	training's rmse: 4429.31	valid_1's rmse: 5690.73
# [3610]	training's rmse: 4426.22	valid_1's rmse: 5690.29
# [3620]	training's rmse: 4423.66	valid_1's rmse: 5688.94
# [3630]	training's rmse: 4420.88	valid_1's rmse: 5687.43
# [3640]	training's rmse: 4418.52	valid_1's rmse: 5685.51
# [3650]	training's rmse: 4414.95	valid_1's rmse: 5681.86
# [3660]	training's rmse: 4411.75	valid_1's rmse: 5679.95
# [3670]	training's rmse: 4408.97	valid_1's rmse: 5679.26
# [3680]	training's rmse: 4406.18	valid_1's rmse: 5678.11
# [3690]	training's rmse: 4403.05	valid_1's rmse: 5676.5
# [3700]	training's rmse: 4399.78	valid_1's rmse: 5676.7
# [3710]	training's rmse: 4396.66	valid_1's rmse: 5677.15
# [3720]	training's rmse: 4393.85	valid_1's rmse: 5676.32
# [3730]	training's rmse: 4391.5	valid_1's rmse: 5675.98
# [3740]	training's rmse: 4388.24	valid_1's rmse: 5676.26
# [3750]	training's rmse: 4385.02	valid_1's rmse: 5674.6
# [3760]	training's rmse: 4382.66	valid_1's rmse: 5673.55
# [3770]	training's rmse: 4379.99	valid_1's rmse: 5672.35
# [3780]	training's rmse: 4377.47	valid_1's rmse: 5670.97
# [3790]	training's rmse: 4374.84	valid_1's rmse: 5669.58
# [3800]	training's rmse: 4371.42	valid_1's rmse: 5668.93
# [3810]	training's rmse: 4368.82	valid_1's rmse: 5667.58
# [3820]	training's rmse: 4366.17	valid_1's rmse: 5667.31
# [3830]	training's rmse: 4363.74	valid_1's rmse: 5666.37
# [3840]	training's rmse: 4360.99	valid_1's rmse: 5664.29
# [3850]	training's rmse: 4358.35	valid_1's rmse: 5663.68
# [3860]	training's rmse: 4355.46	valid_1's rmse: 5663.51
# [3870]	training's rmse: 4352.65	valid_1's rmse: 5662.76
# [3880]	training's rmse: 4349.43	valid_1's rmse: 5661.78
# [3890]	training's rmse: 4346.39	valid_1's rmse: 5659.47
# [3900]	training's rmse: 4343.66	valid_1's rmse: 5657.36
# [3910]	training's rmse: 4340.59	valid_1's rmse: 5657.12
# [3920]	training's rmse: 4337.74	valid_1's rmse: 5653.97
# [3930]	training's rmse: 4334.91	valid_1's rmse: 5653.69
# [3940]	training's rmse: 4332.23	valid_1's rmse: 5651.95
# [3950]	training's rmse: 4329.45	valid_1's rmse: 5651.96
# [3960]	training's rmse: 4326.83	valid_1's rmse: 5651.22
# [3970]	training's rmse: 4324.11	valid_1's rmse: 5650.13
# [3980]	training's rmse: 4321.84	valid_1's rmse: 5649.75
# [3990]	training's rmse: 4319.68	valid_1's rmse: 5649.12
# [4000]	training's rmse: 4317.48	valid_1's rmse: 5648.12
# [4010]	training's rmse: 4314.8	valid_1's rmse: 5648.15
# [4020]	training's rmse: 4312.34	valid_1's rmse: 5647.51
# [4030]	training's rmse: 4309.57	valid_1's rmse: 5646.49
# [4040]	training's rmse: 4307.28	valid_1's rmse: 5644.68
# [4050]	training's rmse: 4304.09	valid_1's rmse: 5644.18
# [4060]	training's rmse: 4301.8	valid_1's rmse: 5643.39
# [4070]	training's rmse: 4299.83	valid_1's rmse: 5642.33
# [4080]	training's rmse: 4296.9	valid_1's rmse: 5639.96
# [4090]	training's rmse: 4294.41	valid_1's rmse: 5639.1
# [4100]	training's rmse: 4291.47	valid_1's rmse: 5638.2
# [4110]	training's rmse: 4289.08	valid_1's rmse: 5636.53
# [4120]	training's rmse: 4287.01	valid_1's rmse: 5635.71
# [4130]	training's rmse: 4284.35	valid_1's rmse: 5634.65
# [4140]	training's rmse: 4282.55	valid_1's rmse: 5633.75
# [4150]	training's rmse: 4280.34	valid_1's rmse: 5632.94
# [4160]	training's rmse: 4277.8	valid_1's rmse: 5631.23
# [4170]	training's rmse: 4275.23	valid_1's rmse: 5630.06
# [4180]	training's rmse: 4272.85	valid_1's rmse: 5628.66
# [4190]	training's rmse: 4269.6	valid_1's rmse: 5628.2
# [4200]	training's rmse: 4266.93	valid_1's rmse: 5627.39
# [4210]	training's rmse: 4264.46	valid_1's rmse: 5626.32
# [4220]	training's rmse: 4262.2	valid_1's rmse: 5626.36
# [4230]	training's rmse: 4259.61	valid_1's rmse: 5625.24
# [4240]	training's rmse: 4257.46	valid_1's rmse: 5624.78
# [4250]	training's rmse: 4254.74	valid_1's rmse: 5623.67
# [4260]	training's rmse: 4252.33	valid_1's rmse: 5624.41
# [4270]	training's rmse: 4249.55	valid_1's rmse: 5624.12
# [4280]	training's rmse: 4247.68	valid_1's rmse: 5624.15
# [4290]	training's rmse: 4245.64	valid_1's rmse: 5623.58
# [4300]	training's rmse: 4243.58	valid_1's rmse: 5622.75
# [4310]	training's rmse: 4241.26	valid_1's rmse: 5620.74
# [4320]	training's rmse: 4238.77	valid_1's rmse: 5619.44
# [4330]	training's rmse: 4236.11	valid_1's rmse: 5618.03
# [4340]	training's rmse: 4233.87	valid_1's rmse: 5617.23
# [4350]	training's rmse: 4231.77	valid_1's rmse: 5616.1
# [4360]	training's rmse: 4229.7	valid_1's rmse: 5615.44
# [4370]	training's rmse: 4227.3	valid_1's rmse: 5614.22
# [4380]	training's rmse: 4225.4	valid_1's rmse: 5613.8
# [4390]	training's rmse: 4222.8	valid_1's rmse: 5613.06
# [4400]	training's rmse: 4220.92	valid_1's rmse: 5612.33
# [4410]	training's rmse: 4218.33	valid_1's rmse: 5611.67
# [4420]	training's rmse: 4216.01	valid_1's rmse: 5611.09
# [4430]	training's rmse: 4213.59	valid_1's rmse: 5610.48
# [4440]	training's rmse: 4211.56	valid_1's rmse: 5609.88
# [4450]	training's rmse: 4209.36	valid_1's rmse: 5609.22
# [4460]	training's rmse: 4207.55	valid_1's rmse: 5607.72
# [4470]	training's rmse: 4205.58	valid_1's rmse: 5607.76
# [4480]	training's rmse: 4203.24	valid_1's rmse: 5606.78
# [4490]	training's rmse: 4201.04	valid_1's rmse: 5605.76
# [4500]	training's rmse: 4198.97	valid_1's rmse: 5605.3
# [4510]	training's rmse: 4196.85	valid_1's rmse: 5604.82
# [4520]	training's rmse: 4194	valid_1's rmse: 5602.76
# [4530]	training's rmse: 4191.1	valid_1's rmse: 5599.75
# [4540]	training's rmse: 4188.84	valid_1's rmse: 5599.35
# [4550]	training's rmse: 4186.28	valid_1's rmse: 5598.09
# [4560]	training's rmse: 4184.07	valid_1's rmse: 5596.41
# [4570]	training's rmse: 4181.92	valid_1's rmse: 5597.67
# [4580]	training's rmse: 4179.97	valid_1's rmse: 5597.28
# [4590]	training's rmse: 4177.49	valid_1's rmse: 5596.05
# [4600]	training's rmse: 4175.03	valid_1's rmse: 5594.46
# [4610]	training's rmse: 4173.07	valid_1's rmse: 5593.32
# [4620]	training's rmse: 4171.4	valid_1's rmse: 5592.93
# [4630]	training's rmse: 4169.67	valid_1's rmse: 5592.09
# [4640]	training's rmse: 4167.23	valid_1's rmse: 5591.64
# [4650]	training's rmse: 4164.97	valid_1's rmse: 5591.48
# [4660]	training's rmse: 4162.95	valid_1's rmse: 5590.4
# [4670]	training's rmse: 4160.73	valid_1's rmse: 5590.05
# [4680]	training's rmse: 4158.72	valid_1's rmse: 5589.04
# [4690]	training's rmse: 4156.81	valid_1's rmse: 5589.17
# [4700]	training's rmse: 4154.93	valid_1's rmse: 5588.99
# [4710]	training's rmse: 4152.45	valid_1's rmse: 5587.97
# [4720]	training's rmse: 4150.95	valid_1's rmse: 5588.33
# [4730]	training's rmse: 4148.67	valid_1's rmse: 5587.04
# [4740]	training's rmse: 4146.91	valid_1's rmse: 5585.95
# [4750]	training's rmse: 4144.75	valid_1's rmse: 5584.72
# [4760]	training's rmse: 4142.65	valid_1's rmse: 5583.43
# [4770]	training's rmse: 4140.69	valid_1's rmse: 5582.37
# [4780]	training's rmse: 4138.52	valid_1's rmse: 5582.22
# [4790]	training's rmse: 4136.56	valid_1's rmse: 5581.97
# [4800]	training's rmse: 4133.82	valid_1's rmse: 5580.15
# [4810]	training's rmse: 4132.35	valid_1's rmse: 5580
# [4820]	training's rmse: 4130.45	valid_1's rmse: 5579.86
# [4830]	training's rmse: 4128.62	valid_1's rmse: 5579.38
# [4840]	training's rmse: 4127.2	valid_1's rmse: 5578.82
# [4850]	training's rmse: 4125.38	valid_1's rmse: 5578.46
# [4860]	training's rmse: 4123.04	valid_1's rmse: 5578.05
# [4870]	training's rmse: 4120.77	valid_1's rmse: 5577.76
# [4880]	training's rmse: 4118.88	valid_1's rmse: 5578.26
# [4890]	training's rmse: 4116.58	valid_1's rmse: 5577.26
# [4900]	training's rmse: 4114.53	valid_1's rmse: 5576.51
# [4910]	training's rmse: 4112.6	valid_1's rmse: 5575.75
# [4920]	training's rmse: 4111	valid_1's rmse: 5575.16
# [4930]	training's rmse: 4109.27	valid_1's rmse: 5574.53
# [4940]	training's rmse: 4107.19	valid_1's rmse: 5573.83
# [4950]	training's rmse: 4105.28	valid_1's rmse: 5573.24
# [4960]	training's rmse: 4103.18	valid_1's rmse: 5572.31
# [4970]	training's rmse: 4101.24	valid_1's rmse: 5571.45
# [4980]	training's rmse: 4099.34	valid_1's rmse: 5570.93
# [4990]	training's rmse: 4097.2	valid_1's rmse: 5570.19
# [5000]	training's rmse: 4095.17	valid_1's rmse: 5570.07
# [5010]	training's rmse: 4093.14	valid_1's rmse: 5569.14
# [5020]	training's rmse: 4091.24	valid_1's rmse: 5569.21
# [5030]	training's rmse: 4089.47	valid_1's rmse: 5568.52
# [5040]	training's rmse: 4087.5	valid_1's rmse: 5568.1
# [5050]	training's rmse: 4085.77	valid_1's rmse: 5567.09
# [5060]	training's rmse: 4083.75	valid_1's rmse: 5567.42
# [5070]	training's rmse: 4082.04	valid_1's rmse: 5567.26
# [5080]	training's rmse: 4080.2	valid_1's rmse: 5566.11
# [5090]	training's rmse: 4078.43	valid_1's rmse: 5565.14
# [5100]	training's rmse: 4076.56	valid_1's rmse: 5564.61
# [5110]	training's rmse: 4074.52	valid_1's rmse: 5563.93
# [5120]	training's rmse: 4072.6	valid_1's rmse: 5563.68
# [5130]	training's rmse: 4070.31	valid_1's rmse: 5561.99
# [5140]	training's rmse: 4068.44	valid_1's rmse: 5561.44
# [5150]	training's rmse: 4066.91	valid_1's rmse: 5561.04
# [5160]	training's rmse: 4064.76	valid_1's rmse: 5559.75
# [5170]	training's rmse: 4063.05	valid_1's rmse: 5559.58
# [5180]	training's rmse: 4061.19	valid_1's rmse: 5559.46
# [5190]	training's rmse: 4059.7	valid_1's rmse: 5558.89
# [5200]	training's rmse: 4057.7	valid_1's rmse: 5558.42
# [5210]	training's rmse: 4055.74	valid_1's rmse: 5557.36
# [5220]	training's rmse: 4053.85	valid_1's rmse: 5556.41
# [5230]	training's rmse: 4052.06	valid_1's rmse: 5555.36
# [5240]	training's rmse: 4050.51	valid_1's rmse: 5554.63
# [5250]	training's rmse: 4048.84	valid_1's rmse: 5554.74
# [5260]	training's rmse: 4046.86	valid_1's rmse: 5554.03
# [5270]	training's rmse: 4045.16	valid_1's rmse: 5554.55
# [5280]	training's rmse: 4043.71	valid_1's rmse: 5553.83
# [5290]	training's rmse: 4042.05	valid_1's rmse: 5552.53
# [5300]	training's rmse: 4040.55	valid_1's rmse: 5552.05
# [5310]	training's rmse: 4038.57	valid_1's rmse: 5549.95
# [5320]	training's rmse: 4036.81	valid_1's rmse: 5550.23
# [5330]	training's rmse: 4035.35	valid_1's rmse: 5549.74
# [5340]	training's rmse: 4033.31	valid_1's rmse: 5547.4
# [5350]	training's rmse: 4031.77	valid_1's rmse: 5546.83
# [5360]	training's rmse: 4029.82	valid_1's rmse: 5546.3
# [5370]	training's rmse: 4028.1	valid_1's rmse: 5545.81
# [5380]	training's rmse: 4025.95	valid_1's rmse: 5545.11
# [5390]	training's rmse: 4024.5	valid_1's rmse: 5544.63
# [5400]	training's rmse: 4022.49	valid_1's rmse: 5544.79
# [5410]	training's rmse: 4020.67	valid_1's rmse: 5545.2
# [5420]	training's rmse: 4019.41	valid_1's rmse: 5544.82
# [5430]	training's rmse: 4017.18	valid_1's rmse: 5544.1
# [5440]	training's rmse: 4015.47	valid_1's rmse: 5543.97
# [5450]	training's rmse: 4013.56	valid_1's rmse: 5544.32
# [5460]	training's rmse: 4011.72	valid_1's rmse: 5544.73
# [5470]	training's rmse: 4009.68	valid_1's rmse: 5543.95
# [5480]	training's rmse: 4007.94	valid_1's rmse: 5543.21
# [5490]	training's rmse: 4006.12	valid_1's rmse: 5543.43
# [5500]	training's rmse: 4004.54	valid_1's rmse: 5542.4
# [5510]	training's rmse: 4002.69	valid_1's rmse: 5540.32
# [5520]	training's rmse: 4001.16	valid_1's rmse: 5540.53
# [5530]	training's rmse: 3999.58	valid_1's rmse: 5540.14
# [5540]	training's rmse: 3997.9	valid_1's rmse: 5540.88
# [5550]	training's rmse: 3996.38	valid_1's rmse: 5540.88
# [5560]	training's rmse: 3994.92	valid_1's rmse: 5541.02
# [5570]	training's rmse: 3993.03	valid_1's rmse: 5539.32
# [5580]	training's rmse: 3991.5	valid_1's rmse: 5539.79
# [5590]	training's rmse: 3990.08	valid_1's rmse: 5539.36
# [5600]	training's rmse: 3988.15	valid_1's rmse: 5539.2
# [5610]	training's rmse: 3986.1	valid_1's rmse: 5539.14
# [5620]	training's rmse: 3984.54	valid_1's rmse: 5538.87
# [5630]	training's rmse: 3982.6	valid_1's rmse: 5539.38
# [5640]	training's rmse: 3981.12	valid_1's rmse: 5539.45
# [5650]	training's rmse: 3979.56	valid_1's rmse: 5540.12
# [5660]	training's rmse: 3977.9	valid_1's rmse: 5539.76
# [5670]	training's rmse: 3976.29	valid_1's rmse: 5539.51
# Early stopping, best iteration is:
# [5616]	training's rmse: 3985.06	valid_1's rmse: 5538.77
# LGBMRegressor(data_sample_strategy='goss', metric='rmse', n_estimators=100000)

# %%
train_X.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년', 'GDP', '한국은행 기준금리',
#        '기대 인플레이션', '거래량', '구별 지가지수', '공시지가 평균', '매수우위지수', '30년이상50년이하',
#        '아파트 카테고리', '지하철 카테고리', '아파트 평균 가격', '계약월_sin'],
#       dtype='object')

# %%
test_X.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', '계약년', 'GDP', '한국은행 기준금리',
#        '기대 인플레이션', '거래량', '구별 지가지수', '공시지가 평균', '매수우위지수', '30년이상50년이하',
#        '아파트 카테고리', '지하철 카테고리', '아파트 평균 가격', '계약월_sin'],
#       dtype='object')

# %%
preds = model.predict(test_X)

# %%
preds
# Out:
# array([190937.6364006 , 318049.41245551, 333292.57113663, ...,
#         86394.2819661 ,  74432.79253627,  74926.20154382])

# %%
preds = np.round(preds).astype(int)

# %%
preds_df = pd.DataFrame(preds, columns=['target'])

# %%
preds_df
# Out:
#       target
# 0     190938
# 1     318049
# 2     333293
# 3     299273
# 4     228520
# ...      ...
# 9267   73878
# 9268   73342
# 9269   86394
# 9270   74433
# 9271   74926
#
# [9272 rows x 1 columns]

# %%
joblib.dump(model, './v_34_2.pkl')
# Out:
# ['./v_34_2.pkl']

# %%
preds_df.to_csv('../preds/v_34_2_preds.csv', index=False)
