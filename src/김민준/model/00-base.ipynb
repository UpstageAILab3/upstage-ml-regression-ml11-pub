# %%
import re
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt

from scipy import stats
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder

import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumBarunGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) # 폰트 설정
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## 통합 데이터 로드

# %%
total_df = pd.read_csv('../data/team/5_interest_rate.csv')
# Out:
# /tmp/ipykernel_1644739/3485981028.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   total_df = pd.read_csv('../data/team/5_interest_rate.csv')

# %%
print(total_df.shape)
print(total_df.columns)
# Out:
# (1128094, 76)
# Index(['시군구', '번지', '본번', '부번', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도',
#        '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)',
#        'k-전화번호', 'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-관리방식', 'k-복도유형',
#        'k-난방방식', 'k-전체동수', 'k-전체세대수', 'k-건설사(시공사)', 'k-시행사', 'k-사용검사일-사용승인일',
#        'k-연면적', 'k-주거전용면적', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)',
#        'k-전용면적별세대현황(60~85이하)', 'k-85~135이하', 'k-135초과', 'k-홈페이지', 'k-등록일자',
#        'k-수정일자', '고용보험관리번호', '경비비관리형태', '세대전기계약방법', '청소비관리형태', '건축면적', '주차대수',
#        '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드', '좌표X', '좌표Y',
#        '단지신청일', 'target', 'is_test', '시군구 번지', '좌표X,좌표Y', '가장 가까운 거리', 'index',
#        '역사_ID', '역사명', '호선', '위도', '경도', '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리',
#        '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호',
#        '가장 가까운 버스 정류소명', '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표',
#        '가장 가까운 버스 정류장 Y좌표', '인근 버스 정류장 개수', '계약년', '계약월', 'GDP', '한국은행 기준금리'],
#       dtype='object')

# %%
total_df.head()
# Out:
#              시군구     번지     본번   부번    아파트명   전용면적    계약년월  계약일  층  건축년도  ...  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712    8  3  1987  ...
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712   22  4  1987  ...
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  54.98  201712   28  5  1987  ...
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201801    3  4  1987  ...
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201801    8  2  1987  ...
#
#   가장 가까운 버스 정류소번호  가장 가까운 버스 정류소명 가장 가까운 버스 정류소 타입 가장 가까운 버스 정류장 X좌표  \
# 0         23445.0         개포우성아파트             일반차로        127.057864
# 1         23445.0         개포우성아파트             일반차로        127.057864
# 2         23445.0         개포우성아파트             일반차로        127.057864
# 3         23445.0         개포우성아파트             일반차로        127.057864
# 4         23445.0         개포우성아파트             일반차로        127.057864
#
#   가장 가까운 버스 정류장 Y좌표 인근 버스 정류장 개수   계약년 계약월        GDP 한국은행 기준금리
# 0         37.476564          7.0  2017  12  1623074.1       1.5
# 1         37.476564          7.0  2017  12  1623074.1       1.5
# 2         37.476564          7.0  2017  12  1623074.1       1.5
# 3         37.476564          7.0  2018   1  1725373.4       1.5
# 4         37.476564          7.0  2018   1  1725373.4       1.5
#
# [5 rows x 76 columns]

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128094 entries, 0 to 1128093
# Data columns (total 76 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   시군구                   1128094 non-null  object
#  1   번지                    1127867 non-null  object
#  2   본번                    1128019 non-null  float64
#  3   부번                    1128019 non-null  float64
#  4   아파트명                  1125958 non-null  object
#  5   전용면적                  1128094 non-null  float64
#  6   계약년월                  1128094 non-null  int64
#  7   계약일                   1128094 non-null  int64
#  8   층                     1128094 non-null  int64
#  9   건축년도                  1128094 non-null  int64
#  10  도로명                   1128094 non-null  object
#  11  해제사유발생일               6195 non-null     float64
#  12  등기신청일자                1128094 non-null  object
#  13  거래유형                  1128094 non-null  object
#  14  중개사소재지                1128094 non-null  object
#  15  k-단지분류(아파트,주상복합등등)    250821 non-null   object
#  16  k-전화번호                251244 non-null   object
#  17  k-팩스번호                248746 non-null   object
#  18  단지소개기존clob            69136 non-null    float64
#  19  k-세대타입(분양형태)          251969 non-null   object
#  20  k-관리방식                251969 non-null   object
#  21  k-복도유형                251640 non-null   object
#  22  k-난방방식                251969 non-null   object
#  23  k-전체동수                250887 non-null   float64
#  24  k-전체세대수               251969 non-null   float64
#  25  k-건설사(시공사)            250457 non-null   object
#  26  k-시행사                 250260 non-null   object
#  27  k-사용검사일-사용승인일         251835 non-null   object
#  28  k-연면적                 251969 non-null   float64
#  29  k-주거전용면적              251924 non-null   float64
#  30  k-관리비부과면적             251969 non-null   float64
#  31  k-전용면적별세대현황(60이하)     251924 non-null   float64
#  32  k-전용면적별세대현황(60~85이하)  251924 non-null   float64
#  33  k-85~135이하            251924 non-null   float64
#  34  k-135초과               329 non-null      float64
#  35  k-홈페이지                114571 non-null   object
#  36  k-등록일자                11708 non-null    object
#  37  k-수정일자                251924 non-null   object
#  38  고용보험관리번호              207337 non-null   object
#  39  경비비관리형태               250533 non-null   object
#  40  세대전기계약방법              242705 non-null   object
#  41  청소비관리형태               250343 non-null   object
#  42  건축면적                  251815 non-null   float64
#  43  주차대수                  251817 non-null   float64
#  44  기타/의무/임대/임의=1/2/3/4   251969 non-null   object
#  45  단지승인일                 251240 non-null   object
#  46  사용허가여부                251969 non-null   object
#  47  관리비 업로드               251969 non-null   object
#  48  좌표X                   1128094 non-null  float64
#  49  좌표Y                   1128094 non-null  float64
#  50  단지신청일                 251907 non-null   object
#  51  target                1118822 non-null  float64
#  52  is_test               1128094 non-null  int64
#  53  시군구 번지                1127867 non-null  object
#  54  좌표X,좌표Y               1128094 non-null  object
#  55  가장 가까운 거리             1128094 non-null  float64
#  56  index                 1128094 non-null  float64
#  57  역사_ID                 1128094 non-null  float64
#  58  역사명                   1128094 non-null  object
#  59  호선                    1128094 non-null  object
#  60  위도                    1128094 non-null  float64
#  61  경도                    1128094 non-null  float64
#  62  인근 지하철 역 개수           1128094 non-null  float64
#  63  가장 가까운 버스 정류장 거리      1128094 non-null  float64
#  64  가장 가까운 버스 정류장 index   1128094 non-null  float64
#  65  가장 가까운 버스 정류장 노드 ID   1128094 non-null  float64
#  66  가장 가까운 버스 정류소번호       1128094 non-null  float64
#  67  가장 가까운 버스 정류소명        1128094 non-null  object
#  68  가장 가까운 버스 정류소 타입      1128094 non-null  object
#  69  가장 가까운 버스 정류장 X좌표     1128094 non-null  float64
#  70  가장 가까운 버스 정류장 Y좌표     1128094 non-null  float64
#  71  인근 버스 정류장 개수          1128094 non-null  float64
#  72  계약년                   1128094 non-null  int64
#  73  계약월                   1128094 non-null  int64
#  74  GDP                   1128094 non-null  float64
#  75  한국은행 기준금리             1128094 non-null  float64
# dtypes: float64(34), int64(7), object(35)
# memory usage: 654.1+ MB

# %% [markdown]
# ## 컬럼 삭제

# %%
# 추가로 제거가 필요한 feature 제거
total_df.drop([
    # '시군구', 
    # '번지',
    # '도로명',
    # '아파트명', 
    # 'k-건설사(시공사)',
    '본번',
    '부번',
    'k-세대타입(분양형태)', 
    '거래유형', 
    'k-시행사', 
    'k-연면적', 
    'k-주거전용면적',
    'k-관리방식',
    '해제사유발생일',
    '등기신청일자',
    '중개사소재지', 'k-단지분류(아파트,주상복합등등)', 'k-전화번호', 'k-팩스번호', '단지소개기존clob', 'k-복도유형', 'k-난방방식', 'k-전체동수',
    '세대전기계약방법', '청소비관리형태', '건축면적', 'k-사용검사일-사용승인일', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)', '시군구 번지', 
    '좌표X,좌표Y', 'index', '역사_ID', '역사명', '위도', '경도',
    '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호', '가장 가까운 버스 정류소명',
    '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표', '가장 가까운 버스 정류장 Y좌표', '호선',
    'k-전용면적별세대현황(60~85이하)', 'k-85~135이하', 'k-135초과', 'k-홈페이지', 'k-등록일자',
    'k-수정일자', '고용보험관리번호', '경비비관리형태', '기타/의무/임대/임의=1/2/3/4', '단지승인일',
    '사용허가여부', '관리비 업로드', '좌표X', '좌표Y', '단지신청일',
    '계약년', '계약월',
], axis=1, inplace=True)

display(total_df.shape)
display(total_df.columns)
display(total_df.head())
# Out:
# (1128094, 20)
# Index(['시군구', '번지', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-전체세대수', 'k-건설사(시공사)', '주차대수', 'target', 'is_test', '가장 가까운 거리',
#        '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP', '한국은행 기준금리'],
#       dtype='object')
#              시군구     번지    아파트명   전용면적    계약년월  계약일  층  건축년도    도로명  k-전체세대수  \
# 0  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712    8  3  1987  언주로 3    270.0
# 1  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712   22  4  1987  언주로 3    270.0
# 2  서울특별시 강남구 개포동  658-1  개포6차우성  54.98  201712   28  5  1987  언주로 3    270.0
# 3  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    3  4  1987  언주로 3    270.0
# 4  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    8  2  1987  언주로 3    270.0
#
#   k-건설사(시공사)   주차대수    target  is_test    가장 가까운 거리  인근 지하철 역 개수  \
# 0       우성건설  262.0  124000.0        0  1127.738351          2.0
# 1       우성건설  262.0  123500.0        0  1127.738351          2.0
# 2       우성건설  262.0   91500.0        0  1127.738351          2.0
# 3       우성건설  262.0  130000.0        0  1127.738351          2.0
# 4       우성건설  262.0  117000.0        0  1127.738351          2.0
#
#    가장 가까운 버스 정류장 거리  인근 버스 정류장 개수        GDP  한국은행 기준금리
# 0          61.89584           7.0  1623074.1        1.5
# 1          61.89584           7.0  1623074.1        1.5
# 2          61.89584           7.0  1623074.1        1.5
# 3          61.89584           7.0  1725373.4        1.5
# 4          61.89584           7.0  1725373.4        1.5

# %% [markdown]
# ## 파생변수1 - 세대별 주차대수

# %%
total_df['세대별_주차대수'] = total_df['주차대수'] / total_df['k-전체세대수']

total_df.drop(['주차대수', 'k-전체세대수'], axis=1, inplace=True)
display(total_df.shape)
display(total_df.columns)
display(total_df.head())
# Out:
# (1128094, 19)
# Index(['시군구', '번지', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-건설사(시공사)', 'target', 'is_test', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP', '한국은행 기준금리', '세대별_주차대수'],
#       dtype='object')
#              시군구     번지    아파트명   전용면적    계약년월  계약일  층  건축년도    도로명  \
# 0  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712    8  3  1987  언주로 3
# 1  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712   22  4  1987  언주로 3
# 2  서울특별시 강남구 개포동  658-1  개포6차우성  54.98  201712   28  5  1987  언주로 3
# 3  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    3  4  1987  언주로 3
# 4  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    8  2  1987  언주로 3
#
#   k-건설사(시공사)    target  is_test    가장 가까운 거리  인근 지하철 역 개수  가장 가까운 버스 정류장 거리  \
# 0       우성건설  124000.0        0  1127.738351          2.0          61.89584
# 1       우성건설  123500.0        0  1127.738351          2.0          61.89584
# 2       우성건설   91500.0        0  1127.738351          2.0          61.89584
# 3       우성건설  130000.0        0  1127.738351          2.0          61.89584
# 4       우성건설  117000.0        0  1127.738351          2.0          61.89584
#
#    인근 버스 정류장 개수        GDP  한국은행 기준금리  세대별_주차대수
# 0           7.0  1623074.1        1.5   0.97037
# 1           7.0  1623074.1        1.5   0.97037
# 2           7.0  1623074.1        1.5   0.97037
# 3           7.0  1725373.4        1.5   0.97037
# 4           7.0  1725373.4        1.5   0.97037

# %% [markdown]
# ### 파생변수2 - 건설사 랭크

# %%
# 동의어 사전
synonyms = {
    '삼성물산': ['삼성물산주식회사', '삼성물산(주)', '삼성물산 건설부문', '삼성물산(주) 건설부문', '삼성물산,두산건설', '삼성물산(주) 주택부문', "삼성건설", "삼성건설(주)", "삼성래미안", "삼성물산",
               "(주)삼성물산", "삼성", "삼성물산", "삼성중공업", "(주)삼성", "삼성물산, 건설부문", "삼성물산, 주택부문"],
    '현대건설': ['현대건설(주)', '현대건설주식회사', '(주)현대건설', '현대산업개발', '현대산업개발(주)', 'HDC현대산업개발', '현대bs&c', '현대BS&C', "(주)현대산업개발", "현대산업개발", 
               "주식회사 현대건설", "현대", "현대산업개발 주", "현대종합건설", "주시회사 현대건설", "현대산업개발", "현대엔지니어링", "현대힐스테이트", "주시회사, 현대건설", "현대건설, 주"],
    '대림산업': ['대림산업(주)', '대림산업주식회사', '(주)대림산업', '대림건설', '대림건설(주)', "(주)대림", "대림", "대림산업", "대림산업 (주)", "대림산업"],
    '대우건설': ['대우건설(주)', '대우푸르지오', "(주)대우", "(주)대우건설", "대우건설", "주)대우건설", "대우경남", "대우", "대우자동차판매"],
    'GS건설': ['GS건설(주)', '지에스 건설', '지에스건설주식회사', '지에스건설(주)', "(주)gs공사", "GS 건설", "GS건설", "GS건설주식회사", "GS자이 건설", "gs건설", "럭키외", "GS", "gs공사",
              'GS건설, unknown', 'GS자이, unknown', "지에스, unknown", '지에스건설'],
    "SK건설": ["(주)에스케이건설", "SK", "에스케이건설"],
    '한라건설': ['(주)한라', '한라건설', '(주)한라건설', '한라'],
    '롯데건설': ['롯데건설(주)', '롯데건설주식회사', "(주)롯데건설", "롯데건설"],
    '한화건설': ['(주)한화건설', '한화건설(주)'],
    '두산건설': ['두산건설주식회사', '두산건설(주)', "두산", "두산건설", "두산건설(주)", "두산건설주식회사"],
    '우성건설': ['우성건설(주)', '(주)우성건설', '우성건설(주)'],
    '포스코건설': ['(주)포스코건설', '포스코, 포스코A&C', '포스코', '포스코', '포스코건설, 포스코A&C'],
    'SH공사': ['sh공사', '에스에이치공사', 'SH', "SH공사", "sh 공사", "sh, 공사", "(주)에스에이치건설", "서울도시개발공사", "주택공사", "도시개발공사", "에스에이치건설"],
    '건영건설': ['(주)건영', '(주) 건영', "(주) 건영", "건영", "건영건설", "건영종합건설(주)", " (주) 건영", "건영종합건설"],
    '신동아건설': ['신동아건설(주)', '신동아 건설(주)', '신동아', '신동아건설', '신동아건설(주)', "신동아건설, unknown"],
    '계룡건설': ['계룡건설(주)', '계룡건설산업(주)'],
    '코오롱건설': ['코오롱글로벌(주)', '코오롱글로벌', '코오롱건설주식회사'],
    '성원건설': ['성원건설(주)', '(주)성원건설'],
    "금호건설": ["(주)금호", "(주)금호건설", "(주)금호산업", "금호", "금호건설", "금호건설(주)", "금호산업", "금호자이"],
    "동아건설": ["(주)동아건설산업", "동아건설", "동아건설산업(주)", "동아건설산업"],
    "동일토건": ["(주)동일토건", "동일토건"],
    "LG건설": ["엘지건설(주)", "엘지건설"],
    "한일건설" : ["한일개발"],
    "삼호건설": ["삼호건설", "삼호주택", "(주)삼호"],
    "서광산업": ["(주)서광건설산업", "서광산업"],
    "서희건설": ["(주)서희건설", "서희건설", "주식회사 서희건설", 'unknown, 서희건설'],
    "신성건설": ["(주)신성건설", "신성건설", "신성건설(주)"],
    "신창건설": ["(주)신창건설", "신창건설", "신창건설(주)->우방건설", "신창건설->우방건설"],
    "쌍용건설": ["(주)쌍용건설", "쌍용건설", "쌍용건설(주)", "쌍용건설(주)", "쌍용"],
    "우방건설": ["(주)우방", "우방", "우방건설"],
    "우리건설": ["(주)우리건설", "우리건설", "우리창우"],
    "일성건설": ["(주)일성건설", "일성건설", "(주)일성건설"],
    "임광건설": ["임광토건(주)"],
    "청구건설": ["청구", "청구주택"],
    "남광건설" : ["남광", "남광토건(주)", "남광토건"],
    "풍림건설" : ["풍림산업"],
    "중앙건설": ["(주)중앙건설", "중앙건설", "중앙건설(주)"],
    "태영건설": ["(주)태영", "(주)태영건설", "태영건설", "태영"],
    "한양건설": ["(주)한양", "(주)한양건설", "한양", "한양건설", "한양", "한양건설", "한양수자인", "한양주택 (주)", "?양건설", "한양산업개발", "한양산업개발(주", "한양주택"],
    "한진건설": ["(주)한진중공업", "한진중공업", "한진중공업(주)", "한진중공업", "한진건설(주)"],
    "한신건설": ["한신공영", "한신공영(주)"],
    "효성건설": ["(주)효성", "(주)효성건설", "효성건설", "효성중공업", "효성"],
    "KCC건설": ["KCC", "kcc건설"],
    "동부건설": ["동부건설", "동부건설(주)", "동부건설(주)외1", "동부건설외1"],
    "이수건설": ["이수건설", "이수건설(주)", "이수건설,대우엔지니어링"],
    "삼성중공업": ["삼성중공업", "삼성중공업(주)"],
    "호반건설" : ["(주)호반건설"],
    "LIG건설" : ["LIG건설", "LIG건설(주)"],
    "경남기업": ["경남기업", "경남기업(주)"],
    "경향건설": ["경향건설(주)"],
    "계룡건설": ["계룡건설산업", "계룡건설(주)", "계룡건설산업(주)"],
    "고려개발": ["고려개발", "고려개발(주)", "고려산업개발", "고려산업개발(주)", "고려개발(주)", "고려산업개발", "고려산업개발(주)"],
    "극동건설" : ["극동건설", "극동건설(주)"],
    "나산건설" : ["나산종합건설"],
    "라이프건설": ["라이프주택"],
    "신도건설": ["(주)신도종합건설", "신도종합건설"],
    "쌍용건설": ["쌍용"],
    "우림건설": ["우림건설", "우림건설(주)"],
    "유원건설": ["유원건설", "유원건설(주)", '울트라건설', '울트라건설(주)', "유원울트라", "유원"],
    "월드건설": ['월드건설', '월드건설(주)'],
    '인정건설' : ['인정건설', '인정건설(주)'],
    "흥화건설": ["흥화공업", "흥화공업(주)"],
    "한솔건설": ["한솔"],
    "한보건설": ["한보", "한보철강", "한보철강", '한보철상'],
    "고려개발": ["고려개발 "],
    "동양메이저건설": ["동양메이저(주)", "동양고속건설주식회사", "동양메이저"],
    "동일건설": ["동일토건", "동일하이빌", "동일", "동일하이빌"],
    "두산건설": ["두산", "두산중공업"],
    "미주건설": ["미주실업주식회사", "미주실업"],
    "벽산건설": ["벽산건설(주)"],
    "삼익건설": ["삼익주택(주)", "삼익주택", "삼익주택(주)", "삼익건설(주)", "unknown, 삼익건설", "청담삼익아파트"],
    "삼정건설": ["삼정기업"],
    "삼환건설": ["삼환기업", "삼환"],
    "세양건설": ["세양건설산업"],
    "신동아건설": ['신동아'],
    "양우건설": ['양우건설(주)', "양우건설사"],
    "우성건설": ["우성"],
    "우정건설": ["우정건설 주식회사", "우정건설, unknown"],
    "중앙건설": ["중앙하이츠", "중앙건설(주)"],
    "진흥건설": ["진흥기업", "진흥연립재건축조합", "진흥기업", "(주)진흥기업", "진흥기업", "진흥기업(주)", "진흥기업"],
    '풍림건설': ['풍림산업(주)', '풍림산업'],
    "신일건업": ['신일산업', '(주)신일건업'],
    "동일건설": ['동일토건', '동일'],
    '세양건설': ['세양건설산업(주)'],
    '라이프건설' : ['라이프주택'],
    '미주건설' : ['미주실업'],
    '선경건설' : ['선경'],
    "unknown" : ['(주)', '주식회사', '건설', 'nan', '박연정', '재건축조합']
}

# (주) 제거하는 함수
def remove_corporate_suffix(name):
    return name.replace('(주)', '').strip()

# 여러 구분자를 처리하는 정규 표현식 패턴
def split_builders(builders):
    pattern = re.compile(r'[\/,\s]+')
    return pattern.split(builders.strip())

# 동의어 대체 함수
def replace_synonyms(value, synonyms_dict):
    for key, values in synonyms_dict.items():
        if value in values:
            return key
    return value

# 여러 문자열을 처리하는 함수
def process_builders(builders, synonyms_dict):
    builders_list = split_builders(builders)
    processed_list = [replace_synonyms(builder, synonyms_dict) for builder in builders_list]
    return ', '.join(processed_list)


# 문자열이 아닌 값을 문자열로 변환
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].apply(lambda x: str(x) if not isinstance(x, str) else x)

# (주) 제거
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].apply(remove_corporate_suffix)

# 동의어 처리 및 리스트를 문자열로 변환
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].apply(lambda x: process_builders(x, synonyms))

# %%
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].replace({
    'GS건설, unknown': 'GS건설',
    'GS자이, unknown': 'GS건설',
    'unknown, 삼익건설' : '삼익건설',
    'unknown, 서희건설' : '서희건설',
    '고려산업개발' : '고려개발',
    "sh, 공사" : "SH공사",
    "동일토건" : "동일건설",
    "동일하이빌" : "동일건설",
    "두산건설주식회사" : "두산건설",
    "미주실업주식회사" : "미주건설",
    "삼성물산, 건설부문" : "삼성물산",
    "삼성물산, 주택부문" : "삼성물산",
    "삼호" : "삼호건설",
    "서광건설산업" : "서광건설",
    "세양건설산업" : "세양건설",
    "신동아건설, unknown" : "신동아건설",
    "우정건설, unknown" : "우정건설",
    "주시회사, 현대건설" : "현대건설",
    "지에스, unknown" : "GS건설",
    "포스코건설, 포스코A&C" : "포스코건설",
    "현대건설, 주" : "현대건설"
})

# %%
# 1. target 컬럼값의 로그 변환
total_df["log_target"] = np.log1p(total_df["target"])

# 2. 변환된 target 값의 평균 계산
builder_mean_target = total_df.groupby("k-건설사(시공사)")["log_target"].mean()

# 3. 평균 로그 변환 가격에 따라 랭킹을 매깁니다 (값이 높을수록 높은 랭크)
builder_rankings = builder_mean_target.rank(ascending=False)

# 4. 건설사별 랭킹을 딕셔너리로 변환
builder_rankings_dict = builder_rankings.to_dict()

# 5. df에 '건설사랭크' 컬럼 추가
total_df["건설사랭크"] = total_df["k-건설사(시공사)"].map(builder_rankings_dict)
total_df = total_df.drop(columns=['log_target'])

# %%
display(total_df.shape)
display(total_df.columns)
display(total_df.head())
# Out:
# (1128094, 20)
# Index(['시군구', '번지', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-건설사(시공사)', 'target', 'is_test', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP', '한국은행 기준금리', '세대별_주차대수',
#        '건설사랭크'],
#       dtype='object')
#              시군구     번지    아파트명   전용면적    계약년월  계약일  층  건축년도    도로명  \
# 0  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712    8  3  1987  언주로 3
# 1  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712   22  4  1987  언주로 3
# 2  서울특별시 강남구 개포동  658-1  개포6차우성  54.98  201712   28  5  1987  언주로 3
# 3  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    3  4  1987  언주로 3
# 4  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    8  2  1987  언주로 3
#
#   k-건설사(시공사)    target  is_test    가장 가까운 거리  인근 지하철 역 개수  가장 가까운 버스 정류장 거리  \
# 0       우성건설  124000.0        0  1127.738351          2.0          61.89584
# 1       우성건설  123500.0        0  1127.738351          2.0          61.89584
# 2       우성건설   91500.0        0  1127.738351          2.0          61.89584
# 3       우성건설  130000.0        0  1127.738351          2.0          61.89584
# 4       우성건설  117000.0        0  1127.738351          2.0          61.89584
#
#    인근 버스 정류장 개수        GDP  한국은행 기준금리  세대별_주차대수  건설사랭크
# 0           7.0  1623074.1        1.5   0.97037  106.0
# 1           7.0  1623074.1        1.5   0.97037  106.0
# 2           7.0  1623074.1        1.5   0.97037  106.0
# 3           7.0  1725373.4        1.5   0.97037  106.0
# 4           7.0  1725373.4        1.5   0.97037  106.0

# %% [markdown]
# ## train과 test의 분포 맞춰주기

# %%
total_df.drop(columns=['계약일', '층', '건축년도', 'k-건설사(시공사)'], axis=1, inplace=True)
total_df = total_df.rename(columns={'가장 가까운 거리' : '최근접_지하철역_거리',
                                    '인근 지하철 역 개수' : '인근_지하철역_개수',
                                    '가장 가까운 버스 정류장 거리' : '최근접_버스정류장_거리',
                                    '인근 버스 정류장 개수' : '인근_버스정류장_개수',
                                    '한국은행 기준금리' : '기준금리'})

# %%
train_df = total_df[total_df['is_test'] == 0]
test_df = total_df[total_df['is_test'] == 1]

train_df = train_df.drop(columns=['is_test'])
test_df = test_df.drop(columns=['is_test', 'target'])
print(train_df.shape, test_df.shape)
# Out:
# (1118822, 15) (9272, 14)

# %%
# train_df = train_df[train_df['아파트명'].isin(test_df['아파트명'])]
# train_df = train_df[train_df['도로명'].isin(test_df['도로명'])]
# train_df = train_df[train_df['번지'].isin(test_df['번지'])]
# train_df = train_df[train_df['시군구'].isin(test_df['시군구'])]

# for index, row in train_df.iterrows():
#     if pd.isnull(row['아파트명']):
#         corresponding_value = test_df[test_df['아파트명'] == row['아파트명']]['아파트명'].values
#         if len(corresponding_value) > 0:
#             train_df.at[index, '아파트명'] = corresponding_value[0]

train_df.drop(columns=['시군구', '번지', '아파트명', '도로명'], axis=1, inplace=True)
test_df.drop(columns=['시군구', '번지', '아파트명', '도로명'], axis=1, inplace=True)
display(train_df.shape, test_df.shape)
# Out:
# (1118822, 11)
# (9272, 10)

# %% [markdown]
# ## 분포확인

# %% [markdown]
# ### target

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_df['target'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(np.log(train_df['target']), bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of target')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
train_df['target'] = np.log(train_df['target'])

# %% [markdown]
# ### 전용면적

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_df['전용면적'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log(train_df['전용면적']), bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['전용면적_minmax'] = scaler.fit_transform(np.log(train_df['전용면적']).values.reshape(-1, 1))
test_df['전용면적_minmax'] = scaler.transform(np.log(test_df['전용면적']).values.reshape(-1, 1))

print(train_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax'],
#       dtype='object')

# %%
plt.hist(train_df['전용면적_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 계약년월

# %%
plt.hist(train_df['계약년월'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 계약년월')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['계약년월_minmax'] = scaler.fit_transform(train_df['계약년월'].values.reshape(-1, 1))
test_df['계약년월_minmax'] = scaler.transform(test_df['계약년월'].values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['계약년월_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 계약년월_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax'],
#       dtype='object')

# %% [markdown]
# ### 최근접_지하철역_거리

# %%
plt.hist(train_df['최근접_지하철역_거리'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_지하철역_거리')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log(train_df['최근접_지하철역_거리']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_지하철역_거리_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['최근접_지하철역_거리_minmax'] = scaler.fit_transform(np.log(train_df['최근접_지하철역_거리']).values.reshape(-1, 1))
test_df['최근접_지하철역_거리_minmax'] = scaler.transform(np.log(test_df['최근접_지하철역_거리']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['최근접_지하철역_거리_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_지하철역_거리_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax'],
#       dtype='object')

# %% [markdown]
# ### 인근_지하쳘역_개수

# %%
plt.hist(train_df['인근_지하철역_개수'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log1p(train_df['인근_지하철역_개수']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box-Cox 변환을 위한 람다 값들
lambdas = [-5, -4, -3, -2, -1, -0.5, 0]

# Box-Cox 변환된 데이터 분포
for i, lam in enumerate(lambdas):
    transformed_data = stats.boxcox(train_df['인근_지하철역_개수'] + 1, lmbda=lam)
    plt.subplot(3, 3, i + 2)
    plt.hist(transformed_data, bins=30, edgecolor='k', alpha=0.7)
    plt.title(f'Box-Cox Transformed (λ={lam})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
scaler = MinMaxScaler()
train_df['인근_지하철역_개수_minmax'] = scaler.fit_transform(np.log1p(train_df['인근_지하철역_개수']).values.reshape(-1, 1))
test_df['인근_지하철역_개수_minmax'] = scaler.transform(np.log1p(test_df['인근_지하철역_개수']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['인근_지하철역_개수_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax'],
#       dtype='object')

# %% [markdown]
# ### 최근접_버스정류장_거리

# %%
plt.hist(train_df['최근접_버스정류장_거리'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_버스정류장_거리')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.sqrt(train_df['최근접_버스정류장_거리']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_버스정류장_거리_sqrt')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log(train_df['최근접_버스정류장_거리']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_버스정류장_거리_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box-Cox 변환을 위한 람다 값들
lambdas = [-5, -4, -3, -2, -1, -0.5, 0]

# Box-Cox 변환된 데이터 분포
for i, lam in enumerate(lambdas):
    transformed_data = stats.boxcox(train_df['최근접_버스정류장_거리'] + 1, lmbda=lam)
    plt.subplot(3, 3, i + 2)
    plt.hist(transformed_data, bins=30, edgecolor='k', alpha=0.7)
    plt.title(f'Box-Cox Transformed (λ={lam})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
scaler = MinMaxScaler()
train_df['최근접_버스정류장_거리_minmax'] = scaler.fit_transform(np.log1p(train_df['최근접_버스정류장_거리']).values.reshape(-1, 1))
test_df['최근접_버스정류장_거리_minmax'] = scaler.transform(np.log1p(test_df['최근접_버스정류장_거리']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['인근_지하철역_개수_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax'],
#       dtype='object')

# %% [markdown]
# ### 인근_버스정류장_개수

# %%
plt.hist(train_df['인근_버스정류장_개수'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_버스정류장_개수')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box-Cox 변환을 위한 람다 값들
lambdas = [-3, -2, -1, -0.5, 0, 1, 2]

# Box-Cox 변환된 데이터 분포
for i, lam in enumerate(lambdas):
    transformed_data = stats.boxcox(train_df['인근_버스정류장_개수'] + 1, lmbda=lam)
    plt.subplot(3, 3, i + 2)
    plt.hist(transformed_data, bins=30, edgecolor='k', alpha=0.7)
    plt.title(f'Box-Cox Transformed (λ={lam})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.hist(np.log1p(train_df['인근_버스정류장_개수']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_버스정류장_개수_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['인근_버스정류장_개수_minmax'] = scaler.fit_transform(np.log1p(train_df['인근_버스정류장_개수']).values.reshape(-1, 1))
test_df['인근_버스정류장_개수_minmax'] = scaler.transform(np.log1p(test_df['인근_버스정류장_개수']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['인근_버스정류장_개수_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_버스정류장_개수_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %% [markdown]
# ### GDP

# %%
plt.hist(train_df['GDP'], edgecolor='k', alpha=0.7)
plt.title('Distribution of GDP')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 기준금리

# %%
plt.hist(train_df['기준금리'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 기준금리')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
train_df['기준금리'].value_counts()
# Out:
# 기준금리
# 1.50    222528
# 1.25    197841
# 2.00    129110
# 2.50    110503
# 0.50     92302
# 5.00     75066
# 1.75     63335
# 3.25     49756
# 2.75     47276
# 2.25     31690
# 4.50     26577
# 3.00     23047
# 3.50     17548
# 0.75     17018
# 4.75      5735
# 5.25      4223
# 1.00      2609
# 4.25      1496
# 4.00      1162
# Name: count, dtype: int64

# %% [markdown]
# ### 세대별_주차대수

# %%
plt.hist(train_df['세대별_주차대수'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 세대별_주차대수')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 건설사랭크

# %%
plt.hist(train_df['건설사랭크'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 건설사랭크')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['건설사랭크'] = scaler.fit_transform(np.log1p(train_df['건설사랭크']).values.reshape(-1, 1))
test_df['건설사랭크'] = scaler.transform(np.log1p(test_df['건설사랭크']).values.reshape(-1, 1))

print(train_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %%
plt.hist(train_df['건설사랭크'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 건설사랭크')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
for column in train_df.columns:
    plt.figure(figsize=(10, 6))
    
    if pd.api.types.is_numeric_dtype(train_df[column]):
        # 연속형 변수일 경우 히스토그램
        plt.hist(train_df[column], bins=10, edgecolor='k', alpha=0.7)
        plt.title(f'{column}의 분포도')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        
    else:
        # 범주형 변수일 경우 막대 그래프
        train_df[column].value_counts().plot(kind='bar', edgecolor='k', alpha=0.7)
        plt.title(f'{column}의 분포도')
        plt.xlabel(column)
        plt.ylabel('Frequency')
    
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Training

# %%
display(train_df.columns)
display(test_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')
# Index(['전용면적', '계약년월', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %%
display(train_df.shape, test_df.shape)
# Out:
# (1118822, 17)
# (9272, 16)

# %%
train_X = train_df.drop(['target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리', '인근_버스정류장_개수'], axis=1)
train_y = train_df[['target']]

display(train_X.columns)
# Out:
# Index(['전용면적', '계약년월', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %%
test_df.drop(columns=['최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리', '인근_버스정류장_개수'], axis=1, inplace=True)
display(test_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %%
params = {
    'n_estimators': 100000,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'metric_freq': 20,
    'device': 'gpu',
    'verbosity': 0
}

# KFold 설정
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# KFold 교차 검증 수행
fold = 1
models = []  # 각 fold에서 학습된 모델을 저장할 리스트
for train_index, valid_index in kf.split(train_X):
    X_train, X_valid = train_X.iloc[train_index], train_X.iloc[valid_index]
    y_train, y_valid = train_y.iloc[train_index], train_y.iloc[valid_index]
    
    model = lgb.LGBMRegressor(**params)
    
    model.fit(
        X_train, y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        eval_metric='rmse',
        callbacks=[lgb.early_stopping(stopping_rounds=60), lgb.log_evaluation(period=10, show_stdv=True)]
    )
    
    models.append(model)
    print(f"Fold {fold} finished.")
    fold += 1
# Out:
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 0.405634	valid_1's rmse: 0.406259
# [20]	training's rmse: 0.34122	valid_1's rmse: 0.34152
# [30]	training's rmse: 0.316106	valid_1's rmse: 0.316305
# [40]	training's rmse: 0.303556	valid_1's rmse: 0.303707
# [50]	training's rmse: 0.294689	valid_1's rmse: 0.29485
# [60]	training's rmse: 0.286858	valid_1's rmse: 0.287068
# [70]	training's rmse: 0.281813	valid_1's rmse: 0.282121
# [80]	training's rmse: 0.276983	valid_1's rmse: 0.277399
# [90]	training's rmse: 0.273214	valid_1's rmse: 0.273693
# [100]	training's rmse: 0.268878	valid_1's rmse: 0.269439
# [110]	training's rmse: 0.265192	valid_1's rmse: 0.265753
# [120]	training's rmse: 0.260821	valid_1's rmse: 0.261322
# [130]	training's rmse: 0.255259	valid_1's rmse: 0.25585
# [140]	training's rmse: 0.251209	valid_1's rmse: 0.251818
# [150]	training's rmse: 0.24863	valid_1's rmse: 0.249241
# [160]	training's rmse: 0.244822	valid_1's rmse: 0.245478
# [170]	training's rmse: 0.241335	valid_1's rmse: 0.241977
# [180]	training's rmse: 0.238112	valid_1's rmse: 0.238795
# [190]	training's rmse: 0.236036	valid_1's rmse: 0.23677
# [200]	training's rmse: 0.233548	valid_1's rmse: 0.234356
# [210]	training's rmse: 0.231328	valid_1's rmse: 0.232122
# [220]	training's rmse: 0.229017	valid_1's rmse: 0.229866
# [230]	training's rmse: 0.226594	valid_1's rmse: 0.227461
# [240]	training's rmse: 0.223795	valid_1's rmse: 0.224701
# [250]	training's rmse: 0.221941	valid_1's rmse: 0.222883
# [260]	training's rmse: 0.22055	valid_1's rmse: 0.22155
# [270]	training's rmse: 0.218607	valid_1's rmse: 0.219626
# [280]	training's rmse: 0.217093	valid_1's rmse: 0.21819
# [290]	training's rmse: 0.215358	valid_1's rmse: 0.216465
# [300]	training's rmse: 0.213459	valid_1's rmse: 0.214582
# [310]	training's rmse: 0.211882	valid_1's rmse: 0.213053
# [320]	training's rmse: 0.210272	valid_1's rmse: 0.211455
# [330]	training's rmse: 0.208472	valid_1's rmse: 0.209731
# [340]	training's rmse: 0.207253	valid_1's rmse: 0.208531
# [350]	training's rmse: 0.205633	valid_1's rmse: 0.206965
# [360]	training's rmse: 0.20432	valid_1's rmse: 0.205665
# [370]	training's rmse: 0.202354	valid_1's rmse: 0.203754
# [380]	training's rmse: 0.200708	valid_1's rmse: 0.202158
# [390]	training's rmse: 0.199627	valid_1's rmse: 0.20112
# [400]	training's rmse: 0.198253	valid_1's rmse: 0.199733
# [410]	training's rmse: 0.197192	valid_1's rmse: 0.198678
# [420]	training's rmse: 0.195924	valid_1's rmse: 0.197431
# [430]	training's rmse: 0.194844	valid_1's rmse: 0.196351
# [440]	training's rmse: 0.193998	valid_1's rmse: 0.195539
# [450]	training's rmse: 0.192715	valid_1's rmse: 0.194316
# [460]	training's rmse: 0.191662	valid_1's rmse: 0.193277
# [470]	training's rmse: 0.190787	valid_1's rmse: 0.192363
# [480]	training's rmse: 0.189841	valid_1's rmse: 0.19146
# [490]	training's rmse: 0.188812	valid_1's rmse: 0.190437
# [500]	training's rmse: 0.187648	valid_1's rmse: 0.189306
# [510]	training's rmse: 0.18661	valid_1's rmse: 0.188305
# [520]	training's rmse: 0.185634	valid_1's rmse: 0.187332
# [530]	training's rmse: 0.184843	valid_1's rmse: 0.186579
# [540]	training's rmse: 0.183858	valid_1's rmse: 0.185626
# [550]	training's rmse: 0.183101	valid_1's rmse: 0.184922
# [560]	training's rmse: 0.182352	valid_1's rmse: 0.184174
# [570]	training's rmse: 0.181389	valid_1's rmse: 0.183197
# [580]	training's rmse: 0.180596	valid_1's rmse: 0.182464
# [590]	training's rmse: 0.179838	valid_1's rmse: 0.181719
# [600]	training's rmse: 0.179206	valid_1's rmse: 0.181131
# [610]	training's rmse: 0.178442	valid_1's rmse: 0.180408
# [620]	training's rmse: 0.177729	valid_1's rmse: 0.179733
# [630]	training's rmse: 0.176628	valid_1's rmse: 0.178646
# [640]	training's rmse: 0.175952	valid_1's rmse: 0.177994
# [650]	training's rmse: 0.175139	valid_1's rmse: 0.177208
# [660]	training's rmse: 0.17424	valid_1's rmse: 0.176338
# [670]	training's rmse: 0.173634	valid_1's rmse: 0.175736
# [680]	training's rmse: 0.17284	valid_1's rmse: 0.174971
# [690]	training's rmse: 0.172256	valid_1's rmse: 0.174417
# [700]	training's rmse: 0.171621	valid_1's rmse: 0.173809
# [710]	training's rmse: 0.171109	valid_1's rmse: 0.173273
# [720]	training's rmse: 0.170603	valid_1's rmse: 0.172761
# [730]	training's rmse: 0.16972	valid_1's rmse: 0.171912
# [740]	training's rmse: 0.168928	valid_1's rmse: 0.171146
# [750]	training's rmse: 0.168299	valid_1's rmse: 0.170547
# [760]	training's rmse: 0.167501	valid_1's rmse: 0.169787
# [770]	training's rmse: 0.166932	valid_1's rmse: 0.169237
# [780]	training's rmse: 0.166354	valid_1's rmse: 0.168683
# [790]	training's rmse: 0.165735	valid_1's rmse: 0.168095
# [800]	training's rmse: 0.165341	valid_1's rmse: 0.167738
# [810]	training's rmse: 0.164798	valid_1's rmse: 0.167232
# [820]	training's rmse: 0.164218	valid_1's rmse: 0.166676
# [830]	training's rmse: 0.163399	valid_1's rmse: 0.165873
# [840]	training's rmse: 0.1628	valid_1's rmse: 0.165262
# [850]	training's rmse: 0.162214	valid_1's rmse: 0.164715
# [860]	training's rmse: 0.161618	valid_1's rmse: 0.164135
# [870]	training's rmse: 0.160969	valid_1's rmse: 0.163558
# [880]	training's rmse: 0.160152	valid_1's rmse: 0.162745
# [890]	training's rmse: 0.159622	valid_1's rmse: 0.162237
# [900]	training's rmse: 0.159074	valid_1's rmse: 0.161699
# [910]	training's rmse: 0.158507	valid_1's rmse: 0.161159
# [920]	training's rmse: 0.157991	valid_1's rmse: 0.160653
# [930]	training's rmse: 0.157417	valid_1's rmse: 0.160092
# [940]	training's rmse: 0.156835	valid_1's rmse: 0.159558
# [950]	training's rmse: 0.156297	valid_1's rmse: 0.159017
# [960]	training's rmse: 0.155791	valid_1's rmse: 0.158539
# [970]	training's rmse: 0.155288	valid_1's rmse: 0.158062
# [980]	training's rmse: 0.154913	valid_1's rmse: 0.157716
# [990]	training's rmse: 0.154248	valid_1's rmse: 0.157063
# [1000]	training's rmse: 0.153919	valid_1's rmse: 0.156772
# [1010]	training's rmse: 0.153363	valid_1's rmse: 0.156243
# [1020]	training's rmse: 0.152867	valid_1's rmse: 0.155739
# [1030]	training's rmse: 0.152464	valid_1's rmse: 0.155376
# [1040]	training's rmse: 0.152077	valid_1's rmse: 0.155014
# [1050]	training's rmse: 0.151564	valid_1's rmse: 0.154518
# [1060]	training's rmse: 0.151074	valid_1's rmse: 0.154048
# [1070]	training's rmse: 0.15051	valid_1's rmse: 0.153478
# [1080]	training's rmse: 0.150127	valid_1's rmse: 0.153113
# [1090]	training's rmse: 0.149849	valid_1's rmse: 0.15286
# [1100]	training's rmse: 0.149334	valid_1's rmse: 0.152369
# [1110]	training's rmse: 0.148894	valid_1's rmse: 0.151953
# [1120]	training's rmse: 0.148373	valid_1's rmse: 0.151473
# [1130]	training's rmse: 0.147934	valid_1's rmse: 0.151065
# [1140]	training's rmse: 0.147544	valid_1's rmse: 0.150695
# [1150]	training's rmse: 0.147261	valid_1's rmse: 0.150442
# [1160]	training's rmse: 0.146646	valid_1's rmse: 0.149876
# [1170]	training's rmse: 0.146299	valid_1's rmse: 0.149543
# [1180]	training's rmse: 0.146069	valid_1's rmse: 0.149335
# [1190]	training's rmse: 0.145402	valid_1's rmse: 0.14867
# [1200]	training's rmse: 0.144976	valid_1's rmse: 0.148253
# [1210]	training's rmse: 0.144652	valid_1's rmse: 0.147925
# [1220]	training's rmse: 0.14422	valid_1's rmse: 0.147536
# [1230]	training's rmse: 0.143673	valid_1's rmse: 0.146979
# [1240]	training's rmse: 0.143366	valid_1's rmse: 0.146694
# [1250]	training's rmse: 0.143016	valid_1's rmse: 0.146362
# [1260]	training's rmse: 0.142658	valid_1's rmse: 0.14601
# [1270]	training's rmse: 0.142266	valid_1's rmse: 0.145648
# [1280]	training's rmse: 0.14193	valid_1's rmse: 0.145334
# [1290]	training's rmse: 0.141666	valid_1's rmse: 0.145093
# [1300]	training's rmse: 0.141423	valid_1's rmse: 0.144877
# [1310]	training's rmse: 0.140988	valid_1's rmse: 0.144478
# [1320]	training's rmse: 0.140654	valid_1's rmse: 0.144172
# [1330]	training's rmse: 0.140295	valid_1's rmse: 0.143868
# [1340]	training's rmse: 0.13989	valid_1's rmse: 0.143484
# [1350]	training's rmse: 0.139442	valid_1's rmse: 0.143062
# [1360]	training's rmse: 0.138949	valid_1's rmse: 0.142577
# [1370]	training's rmse: 0.138575	valid_1's rmse: 0.142243
# [1380]	training's rmse: 0.138223	valid_1's rmse: 0.141918
# [1390]	training's rmse: 0.138004	valid_1's rmse: 0.141698
# [1400]	training's rmse: 0.137673	valid_1's rmse: 0.141395
# [1410]	training's rmse: 0.137367	valid_1's rmse: 0.141113
# [1420]	training's rmse: 0.137116	valid_1's rmse: 0.140885
# [1430]	training's rmse: 0.136712	valid_1's rmse: 0.140501
# [1440]	training's rmse: 0.13645	valid_1's rmse: 0.140273
# [1450]	training's rmse: 0.136082	valid_1's rmse: 0.139934
# [1460]	training's rmse: 0.135685	valid_1's rmse: 0.139544
# [1470]	training's rmse: 0.135234	valid_1's rmse: 0.139114
# [1480]	training's rmse: 0.134837	valid_1's rmse: 0.138733
# [1490]	training's rmse: 0.134492	valid_1's rmse: 0.138392
# [1500]	training's rmse: 0.134126	valid_1's rmse: 0.138045
# [1510]	training's rmse: 0.133849	valid_1's rmse: 0.137782
# [1520]	training's rmse: 0.133588	valid_1's rmse: 0.137531
# [1530]	training's rmse: 0.133321	valid_1's rmse: 0.137291
# [1540]	training's rmse: 0.13306	valid_1's rmse: 0.137047
# [1550]	training's rmse: 0.132769	valid_1's rmse: 0.136779
# [1560]	training's rmse: 0.132421	valid_1's rmse: 0.136456
# [1570]	training's rmse: 0.132137	valid_1's rmse: 0.136192
# [1580]	training's rmse: 0.131693	valid_1's rmse: 0.135796
# [1590]	training's rmse: 0.131453	valid_1's rmse: 0.135571
# [1600]	training's rmse: 0.131136	valid_1's rmse: 0.135262
# [1610]	training's rmse: 0.130832	valid_1's rmse: 0.134995
# [1620]	training's rmse: 0.130464	valid_1's rmse: 0.134638
# [1630]	training's rmse: 0.130239	valid_1's rmse: 0.134432
# [1640]	training's rmse: 0.129913	valid_1's rmse: 0.134124
# [1650]	training's rmse: 0.129668	valid_1's rmse: 0.133886
# [1660]	training's rmse: 0.129372	valid_1's rmse: 0.133616
# [1670]	training's rmse: 0.129135	valid_1's rmse: 0.133393
# [1680]	training's rmse: 0.128935	valid_1's rmse: 0.133197
# [1690]	training's rmse: 0.128634	valid_1's rmse: 0.132937
# [1700]	training's rmse: 0.128422	valid_1's rmse: 0.132735
# [1710]	training's rmse: 0.128162	valid_1's rmse: 0.132502
# [1720]	training's rmse: 0.127906	valid_1's rmse: 0.132268
# [1730]	training's rmse: 0.127753	valid_1's rmse: 0.132129
# [1740]	training's rmse: 0.12758	valid_1's rmse: 0.131971
# [1750]	training's rmse: 0.127308	valid_1's rmse: 0.131726
# [1760]	training's rmse: 0.127085	valid_1's rmse: 0.131524
# [1770]	training's rmse: 0.126847	valid_1's rmse: 0.131309
# [1780]	training's rmse: 0.126502	valid_1's rmse: 0.130961
# [1790]	training's rmse: 0.126305	valid_1's rmse: 0.130782
# [1800]	training's rmse: 0.126179	valid_1's rmse: 0.130672
# [1810]	training's rmse: 0.125944	valid_1's rmse: 0.130462
# [1820]	training's rmse: 0.125686	valid_1's rmse: 0.130227
# [1830]	training's rmse: 0.125517	valid_1's rmse: 0.130086
# [1840]	training's rmse: 0.125373	valid_1's rmse: 0.129953
# [1850]	training's rmse: 0.125137	valid_1's rmse: 0.129726
# [1860]	training's rmse: 0.124909	valid_1's rmse: 0.129508
# [1870]	training's rmse: 0.12453	valid_1's rmse: 0.129145
# [1880]	training's rmse: 0.124292	valid_1's rmse: 0.12892
# [1890]	training's rmse: 0.124119	valid_1's rmse: 0.128766
# [1900]	training's rmse: 0.123901	valid_1's rmse: 0.128579
# [1910]	training's rmse: 0.123689	valid_1's rmse: 0.128392
# [1920]	training's rmse: 0.123509	valid_1's rmse: 0.128231
# [1930]	training's rmse: 0.123257	valid_1's rmse: 0.128012
# [1940]	training's rmse: 0.123067	valid_1's rmse: 0.127839
# [1950]	training's rmse: 0.122887	valid_1's rmse: 0.127664
# [1960]	training's rmse: 0.122703	valid_1's rmse: 0.127508
# [1970]	training's rmse: 0.122433	valid_1's rmse: 0.127236
# [1980]	training's rmse: 0.122304	valid_1's rmse: 0.127132
# [1990]	training's rmse: 0.122094	valid_1's rmse: 0.126965
# [2000]	training's rmse: 0.121876	valid_1's rmse: 0.126752
# [2010]	training's rmse: 0.12163	valid_1's rmse: 0.12654
# [2020]	training's rmse: 0.121485	valid_1's rmse: 0.126406
# [2030]	training's rmse: 0.121295	valid_1's rmse: 0.126244
# [2040]	training's rmse: 0.121139	valid_1's rmse: 0.126116
# [2050]	training's rmse: 0.120993	valid_1's rmse: 0.125979
# [2060]	training's rmse: 0.120693	valid_1's rmse: 0.125692
# [2070]	training's rmse: 0.120543	valid_1's rmse: 0.125561
# [2080]	training's rmse: 0.120427	valid_1's rmse: 0.125452
# [2090]	training's rmse: 0.120225	valid_1's rmse: 0.125272
# [2100]	training's rmse: 0.120001	valid_1's rmse: 0.125074
# [2110]	training's rmse: 0.119783	valid_1's rmse: 0.124861
# [2120]	training's rmse: 0.11955	valid_1's rmse: 0.124642
# [2130]	training's rmse: 0.119337	valid_1's rmse: 0.124444
# [2140]	training's rmse: 0.119098	valid_1's rmse: 0.124227
# [2150]	training's rmse: 0.118939	valid_1's rmse: 0.124077
# [2160]	training's rmse: 0.118724	valid_1's rmse: 0.123874
# [2170]	training's rmse: 0.118501	valid_1's rmse: 0.123667
# [2180]	training's rmse: 0.118241	valid_1's rmse: 0.123431
# [2190]	training's rmse: 0.118013	valid_1's rmse: 0.123214
# [2200]	training's rmse: 0.117852	valid_1's rmse: 0.123057
# [2210]	training's rmse: 0.117688	valid_1's rmse: 0.12291
# [2220]	training's rmse: 0.11745	valid_1's rmse: 0.122693
# [2230]	training's rmse: 0.117319	valid_1's rmse: 0.122575
# [2240]	training's rmse: 0.117155	valid_1's rmse: 0.122425
# [2250]	training's rmse: 0.116978	valid_1's rmse: 0.122251
# [2260]	training's rmse: 0.116815	valid_1's rmse: 0.12209
# [2270]	training's rmse: 0.116573	valid_1's rmse: 0.121858
# [2280]	training's rmse: 0.116389	valid_1's rmse: 0.121683
# [2290]	training's rmse: 0.116185	valid_1's rmse: 0.121499
# [2300]	training's rmse: 0.116017	valid_1's rmse: 0.121336
# [2310]	training's rmse: 0.115891	valid_1's rmse: 0.121231
# [2320]	training's rmse: 0.115691	valid_1's rmse: 0.121042
# [2330]	training's rmse: 0.115461	valid_1's rmse: 0.120849
# [2340]	training's rmse: 0.115257	valid_1's rmse: 0.120647
# [2350]	training's rmse: 0.115146	valid_1's rmse: 0.120549
# [2360]	training's rmse: 0.115029	valid_1's rmse: 0.120455
# [2370]	training's rmse: 0.114733	valid_1's rmse: 0.120181
# [2380]	training's rmse: 0.114572	valid_1's rmse: 0.12003
# [2390]	training's rmse: 0.114379	valid_1's rmse: 0.11986
# [2400]	training's rmse: 0.114265	valid_1's rmse: 0.119758
# [2410]	training's rmse: 0.114069	valid_1's rmse: 0.119576
# [2420]	training's rmse: 0.113967	valid_1's rmse: 0.119487
# [2430]	training's rmse: 0.113786	valid_1's rmse: 0.119316
# [2440]	training's rmse: 0.113679	valid_1's rmse: 0.119233
# [2450]	training's rmse: 0.113549	valid_1's rmse: 0.119112
# [2460]	training's rmse: 0.113409	valid_1's rmse: 0.11899
# [2470]	training's rmse: 0.113282	valid_1's rmse: 0.118879
# [2480]	training's rmse: 0.113085	valid_1's rmse: 0.118714
# [2490]	training's rmse: 0.112993	valid_1's rmse: 0.118635
# [2500]	training's rmse: 0.112891	valid_1's rmse: 0.118541
# [2510]	training's rmse: 0.112772	valid_1's rmse: 0.118441
# [2520]	training's rmse: 0.112566	valid_1's rmse: 0.118271
# [2530]	training's rmse: 0.112406	valid_1's rmse: 0.118118
# [2540]	training's rmse: 0.112239	valid_1's rmse: 0.117975
# [2550]	training's rmse: 0.112158	valid_1's rmse: 0.117914
# [2560]	training's rmse: 0.111977	valid_1's rmse: 0.117764
# [2570]	training's rmse: 0.111855	valid_1's rmse: 0.117652
# [2580]	training's rmse: 0.111749	valid_1's rmse: 0.117564
# [2590]	training's rmse: 0.111615	valid_1's rmse: 0.117452
# [2600]	training's rmse: 0.111466	valid_1's rmse: 0.117325
# [2610]	training's rmse: 0.11133	valid_1's rmse: 0.117215
# [2620]	training's rmse: 0.111256	valid_1's rmse: 0.117157
# [2630]	training's rmse: 0.11113	valid_1's rmse: 0.117048
# [2640]	training's rmse: 0.110989	valid_1's rmse: 0.11692
# [2650]	training's rmse: 0.110873	valid_1's rmse: 0.116823
# [2660]	training's rmse: 0.110742	valid_1's rmse: 0.116715
# [2670]	training's rmse: 0.110653	valid_1's rmse: 0.116644
# [2680]	training's rmse: 0.11053	valid_1's rmse: 0.116536
# [2690]	training's rmse: 0.110359	valid_1's rmse: 0.116377
# [2700]	training's rmse: 0.110224	valid_1's rmse: 0.116266
# [2710]	training's rmse: 0.110124	valid_1's rmse: 0.116175
# [2720]	training's rmse: 0.110019	valid_1's rmse: 0.116096
# [2730]	training's rmse: 0.109876	valid_1's rmse: 0.115964
# [2740]	training's rmse: 0.109714	valid_1's rmse: 0.115827
# [2750]	training's rmse: 0.109575	valid_1's rmse: 0.115708
# [2760]	training's rmse: 0.109483	valid_1's rmse: 0.115633
# [2770]	training's rmse: 0.109382	valid_1's rmse: 0.115549
# [2780]	training's rmse: 0.109263	valid_1's rmse: 0.115445
# [2790]	training's rmse: 0.109112	valid_1's rmse: 0.115309
# [2800]	training's rmse: 0.108949	valid_1's rmse: 0.115165
# [2810]	training's rmse: 0.108851	valid_1's rmse: 0.115083
# [2820]	training's rmse: 0.108745	valid_1's rmse: 0.114993
# [2830]	training's rmse: 0.108624	valid_1's rmse: 0.114889
# [2840]	training's rmse: 0.10852	valid_1's rmse: 0.114792
# [2850]	training's rmse: 0.108416	valid_1's rmse: 0.114698
# [2860]	training's rmse: 0.108236	valid_1's rmse: 0.114536
# [2870]	training's rmse: 0.108081	valid_1's rmse: 0.114397
# [2880]	training's rmse: 0.108005	valid_1's rmse: 0.114334
# [2890]	training's rmse: 0.107866	valid_1's rmse: 0.114211
# [2900]	training's rmse: 0.107753	valid_1's rmse: 0.114109
# [2910]	training's rmse: 0.107675	valid_1's rmse: 0.114048
# [2920]	training's rmse: 0.10758	valid_1's rmse: 0.113964
# [2930]	training's rmse: 0.107446	valid_1's rmse: 0.113849
# [2940]	training's rmse: 0.107341	valid_1's rmse: 0.113757
# [2950]	training's rmse: 0.107186	valid_1's rmse: 0.113628
# [2960]	training's rmse: 0.107092	valid_1's rmse: 0.113548
# [2970]	training's rmse: 0.106946	valid_1's rmse: 0.113427
# [2980]	training's rmse: 0.106799	valid_1's rmse: 0.113298
# [2990]	training's rmse: 0.106686	valid_1's rmse: 0.113206
# [3000]	training's rmse: 0.106546	valid_1's rmse: 0.113078
# [3010]	training's rmse: 0.106405	valid_1's rmse: 0.112957
# [3020]	training's rmse: 0.106271	valid_1's rmse: 0.112839
# [3030]	training's rmse: 0.10616	valid_1's rmse: 0.11274
# [3040]	training's rmse: 0.106019	valid_1's rmse: 0.112625
# [3050]	training's rmse: 0.105898	valid_1's rmse: 0.11252
# [3060]	training's rmse: 0.105806	valid_1's rmse: 0.112453
# [3070]	training's rmse: 0.10572	valid_1's rmse: 0.112379
# [3080]	training's rmse: 0.105637	valid_1's rmse: 0.112315
# [3090]	training's rmse: 0.105505	valid_1's rmse: 0.112207
# [3100]	training's rmse: 0.105378	valid_1's rmse: 0.112102
# [3110]	training's rmse: 0.105238	valid_1's rmse: 0.111983
# [3120]	training's rmse: 0.105094	valid_1's rmse: 0.111858
# [3130]	training's rmse: 0.105016	valid_1's rmse: 0.1118
# [3140]	training's rmse: 0.104902	valid_1's rmse: 0.111711
# [3150]	training's rmse: 0.104785	valid_1's rmse: 0.111615
# [3160]	training's rmse: 0.104682	valid_1's rmse: 0.111539
# [3170]	training's rmse: 0.104544	valid_1's rmse: 0.111425
# [3180]	training's rmse: 0.104461	valid_1's rmse: 0.111351
# [3190]	training's rmse: 0.104348	valid_1's rmse: 0.11125
# [3200]	training's rmse: 0.104251	valid_1's rmse: 0.111168
# [3210]	training's rmse: 0.104189	valid_1's rmse: 0.111113
# [3220]	training's rmse: 0.104103	valid_1's rmse: 0.111044
# [3230]	training's rmse: 0.104	valid_1's rmse: 0.110953
# [3240]	training's rmse: 0.103934	valid_1's rmse: 0.110905
# [3250]	training's rmse: 0.103843	valid_1's rmse: 0.110826
# [3260]	training's rmse: 0.10376	valid_1's rmse: 0.110754
# [3270]	training's rmse: 0.103701	valid_1's rmse: 0.110705
# [3280]	training's rmse: 0.103578	valid_1's rmse: 0.110593
# [3290]	training's rmse: 0.103506	valid_1's rmse: 0.110535
# [3300]	training's rmse: 0.103398	valid_1's rmse: 0.110444
# [3310]	training's rmse: 0.103302	valid_1's rmse: 0.110371
# [3320]	training's rmse: 0.103212	valid_1's rmse: 0.110295
# [3330]	training's rmse: 0.103133	valid_1's rmse: 0.110228
# [3340]	training's rmse: 0.103001	valid_1's rmse: 0.110105
# [3350]	training's rmse: 0.102898	valid_1's rmse: 0.110027
# [3360]	training's rmse: 0.102819	valid_1's rmse: 0.10996
# [3370]	training's rmse: 0.102755	valid_1's rmse: 0.109906
# [3380]	training's rmse: 0.102692	valid_1's rmse: 0.109859
# [3390]	training's rmse: 0.102606	valid_1's rmse: 0.109784
# [3400]	training's rmse: 0.102481	valid_1's rmse: 0.109674
# [3410]	training's rmse: 0.102361	valid_1's rmse: 0.109563
# [3420]	training's rmse: 0.102215	valid_1's rmse: 0.109433
# [3430]	training's rmse: 0.102111	valid_1's rmse: 0.109337
# [3440]	training's rmse: 0.102006	valid_1's rmse: 0.109245
# [3450]	training's rmse: 0.101906	valid_1's rmse: 0.109165
# [3460]	training's rmse: 0.101806	valid_1's rmse: 0.109083
# [3470]	training's rmse: 0.101717	valid_1's rmse: 0.109015
# [3480]	training's rmse: 0.101644	valid_1's rmse: 0.108961
# [3490]	training's rmse: 0.101571	valid_1's rmse: 0.108901
# [3500]	training's rmse: 0.101464	valid_1's rmse: 0.108812
# [3510]	training's rmse: 0.101344	valid_1's rmse: 0.108694
# [3520]	training's rmse: 0.101208	valid_1's rmse: 0.108572
# [3530]	training's rmse: 0.101162	valid_1's rmse: 0.108546
# [3540]	training's rmse: 0.101066	valid_1's rmse: 0.108467
# [3550]	training's rmse: 0.100966	valid_1's rmse: 0.10838
# [3560]	training's rmse: 0.100917	valid_1's rmse: 0.108341
# [3570]	training's rmse: 0.100822	valid_1's rmse: 0.108267
# [3580]	training's rmse: 0.100731	valid_1's rmse: 0.108188
# [3590]	training's rmse: 0.100623	valid_1's rmse: 0.108099
# [3600]	training's rmse: 0.100527	valid_1's rmse: 0.108015
# [3610]	training's rmse: 0.100452	valid_1's rmse: 0.107961
# [3620]	training's rmse: 0.100377	valid_1's rmse: 0.107911
# [3630]	training's rmse: 0.100281	valid_1's rmse: 0.107821
# [3640]	training's rmse: 0.100206	valid_1's rmse: 0.107758
# [3650]	training's rmse: 0.100073	valid_1's rmse: 0.107645
# [3660]	training's rmse: 0.0999754	valid_1's rmse: 0.107567
# [3670]	training's rmse: 0.0998959	valid_1's rmse: 0.107502
# [3680]	training's rmse: 0.099791	valid_1's rmse: 0.107417
# [3690]	training's rmse: 0.0996897	valid_1's rmse: 0.107342
# [3700]	training's rmse: 0.099601	valid_1's rmse: 0.107272
# [3710]	training's rmse: 0.099532	valid_1's rmse: 0.107225
# [3720]	training's rmse: 0.0994747	valid_1's rmse: 0.107181
# [3730]	training's rmse: 0.0993708	valid_1's rmse: 0.107083
# [3740]	training's rmse: 0.0992998	valid_1's rmse: 0.10704
# [3750]	training's rmse: 0.0992113	valid_1's rmse: 0.106969
# [3760]	training's rmse: 0.0991158	valid_1's rmse: 0.106889
# [3770]	training's rmse: 0.0990544	valid_1's rmse: 0.10684
# [3780]	training's rmse: 0.0989853	valid_1's rmse: 0.106783
# [3790]	training's rmse: 0.0989131	valid_1's rmse: 0.106728
# [3800]	training's rmse: 0.0988202	valid_1's rmse: 0.106641
# [3810]	training's rmse: 0.098721	valid_1's rmse: 0.106559
# [3820]	training's rmse: 0.0986296	valid_1's rmse: 0.106491
# [3830]	training's rmse: 0.0985495	valid_1's rmse: 0.106423
# [3840]	training's rmse: 0.0984349	valid_1's rmse: 0.106326
# [3850]	training's rmse: 0.0983812	valid_1's rmse: 0.106283
# [3860]	training's rmse: 0.0983001	valid_1's rmse: 0.106215
# [3870]	training's rmse: 0.0982335	valid_1's rmse: 0.106166
# [3880]	training's rmse: 0.0981702	valid_1's rmse: 0.106116
# [3890]	training's rmse: 0.098059	valid_1's rmse: 0.106028
# [3900]	training's rmse: 0.0979898	valid_1's rmse: 0.105977
# [3910]	training's rmse: 0.0979062	valid_1's rmse: 0.105905
# [3920]	training's rmse: 0.0978487	valid_1's rmse: 0.105862
# [3930]	training's rmse: 0.0978037	valid_1's rmse: 0.105827
# [3940]	training's rmse: 0.0977315	valid_1's rmse: 0.105771
# [3950]	training's rmse: 0.0976355	valid_1's rmse: 0.105684
# [3960]	training's rmse: 0.0975668	valid_1's rmse: 0.105629
# [3970]	training's rmse: 0.0974938	valid_1's rmse: 0.105571
# [3980]	training's rmse: 0.0974458	valid_1's rmse: 0.105535
# [3990]	training's rmse: 0.0973252	valid_1's rmse: 0.105422
# [4000]	training's rmse: 0.0972527	valid_1's rmse: 0.105366
# [4010]	training's rmse: 0.0971918	valid_1's rmse: 0.105312
# [4020]	training's rmse: 0.0970933	valid_1's rmse: 0.105228
# [4030]	training's rmse: 0.0970078	valid_1's rmse: 0.105157
# [4040]	training's rmse: 0.0969397	valid_1's rmse: 0.105111
# [4050]	training's rmse: 0.096877	valid_1's rmse: 0.105062
# [4060]	training's rmse: 0.0968194	valid_1's rmse: 0.105013
# [4070]	training's rmse: 0.0967585	valid_1's rmse: 0.104975
# [4080]	training's rmse: 0.0967188	valid_1's rmse: 0.104946
# [4090]	training's rmse: 0.0966611	valid_1's rmse: 0.104903
# [4100]	training's rmse: 0.0965896	valid_1's rmse: 0.104845
# [4110]	training's rmse: 0.0965463	valid_1's rmse: 0.104805
# [4120]	training's rmse: 0.0964689	valid_1's rmse: 0.104743
# [4130]	training's rmse: 0.0963876	valid_1's rmse: 0.104681
# [4140]	training's rmse: 0.0963038	valid_1's rmse: 0.104601
# [4150]	training's rmse: 0.0962527	valid_1's rmse: 0.104559
# [4160]	training's rmse: 0.0961879	valid_1's rmse: 0.104502
# [4170]	training's rmse: 0.0960835	valid_1's rmse: 0.104403
# [4180]	training's rmse: 0.096022	valid_1's rmse: 0.104358
# [4190]	training's rmse: 0.0959647	valid_1's rmse: 0.104318
# [4200]	training's rmse: 0.095904	valid_1's rmse: 0.104275
# [4210]	training's rmse: 0.0958227	valid_1's rmse: 0.104207
# [4220]	training's rmse: 0.0957581	valid_1's rmse: 0.104161
# [4230]	training's rmse: 0.0956882	valid_1's rmse: 0.104114
# [4240]	training's rmse: 0.0956138	valid_1's rmse: 0.104045
# [4250]	training's rmse: 0.095549	valid_1's rmse: 0.103998
# [4260]	training's rmse: 0.0954644	valid_1's rmse: 0.103933
# [4270]	training's rmse: 0.0954075	valid_1's rmse: 0.103889
# [4280]	training's rmse: 0.0953441	valid_1's rmse: 0.103832
# [4290]	training's rmse: 0.0952884	valid_1's rmse: 0.10379
# [4300]	training's rmse: 0.095221	valid_1's rmse: 0.103732
# [4310]	training's rmse: 0.0950972	valid_1's rmse: 0.103627
# [4320]	training's rmse: 0.0950178	valid_1's rmse: 0.103563
# [4330]	training's rmse: 0.0949729	valid_1's rmse: 0.103527
# [4340]	training's rmse: 0.0948991	valid_1's rmse: 0.103472
# [4350]	training's rmse: 0.0948406	valid_1's rmse: 0.10343
# [4360]	training's rmse: 0.0947645	valid_1's rmse: 0.103367
# [4370]	training's rmse: 0.0947017	valid_1's rmse: 0.103318
# [4380]	training's rmse: 0.094609	valid_1's rmse: 0.103241
# [4390]	training's rmse: 0.0945414	valid_1's rmse: 0.103183
# [4400]	training's rmse: 0.0944709	valid_1's rmse: 0.103127
# [4410]	training's rmse: 0.0944062	valid_1's rmse: 0.103073
# [4420]	training's rmse: 0.0943363	valid_1's rmse: 0.103017
# [4430]	training's rmse: 0.0942476	valid_1's rmse: 0.102939
# [4440]	training's rmse: 0.0941726	valid_1's rmse: 0.102872
# [4450]	training's rmse: 0.0940996	valid_1's rmse: 0.102816
# [4460]	training's rmse: 0.0940249	valid_1's rmse: 0.102751
# [4470]	training's rmse: 0.0939719	valid_1's rmse: 0.102712
# [4480]	training's rmse: 0.0939142	valid_1's rmse: 0.102671
# [4490]	training's rmse: 0.0938671	valid_1's rmse: 0.102628
# [4500]	training's rmse: 0.0937937	valid_1's rmse: 0.102563
# [4510]	training's rmse: 0.0937408	valid_1's rmse: 0.102527
# [4520]	training's rmse: 0.0936634	valid_1's rmse: 0.102452
# [4530]	training's rmse: 0.0936054	valid_1's rmse: 0.102416
# [4540]	training's rmse: 0.0935463	valid_1's rmse: 0.102372
# [4550]	training's rmse: 0.0934962	valid_1's rmse: 0.102331
# [4560]	training's rmse: 0.0934353	valid_1's rmse: 0.102284
# [4570]	training's rmse: 0.0933479	valid_1's rmse: 0.102215
# [4580]	training's rmse: 0.0932696	valid_1's rmse: 0.102154
# [4590]	training's rmse: 0.0932005	valid_1's rmse: 0.102101
# [4600]	training's rmse: 0.0931424	valid_1's rmse: 0.102054
# [4610]	training's rmse: 0.0930868	valid_1's rmse: 0.102013
# [4620]	training's rmse: 0.0930399	valid_1's rmse: 0.101981
# [4630]	training's rmse: 0.0929801	valid_1's rmse: 0.101931
# [4640]	training's rmse: 0.09292	valid_1's rmse: 0.101884
# [4650]	training's rmse: 0.0928511	valid_1's rmse: 0.101832
# [4660]	training's rmse: 0.0927789	valid_1's rmse: 0.101775
# [4670]	training's rmse: 0.0927338	valid_1's rmse: 0.101743
# [4680]	training's rmse: 0.0926643	valid_1's rmse: 0.101689
# [4690]	training's rmse: 0.0926003	valid_1's rmse: 0.101636
# [4700]	training's rmse: 0.092545	valid_1's rmse: 0.101596
# [4710]	training's rmse: 0.0924875	valid_1's rmse: 0.101553
# [4720]	training's rmse: 0.0924081	valid_1's rmse: 0.101494
# [4730]	training's rmse: 0.0923556	valid_1's rmse: 0.101459
# [4740]	training's rmse: 0.0923041	valid_1's rmse: 0.10142
# [4750]	training's rmse: 0.0922447	valid_1's rmse: 0.101378
# [4760]	training's rmse: 0.092198	valid_1's rmse: 0.101343
# [4770]	training's rmse: 0.0921452	valid_1's rmse: 0.101302
# [4780]	training's rmse: 0.0920818	valid_1's rmse: 0.101254
# [4790]	training's rmse: 0.0920196	valid_1's rmse: 0.101213
# [4800]	training's rmse: 0.0919583	valid_1's rmse: 0.101163
# [4810]	training's rmse: 0.0919048	valid_1's rmse: 0.101121
# [4820]	training's rmse: 0.0918455	valid_1's rmse: 0.101069
# [4830]	training's rmse: 0.0917627	valid_1's rmse: 0.101004
# [4840]	training's rmse: 0.0916756	valid_1's rmse: 0.100923
# [4850]	training's rmse: 0.0916271	valid_1's rmse: 0.100883
# [4860]	training's rmse: 0.0915607	valid_1's rmse: 0.100828
# [4870]	training's rmse: 0.0915157	valid_1's rmse: 0.100794
# [4880]	training's rmse: 0.0914492	valid_1's rmse: 0.100745
# [4890]	training's rmse: 0.0913735	valid_1's rmse: 0.10068
# [4900]	training's rmse: 0.0912986	valid_1's rmse: 0.10062
# [4910]	training's rmse: 0.0912153	valid_1's rmse: 0.100546
# [4920]	training's rmse: 0.0911616	valid_1's rmse: 0.100508
# [4930]	training's rmse: 0.0910928	valid_1's rmse: 0.10045
# [4940]	training's rmse: 0.091012	valid_1's rmse: 0.100379
# [4950]	training's rmse: 0.0909466	valid_1's rmse: 0.100323
# [4960]	training's rmse: 0.0908926	valid_1's rmse: 0.100282
# [4970]	training's rmse: 0.0908397	valid_1's rmse: 0.100241
# [4980]	training's rmse: 0.0907797	valid_1's rmse: 0.100193
# [4990]	training's rmse: 0.0907388	valid_1's rmse: 0.100164
# [5000]	training's rmse: 0.0906859	valid_1's rmse: 0.100123
# [5010]	training's rmse: 0.0906432	valid_1's rmse: 0.100091
# [5020]	training's rmse: 0.0905647	valid_1's rmse: 0.100025
# [5030]	training's rmse: 0.0905153	valid_1's rmse: 0.0999877
# [5040]	training's rmse: 0.0904519	valid_1's rmse: 0.0999369
# [5050]	training's rmse: 0.0903994	valid_1's rmse: 0.0999
# [5060]	training's rmse: 0.0903362	valid_1's rmse: 0.0998549
# [5070]	training's rmse: 0.090278	valid_1's rmse: 0.0998103
# [5080]	training's rmse: 0.0902304	valid_1's rmse: 0.0997777
# [5090]	training's rmse: 0.0901903	valid_1's rmse: 0.0997475
# [5100]	training's rmse: 0.0901557	valid_1's rmse: 0.0997197
# [5110]	training's rmse: 0.0901027	valid_1's rmse: 0.0996766
# [5120]	training's rmse: 0.0900659	valid_1's rmse: 0.0996515
# [5130]	training's rmse: 0.0900093	valid_1's rmse: 0.0996105
# [5140]	training's rmse: 0.0899638	valid_1's rmse: 0.0995749
# [5150]	training's rmse: 0.0899318	valid_1's rmse: 0.0995502
# [5160]	training's rmse: 0.089889	valid_1's rmse: 0.0995193
# [5170]	training's rmse: 0.0898485	valid_1's rmse: 0.0994888
# [5180]	training's rmse: 0.0898169	valid_1's rmse: 0.0994673
# [5190]	training's rmse: 0.0897737	valid_1's rmse: 0.0994273
# [5200]	training's rmse: 0.0897152	valid_1's rmse: 0.0993814
# [5210]	training's rmse: 0.0896625	valid_1's rmse: 0.0993409
# [5220]	training's rmse: 0.089619	valid_1's rmse: 0.0993061
# [5230]	training's rmse: 0.0895596	valid_1's rmse: 0.0992577
# [5240]	training's rmse: 0.0894754	valid_1's rmse: 0.0991945
# [5250]	training's rmse: 0.0894363	valid_1's rmse: 0.0991698
# [5260]	training's rmse: 0.0894082	valid_1's rmse: 0.0991513
# [5270]	training's rmse: 0.0893714	valid_1's rmse: 0.0991274
# [5280]	training's rmse: 0.0893271	valid_1's rmse: 0.0990991
# [5290]	training's rmse: 0.089275	valid_1's rmse: 0.09906
# [5300]	training's rmse: 0.0892171	valid_1's rmse: 0.0990156
# [5310]	training's rmse: 0.08917	valid_1's rmse: 0.0989737
# [5320]	training's rmse: 0.0891283	valid_1's rmse: 0.0989464
# [5330]	training's rmse: 0.0890941	valid_1's rmse: 0.0989253
# [5340]	training's rmse: 0.0890377	valid_1's rmse: 0.09888
# [5350]	training's rmse: 0.0889696	valid_1's rmse: 0.0988147
# [5360]	training's rmse: 0.088912	valid_1's rmse: 0.0987701
# [5370]	training's rmse: 0.0888648	valid_1's rmse: 0.0987351
# [5380]	training's rmse: 0.0888078	valid_1's rmse: 0.0986948
# [5390]	training's rmse: 0.0887645	valid_1's rmse: 0.0986679
# [5400]	training's rmse: 0.08872	valid_1's rmse: 0.0986363
# [5410]	training's rmse: 0.0886736	valid_1's rmse: 0.0986011
# [5420]	training's rmse: 0.0886352	valid_1's rmse: 0.0985811
# [5430]	training's rmse: 0.0886054	valid_1's rmse: 0.0985583
# [5440]	training's rmse: 0.0885568	valid_1's rmse: 0.0985132
# [5450]	training's rmse: 0.0884755	valid_1's rmse: 0.0984481
# [5460]	training's rmse: 0.088439	valid_1's rmse: 0.0984252
# [5470]	training's rmse: 0.088386	valid_1's rmse: 0.0983862
# [5480]	training's rmse: 0.0883439	valid_1's rmse: 0.0983547
# [5490]	training's rmse: 0.0882946	valid_1's rmse: 0.0983159
# [5500]	training's rmse: 0.0882482	valid_1's rmse: 0.0982832
# [5510]	training's rmse: 0.0882149	valid_1's rmse: 0.0982625
# [5520]	training's rmse: 0.0881719	valid_1's rmse: 0.0982285
# [5530]	training's rmse: 0.0881146	valid_1's rmse: 0.098189
# [5540]	training's rmse: 0.088074	valid_1's rmse: 0.098157
# [5550]	training's rmse: 0.0880431	valid_1's rmse: 0.0981341
# [5560]	training's rmse: 0.0879952	valid_1's rmse: 0.0981011
# [5570]	training's rmse: 0.0879202	valid_1's rmse: 0.0980462
# [5580]	training's rmse: 0.0878836	valid_1's rmse: 0.0980226
# [5590]	training's rmse: 0.0878386	valid_1's rmse: 0.0979891
# [5600]	training's rmse: 0.0877884	valid_1's rmse: 0.097961
# [5610]	training's rmse: 0.0877446	valid_1's rmse: 0.0979293
# [5620]	training's rmse: 0.0876995	valid_1's rmse: 0.0978955
# [5630]	training's rmse: 0.0876423	valid_1's rmse: 0.0978481
# [5640]	training's rmse: 0.0876119	valid_1's rmse: 0.0978265
# [5650]	training's rmse: 0.0875637	valid_1's rmse: 0.0977898
# [5660]	training's rmse: 0.0875066	valid_1's rmse: 0.0977453
# [5670]	training's rmse: 0.087456	valid_1's rmse: 0.0977107
# [5680]	training's rmse: 0.087431	valid_1's rmse: 0.0976965
# [5690]	training's rmse: 0.0873923	valid_1's rmse: 0.0976748
# [5700]	training's rmse: 0.0873581	valid_1's rmse: 0.0976516
# [5710]	training's rmse: 0.0873286	valid_1's rmse: 0.0976318
# [5720]	training's rmse: 0.0872925	valid_1's rmse: 0.0976024
# [5730]	training's rmse: 0.0872579	valid_1's rmse: 0.097578
# [5740]	training's rmse: 0.0872112	valid_1's rmse: 0.0975483
# [5750]	training's rmse: 0.0871716	valid_1's rmse: 0.0975163
# [5760]	training's rmse: 0.0871281	valid_1's rmse: 0.0974857
# [5770]	training's rmse: 0.0870971	valid_1's rmse: 0.0974667
# [5780]	training's rmse: 0.0870641	valid_1's rmse: 0.0974468
# [5790]	training's rmse: 0.0870153	valid_1's rmse: 0.0974102
# [5800]	training's rmse: 0.086979	valid_1's rmse: 0.097387
# [5810]	training's rmse: 0.0869304	valid_1's rmse: 0.0973478
# [5820]	training's rmse: 0.0869074	valid_1's rmse: 0.0973314
# [5830]	training's rmse: 0.0868471	valid_1's rmse: 0.0972728
# [5840]	training's rmse: 0.0868174	valid_1's rmse: 0.0972559
# [5850]	training's rmse: 0.0867937	valid_1's rmse: 0.0972453
# [5860]	training's rmse: 0.0867489	valid_1's rmse: 0.0972156
# [5870]	training's rmse: 0.0866969	valid_1's rmse: 0.0971724
# [5880]	training's rmse: 0.0866509	valid_1's rmse: 0.0971373
# [5890]	training's rmse: 0.0866143	valid_1's rmse: 0.0971108
# [5900]	training's rmse: 0.0865873	valid_1's rmse: 0.0970961
# [5910]	training's rmse: 0.0865615	valid_1's rmse: 0.0970783
# [5920]	training's rmse: 0.086507	valid_1's rmse: 0.0970354
# [5930]	training's rmse: 0.0864677	valid_1's rmse: 0.097004
# [5940]	training's rmse: 0.0864375	valid_1's rmse: 0.0969811
# [5950]	training's rmse: 0.0863886	valid_1's rmse: 0.0969472
# [5960]	training's rmse: 0.0863343	valid_1's rmse: 0.0969075
# [5970]	training's rmse: 0.0863041	valid_1's rmse: 0.0968878
# [5980]	training's rmse: 0.0862635	valid_1's rmse: 0.0968601
# [5990]	training's rmse: 0.0862316	valid_1's rmse: 0.0968379
# [6000]	training's rmse: 0.0862051	valid_1's rmse: 0.0968277
# [6010]	training's rmse: 0.08616	valid_1's rmse: 0.0967917
# [6020]	training's rmse: 0.0861011	valid_1's rmse: 0.0967474
# [6030]	training's rmse: 0.0860749	valid_1's rmse: 0.0967345
# [6040]	training's rmse: 0.0860383	valid_1's rmse: 0.0967057
# [6050]	training's rmse: 0.0859992	valid_1's rmse: 0.0966789
# [6060]	training's rmse: 0.0859627	valid_1's rmse: 0.0966521
# [6070]	training's rmse: 0.0859156	valid_1's rmse: 0.096613
# [6080]	training's rmse: 0.0858477	valid_1's rmse: 0.0965593
# [6090]	training's rmse: 0.0858145	valid_1's rmse: 0.0965358
# [6100]	training's rmse: 0.0857813	valid_1's rmse: 0.0965123
# [6110]	training's rmse: 0.0857445	valid_1's rmse: 0.09649
# [6120]	training's rmse: 0.0857114	valid_1's rmse: 0.0964658
# [6130]	training's rmse: 0.0856839	valid_1's rmse: 0.0964479
# [6140]	training's rmse: 0.0856589	valid_1's rmse: 0.0964331
# [6150]	training's rmse: 0.0856345	valid_1's rmse: 0.0964127
# [6160]	training's rmse: 0.0856101	valid_1's rmse: 0.0964016
# [6170]	training's rmse: 0.0855761	valid_1's rmse: 0.0963753
# [6180]	training's rmse: 0.085533	valid_1's rmse: 0.096341
# [6190]	training's rmse: 0.0854861	valid_1's rmse: 0.0962991
# [6200]	training's rmse: 0.0854312	valid_1's rmse: 0.0962534
# [6210]	training's rmse: 0.0854027	valid_1's rmse: 0.0962317
# [6220]	training's rmse: 0.0853595	valid_1's rmse: 0.0961988
# [6230]	training's rmse: 0.0853125	valid_1's rmse: 0.0961617
# [6240]	training's rmse: 0.0852675	valid_1's rmse: 0.0961332
# [6250]	training's rmse: 0.085235	valid_1's rmse: 0.0961128
# [6260]	training's rmse: 0.0851967	valid_1's rmse: 0.0960906
# [6270]	training's rmse: 0.0851565	valid_1's rmse: 0.0960629
# [6280]	training's rmse: 0.0851246	valid_1's rmse: 0.0960379
# [6290]	training's rmse: 0.0851066	valid_1's rmse: 0.0960249
# [6300]	training's rmse: 0.0850661	valid_1's rmse: 0.0959994
# [6310]	training's rmse: 0.0850211	valid_1's rmse: 0.0959619
# [6320]	training's rmse: 0.084992	valid_1's rmse: 0.0959423
# [6330]	training's rmse: 0.0849411	valid_1's rmse: 0.0958945
# [6340]	training's rmse: 0.0849066	valid_1's rmse: 0.0958722
# [6350]	training's rmse: 0.0848712	valid_1's rmse: 0.0958459
# [6360]	training's rmse: 0.0848425	valid_1's rmse: 0.0958284
# [6370]	training's rmse: 0.0848168	valid_1's rmse: 0.0958141
# [6380]	training's rmse: 0.0847853	valid_1's rmse: 0.0957962
# [6390]	training's rmse: 0.0847567	valid_1's rmse: 0.0957788
# [6400]	training's rmse: 0.0847244	valid_1's rmse: 0.095756
# [6410]	training's rmse: 0.0846739	valid_1's rmse: 0.0957166
# [6420]	training's rmse: 0.0846245	valid_1's rmse: 0.0956731
# [6430]	training's rmse: 0.084589	valid_1's rmse: 0.0956466
# [6440]	training's rmse: 0.084554	valid_1's rmse: 0.0956196
# [6450]	training's rmse: 0.0845148	valid_1's rmse: 0.0955967
# [6460]	training's rmse: 0.0844786	valid_1's rmse: 0.0955756
# [6470]	training's rmse: 0.084448	valid_1's rmse: 0.0955585
# [6480]	training's rmse: 0.0844226	valid_1's rmse: 0.095548
# [6490]	training's rmse: 0.0843839	valid_1's rmse: 0.0955152
# [6500]	training's rmse: 0.0843304	valid_1's rmse: 0.0954743
# [6510]	training's rmse: 0.0842977	valid_1's rmse: 0.0954479
# [6520]	training's rmse: 0.0842679	valid_1's rmse: 0.0954272
# [6530]	training's rmse: 0.0842212	valid_1's rmse: 0.0953911
# [6540]	training's rmse: 0.0841897	valid_1's rmse: 0.095376
# [6550]	training's rmse: 0.0841553	valid_1's rmse: 0.0953482
# [6560]	training's rmse: 0.0841262	valid_1's rmse: 0.0953282
# [6570]	training's rmse: 0.084089	valid_1's rmse: 0.0952954
# [6580]	training's rmse: 0.0840525	valid_1's rmse: 0.0952714
# [6590]	training's rmse: 0.084024	valid_1's rmse: 0.0952429
# [6600]	training's rmse: 0.083966	valid_1's rmse: 0.0952023
# [6610]	training's rmse: 0.0839145	valid_1's rmse: 0.0951609
# [6620]	training's rmse: 0.0838708	valid_1's rmse: 0.0951257
# [6630]	training's rmse: 0.0838175	valid_1's rmse: 0.0950808
# [6640]	training's rmse: 0.0837847	valid_1's rmse: 0.0950601
# [6650]	training's rmse: 0.0837399	valid_1's rmse: 0.0950262
# [6660]	training's rmse: 0.0836918	valid_1's rmse: 0.0949886
# [6670]	training's rmse: 0.0836577	valid_1's rmse: 0.0949646
# [6680]	training's rmse: 0.0836347	valid_1's rmse: 0.0949516
# [6690]	training's rmse: 0.0836127	valid_1's rmse: 0.0949366
# [6700]	training's rmse: 0.0835788	valid_1's rmse: 0.0949086
# [6710]	training's rmse: 0.0835479	valid_1's rmse: 0.0948878
# [6720]	training's rmse: 0.0835267	valid_1's rmse: 0.094877
# [6730]	training's rmse: 0.0834962	valid_1's rmse: 0.0948588
# [6740]	training's rmse: 0.0834709	valid_1's rmse: 0.0948388
# [6750]	training's rmse: 0.0834247	valid_1's rmse: 0.0948081
# [6760]	training's rmse: 0.0834035	valid_1's rmse: 0.0947979
# [6770]	training's rmse: 0.0833846	valid_1's rmse: 0.094786
# [6780]	training's rmse: 0.0833373	valid_1's rmse: 0.0947569
# [6790]	training's rmse: 0.0832984	valid_1's rmse: 0.0947319
# [6800]	training's rmse: 0.0832627	valid_1's rmse: 0.0947092
# [6810]	training's rmse: 0.0832314	valid_1's rmse: 0.0946825
# [6820]	training's rmse: 0.0831825	valid_1's rmse: 0.0946451
# [6830]	training's rmse: 0.0831473	valid_1's rmse: 0.0946223
# [6840]	training's rmse: 0.0831259	valid_1's rmse: 0.0946113
# [6850]	training's rmse: 0.0830932	valid_1's rmse: 0.0945902
# [6860]	training's rmse: 0.0830594	valid_1's rmse: 0.0945609
# [6870]	training's rmse: 0.0830424	valid_1's rmse: 0.0945516
# [6880]	training's rmse: 0.0830203	valid_1's rmse: 0.0945417
# [6890]	training's rmse: 0.0829931	valid_1's rmse: 0.094519
# [6900]	training's rmse: 0.0829451	valid_1's rmse: 0.094486
# [6910]	training's rmse: 0.0829111	valid_1's rmse: 0.0944674
# [6920]	training's rmse: 0.0828709	valid_1's rmse: 0.0944377
# [6930]	training's rmse: 0.0828417	valid_1's rmse: 0.0944187
# [6940]	training's rmse: 0.0828181	valid_1's rmse: 0.094401
# [6950]	training's rmse: 0.082779	valid_1's rmse: 0.0943712
# [6960]	training's rmse: 0.0827409	valid_1's rmse: 0.0943413
# [6970]	training's rmse: 0.0827115	valid_1's rmse: 0.0943241
# [6980]	training's rmse: 0.082679	valid_1's rmse: 0.0943009
# [6990]	training's rmse: 0.082623	valid_1's rmse: 0.0942536
# [7000]	training's rmse: 0.0825777	valid_1's rmse: 0.0942174
# [7010]	training's rmse: 0.0825392	valid_1's rmse: 0.0941917
# [7020]	training's rmse: 0.0824963	valid_1's rmse: 0.0941627
# [7030]	training's rmse: 0.0824543	valid_1's rmse: 0.0941294
# [7040]	training's rmse: 0.0824208	valid_1's rmse: 0.0941031
# [7050]	training's rmse: 0.0823811	valid_1's rmse: 0.0940777
# [7060]	training's rmse: 0.0823463	valid_1's rmse: 0.0940539
# [7070]	training's rmse: 0.0823184	valid_1's rmse: 0.0940371
# [7080]	training's rmse: 0.0822846	valid_1's rmse: 0.0940129
# [7090]	training's rmse: 0.0822569	valid_1's rmse: 0.0939923
# [7100]	training's rmse: 0.0822186	valid_1's rmse: 0.0939622
# [7110]	training's rmse: 0.0821808	valid_1's rmse: 0.0939404
# [7120]	training's rmse: 0.0821502	valid_1's rmse: 0.0939146
# [7130]	training's rmse: 0.0821172	valid_1's rmse: 0.0938925
# [7140]	training's rmse: 0.0820799	valid_1's rmse: 0.0938649
# [7150]	training's rmse: 0.0820381	valid_1's rmse: 0.0938385
# [7160]	training's rmse: 0.082011	valid_1's rmse: 0.0938205
# [7170]	training's rmse: 0.0819817	valid_1's rmse: 0.0938009
# [7180]	training's rmse: 0.0819375	valid_1's rmse: 0.0937674
# [7190]	training's rmse: 0.081916	valid_1's rmse: 0.093755
# [7200]	training's rmse: 0.0818824	valid_1's rmse: 0.0937305
# [7210]	training's rmse: 0.0818529	valid_1's rmse: 0.0937122
# [7220]	training's rmse: 0.0818211	valid_1's rmse: 0.0936883
# [7230]	training's rmse: 0.0817972	valid_1's rmse: 0.0936723
# [7240]	training's rmse: 0.081762	valid_1's rmse: 0.0936532
# [7250]	training's rmse: 0.0817434	valid_1's rmse: 0.0936455
# [7260]	training's rmse: 0.0817207	valid_1's rmse: 0.0936291
# [7270]	training's rmse: 0.0816872	valid_1's rmse: 0.0936091
# [7280]	training's rmse: 0.0816507	valid_1's rmse: 0.0935829
# [7290]	training's rmse: 0.0816084	valid_1's rmse: 0.0935535
# [7300]	training's rmse: 0.0815863	valid_1's rmse: 0.0935376
# [7310]	training's rmse: 0.0815667	valid_1's rmse: 0.0935261
# [7320]	training's rmse: 0.0815225	valid_1's rmse: 0.0934923
# [7330]	training's rmse: 0.0815072	valid_1's rmse: 0.0934854
# [7340]	training's rmse: 0.0814584	valid_1's rmse: 0.093445
# [7350]	training's rmse: 0.0814296	valid_1's rmse: 0.0934243
# [7360]	training's rmse: 0.081395	valid_1's rmse: 0.0934023
# [7370]	training's rmse: 0.0813568	valid_1's rmse: 0.0933753
# [7380]	training's rmse: 0.0813261	valid_1's rmse: 0.0933585
# [7390]	training's rmse: 0.0812775	valid_1's rmse: 0.0933214
# [7400]	training's rmse: 0.0812415	valid_1's rmse: 0.0932911
# [7410]	training's rmse: 0.0812076	valid_1's rmse: 0.0932676
# [7420]	training's rmse: 0.0811758	valid_1's rmse: 0.0932454
# [7430]	training's rmse: 0.0811445	valid_1's rmse: 0.0932229
# [7440]	training's rmse: 0.0810975	valid_1's rmse: 0.0931826
# [7450]	training's rmse: 0.0810711	valid_1's rmse: 0.093164
# [7460]	training's rmse: 0.0810315	valid_1's rmse: 0.0931382
# [7470]	training's rmse: 0.0810094	valid_1's rmse: 0.093125
# [7480]	training's rmse: 0.0809788	valid_1's rmse: 0.0931046
# [7490]	training's rmse: 0.0809631	valid_1's rmse: 0.0931009
# [7500]	training's rmse: 0.0809368	valid_1's rmse: 0.0930871
# [7510]	training's rmse: 0.0809167	valid_1's rmse: 0.0930747
# [7520]	training's rmse: 0.0808949	valid_1's rmse: 0.0930616
# [7530]	training's rmse: 0.0808544	valid_1's rmse: 0.0930348
# [7540]	training's rmse: 0.0808139	valid_1's rmse: 0.0930075
# [7550]	training's rmse: 0.0807907	valid_1's rmse: 0.0929922
# [7560]	training's rmse: 0.0807618	valid_1's rmse: 0.0929773
# [7570]	training's rmse: 0.0807381	valid_1's rmse: 0.0929678
# [7580]	training's rmse: 0.0807045	valid_1's rmse: 0.0929467
# [7590]	training's rmse: 0.0806571	valid_1's rmse: 0.0929111
# [7600]	training's rmse: 0.0806286	valid_1's rmse: 0.0928924
# [7610]	training's rmse: 0.0805902	valid_1's rmse: 0.0928698
# [7620]	training's rmse: 0.0805642	valid_1's rmse: 0.0928542
# [7630]	training's rmse: 0.0805388	valid_1's rmse: 0.0928421
# [7640]	training's rmse: 0.0805075	valid_1's rmse: 0.0928188
# [7650]	training's rmse: 0.0804689	valid_1's rmse: 0.0927949
# [7660]	training's rmse: 0.080443	valid_1's rmse: 0.0927779
# [7670]	training's rmse: 0.0803991	valid_1's rmse: 0.0927482
# [7680]	training's rmse: 0.0803703	valid_1's rmse: 0.0927269
# [7690]	training's rmse: 0.0803363	valid_1's rmse: 0.092698
# [7700]	training's rmse: 0.0802962	valid_1's rmse: 0.0926702
# [7710]	training's rmse: 0.0802678	valid_1's rmse: 0.0926521
# [7720]	training's rmse: 0.080238	valid_1's rmse: 0.0926326
# [7730]	training's rmse: 0.080212	valid_1's rmse: 0.0926168
# [7740]	training's rmse: 0.0801878	valid_1's rmse: 0.0926045
# [7750]	training's rmse: 0.0801718	valid_1's rmse: 0.0925935
# [7760]	training's rmse: 0.0801514	valid_1's rmse: 0.0925823
# [7770]	training's rmse: 0.0801275	valid_1's rmse: 0.0925659
# [7780]	training's rmse: 0.0801005	valid_1's rmse: 0.0925452
# [7790]	training's rmse: 0.0800715	valid_1's rmse: 0.0925255
# [7800]	training's rmse: 0.0800491	valid_1's rmse: 0.0925112
# [7810]	training's rmse: 0.0800202	valid_1's rmse: 0.0924966
# [7820]	training's rmse: 0.0799992	valid_1's rmse: 0.0924839
# [7830]	training's rmse: 0.0799602	valid_1's rmse: 0.0924522
# [7840]	training's rmse: 0.0799291	valid_1's rmse: 0.0924333
# [7850]	training's rmse: 0.0799008	valid_1's rmse: 0.0924188
# [7860]	training's rmse: 0.0798795	valid_1's rmse: 0.0924031
# [7870]	training's rmse: 0.0798452	valid_1's rmse: 0.0923813
# [7880]	training's rmse: 0.0798179	valid_1's rmse: 0.0923622
# [7890]	training's rmse: 0.0797904	valid_1's rmse: 0.0923442
# [7900]	training's rmse: 0.0797584	valid_1's rmse: 0.0923203
# [7910]	training's rmse: 0.0797381	valid_1's rmse: 0.0923077
# [7920]	training's rmse: 0.0797115	valid_1's rmse: 0.0922912
# [7930]	training's rmse: 0.0796838	valid_1's rmse: 0.0922709
# [7940]	training's rmse: 0.0796572	valid_1's rmse: 0.0922513
# [7950]	training's rmse: 0.0796182	valid_1's rmse: 0.0922214
# [7960]	training's rmse: 0.0795927	valid_1's rmse: 0.0922045
# [7970]	training's rmse: 0.0795738	valid_1's rmse: 0.0921922
# [7980]	training's rmse: 0.0795355	valid_1's rmse: 0.0921681
# [7990]	training's rmse: 0.0795173	valid_1's rmse: 0.0921568
# [8000]	training's rmse: 0.0794883	valid_1's rmse: 0.0921418
# [8010]	training's rmse: 0.0794576	valid_1's rmse: 0.0921211
# [8020]	training's rmse: 0.0794346	valid_1's rmse: 0.0921071
# [8030]	training's rmse: 0.0794129	valid_1's rmse: 0.0920893
# [8040]	training's rmse: 0.0793781	valid_1's rmse: 0.0920642
# [8050]	training's rmse: 0.0793483	valid_1's rmse: 0.0920403
# [8060]	training's rmse: 0.0793222	valid_1's rmse: 0.0920262
# [8070]	training's rmse: 0.0793026	valid_1's rmse: 0.0920201
# [8080]	training's rmse: 0.07928	valid_1's rmse: 0.0920066
# [8090]	training's rmse: 0.0792449	valid_1's rmse: 0.0919839
# [8100]	training's rmse: 0.0792145	valid_1's rmse: 0.0919613
# [8110]	training's rmse: 0.0791809	valid_1's rmse: 0.0919364
# [8120]	training's rmse: 0.0791559	valid_1's rmse: 0.0919183
# [8130]	training's rmse: 0.0791216	valid_1's rmse: 0.0918889
# [8140]	training's rmse: 0.0790987	valid_1's rmse: 0.0918715
# [8150]	training's rmse: 0.0790668	valid_1's rmse: 0.0918534
# [8160]	training's rmse: 0.0790447	valid_1's rmse: 0.0918422
# [8170]	training's rmse: 0.0790249	valid_1's rmse: 0.0918327
# ...
# [20290]	training's rmse: 0.0637172	valid_1's rmse: 0.0829576
# [20300]	training's rmse: 0.063712	valid_1's rmse: 0.0829556
# [20310]	training's rmse: 0.0637064	valid_1's rmse: 0.0829531
# [20320]	training's rmse: 0.0636989	valid_1's rmse: 0.0829505
# [20330]	training's rmse: 0.0636918	valid_1's rmse: 0.0829471
# [20340]	training's rmse: 0.0636845	valid_1's rmse: 0.0829459
# [20350]	training's rmse: 0.0636791	valid_1's rmse: 0.0829442
# [20360]	training's rmse: 0.063673	valid_1's rmse: 0.0829432
# [20370]	training's rmse: 0.0636643	valid_1's rmse: 0.0829397
# [20380]	training's rmse: 0.0636558	valid_1's rmse: 0.0829374
# [20390]	training's rmse: 0.0636486	valid_1's rmse: 0.0829368
# [20400]	training's rmse: 0.0636404	valid_1's rmse: 0.0829332
# [20410]	training's rmse: 0.0636311	valid_1's rmse: 0.082929
# [20420]	training's rmse: 0.0636257	valid_1's rmse: 0.0829259
# [20430]	training's rmse: 0.0636193	valid_1's rmse: 0.0829238
# [20440]	training's rmse: 0.0636162	valid_1's rmse: 0.0829227
# [20450]	training's rmse: 0.0636119	valid_1's rmse: 0.0829215
# [20460]	training's rmse: 0.0636044	valid_1's rmse: 0.0829181
# [20470]	training's rmse: 0.0635973	valid_1's rmse: 0.0829139
# [20480]	training's rmse: 0.0635926	valid_1's rmse: 0.0829121
# [20490]	training's rmse: 0.0635856	valid_1's rmse: 0.0829096
# [20500]	training's rmse: 0.0635807	valid_1's rmse: 0.0829083
# [20510]	training's rmse: 0.0635735	valid_1's rmse: 0.0829063
# [20520]	training's rmse: 0.0635651	valid_1's rmse: 0.0829025
# [20530]	training's rmse: 0.0635589	valid_1's rmse: 0.0829009
# [20540]	training's rmse: 0.0635525	valid_1's rmse: 0.0828998
# [20550]	training's rmse: 0.0635471	valid_1's rmse: 0.0828986
# [20560]	training's rmse: 0.0635399	valid_1's rmse: 0.0828968
# [20570]	training's rmse: 0.0635348	valid_1's rmse: 0.0828958
# [20580]	training's rmse: 0.0635264	valid_1's rmse: 0.08289
# [20590]	training's rmse: 0.0635176	valid_1's rmse: 0.0828849
# [20600]	training's rmse: 0.0635105	valid_1's rmse: 0.0828833
# [20610]	training's rmse: 0.0635031	valid_1's rmse: 0.0828807
# [20620]	training's rmse: 0.0634968	valid_1's rmse: 0.0828792
# [20630]	training's rmse: 0.0634898	valid_1's rmse: 0.0828775
# [20640]	training's rmse: 0.0634821	valid_1's rmse: 0.0828758
# [20650]	training's rmse: 0.0634755	valid_1's rmse: 0.0828722
# [20660]	training's rmse: 0.0634698	valid_1's rmse: 0.0828719
# [20670]	training's rmse: 0.0634637	valid_1's rmse: 0.0828691
# [20680]	training's rmse: 0.0634575	valid_1's rmse: 0.082867
# [20690]	training's rmse: 0.06345	valid_1's rmse: 0.0828653
# [20700]	training's rmse: 0.0634442	valid_1's rmse: 0.0828629
# [20710]	training's rmse: 0.0634379	valid_1's rmse: 0.0828604
# [20720]	training's rmse: 0.0634279	valid_1's rmse: 0.0828544
# [20730]	training's rmse: 0.0634227	valid_1's rmse: 0.0828525
# [20740]	training's rmse: 0.0634134	valid_1's rmse: 0.0828482
# [20750]	training's rmse: 0.0634046	valid_1's rmse: 0.0828448
# [20760]	training's rmse: 0.0633974	valid_1's rmse: 0.0828414
# [20770]	training's rmse: 0.0633933	valid_1's rmse: 0.0828418
# [20780]	training's rmse: 0.0633869	valid_1's rmse: 0.0828397
# [20790]	training's rmse: 0.063381	valid_1's rmse: 0.0828396
# [20800]	training's rmse: 0.0633718	valid_1's rmse: 0.0828345
# [20810]	training's rmse: 0.0633622	valid_1's rmse: 0.08283
# [20820]	training's rmse: 0.0633527	valid_1's rmse: 0.0828276
# [20830]	training's rmse: 0.0633466	valid_1's rmse: 0.0828254
# [20840]	training's rmse: 0.06334	valid_1's rmse: 0.0828227
# [20850]	training's rmse: 0.0633316	valid_1's rmse: 0.0828212
# [20860]	training's rmse: 0.0633261	valid_1's rmse: 0.0828202
# [20870]	training's rmse: 0.0633184	valid_1's rmse: 0.0828192
# [20880]	training's rmse: 0.0633116	valid_1's rmse: 0.0828166
# [20890]	training's rmse: 0.0633059	valid_1's rmse: 0.0828141
# [20900]	training's rmse: 0.063298	valid_1's rmse: 0.0828113
# [20910]	training's rmse: 0.0632924	valid_1's rmse: 0.0828105
# [20920]	training's rmse: 0.0632855	valid_1's rmse: 0.082809
# [20930]	training's rmse: 0.0632812	valid_1's rmse: 0.0828071
# [20940]	training's rmse: 0.0632753	valid_1's rmse: 0.0828045
# [20950]	training's rmse: 0.0632695	valid_1's rmse: 0.0828044
# [20960]	training's rmse: 0.0632621	valid_1's rmse: 0.0828026
# [20970]	training's rmse: 0.0632581	valid_1's rmse: 0.0828018
# [20980]	training's rmse: 0.0632504	valid_1's rmse: 0.0827977
# [20990]	training's rmse: 0.0632427	valid_1's rmse: 0.0827959
# [21000]	training's rmse: 0.0632356	valid_1's rmse: 0.082797
# [21010]	training's rmse: 0.0632298	valid_1's rmse: 0.0827947
# [21020]	training's rmse: 0.0632234	valid_1's rmse: 0.0827934
# [21030]	training's rmse: 0.063218	valid_1's rmse: 0.082792
# [21040]	training's rmse: 0.0632131	valid_1's rmse: 0.0827924
# [21050]	training's rmse: 0.063204	valid_1's rmse: 0.0827904
# [21060]	training's rmse: 0.0631974	valid_1's rmse: 0.0827899
# [21070]	training's rmse: 0.0631887	valid_1's rmse: 0.0827866
# [21080]	training's rmse: 0.0631811	valid_1's rmse: 0.0827818
# [21090]	training's rmse: 0.0631761	valid_1's rmse: 0.0827804
# [21100]	training's rmse: 0.0631699	valid_1's rmse: 0.0827803
# [21110]	training's rmse: 0.0631634	valid_1's rmse: 0.0827781
# [21120]	training's rmse: 0.0631561	valid_1's rmse: 0.0827764
# [21130]	training's rmse: 0.063148	valid_1's rmse: 0.0827734
# [21140]	training's rmse: 0.0631377	valid_1's rmse: 0.0827683
# [21150]	training's rmse: 0.0631318	valid_1's rmse: 0.082765
# [21160]	training's rmse: 0.0631237	valid_1's rmse: 0.082761
# [21170]	training's rmse: 0.0631176	valid_1's rmse: 0.0827586
# [21180]	training's rmse: 0.0631113	valid_1's rmse: 0.082758
# [21190]	training's rmse: 0.0631037	valid_1's rmse: 0.0827538
# [21200]	training's rmse: 0.0630952	valid_1's rmse: 0.08275
# [21210]	training's rmse: 0.0630895	valid_1's rmse: 0.0827488
# [21220]	training's rmse: 0.0630856	valid_1's rmse: 0.0827488
# [21230]	training's rmse: 0.0630804	valid_1's rmse: 0.0827478
# [21240]	training's rmse: 0.063075	valid_1's rmse: 0.0827487
# [21250]	training's rmse: 0.0630677	valid_1's rmse: 0.0827456
# [21260]	training's rmse: 0.063061	valid_1's rmse: 0.0827418
# [21270]	training's rmse: 0.0630561	valid_1's rmse: 0.0827404
# [21280]	training's rmse: 0.0630506	valid_1's rmse: 0.0827375
# [21290]	training's rmse: 0.0630466	valid_1's rmse: 0.0827366
# [21300]	training's rmse: 0.0630394	valid_1's rmse: 0.0827339
# [21310]	training's rmse: 0.0630312	valid_1's rmse: 0.0827302
# [21320]	training's rmse: 0.063024	valid_1's rmse: 0.0827262
# [21330]	training's rmse: 0.0630172	valid_1's rmse: 0.0827247
# [21340]	training's rmse: 0.0630113	valid_1's rmse: 0.0827223
# [21350]	training's rmse: 0.0630041	valid_1's rmse: 0.0827204
# [21360]	training's rmse: 0.0629982	valid_1's rmse: 0.082719
# [21370]	training's rmse: 0.0629921	valid_1's rmse: 0.0827179
# [21380]	training's rmse: 0.0629878	valid_1's rmse: 0.0827162
# [21390]	training's rmse: 0.0629818	valid_1's rmse: 0.0827156
# [21400]	training's rmse: 0.062976	valid_1's rmse: 0.0827126
# [21410]	training's rmse: 0.0629689	valid_1's rmse: 0.0827099
# [21420]	training's rmse: 0.0629625	valid_1's rmse: 0.082707
# [21430]	training's rmse: 0.0629526	valid_1's rmse: 0.0827043
# [21440]	training's rmse: 0.0629477	valid_1's rmse: 0.0827026
# [21450]	training's rmse: 0.0629409	valid_1's rmse: 0.0827011
# [21460]	training's rmse: 0.0629351	valid_1's rmse: 0.0826995
# [21470]	training's rmse: 0.0629305	valid_1's rmse: 0.0826985
# [21480]	training's rmse: 0.0629227	valid_1's rmse: 0.0826961
# [21490]	training's rmse: 0.0629165	valid_1's rmse: 0.0826959
# [21500]	training's rmse: 0.062908	valid_1's rmse: 0.0826923
# [21510]	training's rmse: 0.062899	valid_1's rmse: 0.0826873
# [21520]	training's rmse: 0.0628897	valid_1's rmse: 0.0826859
# [21530]	training's rmse: 0.0628836	valid_1's rmse: 0.0826844
# [21540]	training's rmse: 0.0628749	valid_1's rmse: 0.0826803
# [21550]	training's rmse: 0.0628668	valid_1's rmse: 0.08268
# [21560]	training's rmse: 0.0628598	valid_1's rmse: 0.0826779
# [21570]	training's rmse: 0.0628538	valid_1's rmse: 0.0826765
# [21580]	training's rmse: 0.0628493	valid_1's rmse: 0.0826761
# [21590]	training's rmse: 0.0628416	valid_1's rmse: 0.0826713
# [21600]	training's rmse: 0.0628366	valid_1's rmse: 0.0826703
# [21610]	training's rmse: 0.062831	valid_1's rmse: 0.0826697
# [21620]	training's rmse: 0.0628256	valid_1's rmse: 0.0826683
# [21630]	training's rmse: 0.0628192	valid_1's rmse: 0.082666
# [21640]	training's rmse: 0.0628129	valid_1's rmse: 0.0826651
# [21650]	training's rmse: 0.0628067	valid_1's rmse: 0.0826634
# [21660]	training's rmse: 0.062799	valid_1's rmse: 0.0826598
# [21670]	training's rmse: 0.0627933	valid_1's rmse: 0.0826584
# [21680]	training's rmse: 0.0627851	valid_1's rmse: 0.0826557
# [21690]	training's rmse: 0.0627781	valid_1's rmse: 0.0826539
# [21700]	training's rmse: 0.0627736	valid_1's rmse: 0.0826521
# [21710]	training's rmse: 0.0627692	valid_1's rmse: 0.0826512
# [21720]	training's rmse: 0.0627631	valid_1's rmse: 0.0826485
# [21730]	training's rmse: 0.0627577	valid_1's rmse: 0.0826459
# [21740]	training's rmse: 0.0627516	valid_1's rmse: 0.082643
# [21750]	training's rmse: 0.0627485	valid_1's rmse: 0.0826428
# [21760]	training's rmse: 0.0627437	valid_1's rmse: 0.0826411
# [21770]	training's rmse: 0.0627389	valid_1's rmse: 0.0826394
# [21780]	training's rmse: 0.0627312	valid_1's rmse: 0.0826372
# [21790]	training's rmse: 0.0627264	valid_1's rmse: 0.0826374
# [21800]	training's rmse: 0.0627225	valid_1's rmse: 0.082637
# [21810]	training's rmse: 0.0627183	valid_1's rmse: 0.0826357
# [21820]	training's rmse: 0.0627126	valid_1's rmse: 0.0826346
# [21830]	training's rmse: 0.0627063	valid_1's rmse: 0.0826318
# [21840]	training's rmse: 0.0626995	valid_1's rmse: 0.0826288
# [21850]	training's rmse: 0.0626936	valid_1's rmse: 0.082628
# [21860]	training's rmse: 0.0626875	valid_1's rmse: 0.0826245
# [21870]	training's rmse: 0.0626802	valid_1's rmse: 0.0826223
# [21880]	training's rmse: 0.0626743	valid_1's rmse: 0.082621
# [21890]	training's rmse: 0.0626666	valid_1's rmse: 0.0826177
# [21900]	training's rmse: 0.0626599	valid_1's rmse: 0.0826164
# [21910]	training's rmse: 0.0626529	valid_1's rmse: 0.0826148
# [21920]	training's rmse: 0.0626476	valid_1's rmse: 0.0826134
# [21930]	training's rmse: 0.0626398	valid_1's rmse: 0.0826091
# [21940]	training's rmse: 0.0626338	valid_1's rmse: 0.0826073
# [21950]	training's rmse: 0.0626252	valid_1's rmse: 0.0826025
# [21960]	training's rmse: 0.0626193	valid_1's rmse: 0.082601
# [21970]	training's rmse: 0.0626123	valid_1's rmse: 0.0826007
# [21980]	training's rmse: 0.0626071	valid_1's rmse: 0.0826001
# [21990]	training's rmse: 0.0626039	valid_1's rmse: 0.0826001
# [22000]	training's rmse: 0.0625971	valid_1's rmse: 0.0825964
# [22010]	training's rmse: 0.0625923	valid_1's rmse: 0.0825949
# [22020]	training's rmse: 0.0625857	valid_1's rmse: 0.0825921
# [22030]	training's rmse: 0.0625789	valid_1's rmse: 0.082592
# [22040]	training's rmse: 0.0625708	valid_1's rmse: 0.0825877
# [22050]	training's rmse: 0.0625624	valid_1's rmse: 0.0825852
# [22060]	training's rmse: 0.062556	valid_1's rmse: 0.0825818
# [22070]	training's rmse: 0.0625501	valid_1's rmse: 0.0825787
# [22080]	training's rmse: 0.0625465	valid_1's rmse: 0.0825782
# [22090]	training's rmse: 0.0625416	valid_1's rmse: 0.0825772
# [22100]	training's rmse: 0.0625365	valid_1's rmse: 0.082576
# [22110]	training's rmse: 0.0625293	valid_1's rmse: 0.0825742
# [22120]	training's rmse: 0.0625221	valid_1's rmse: 0.0825738
# [22130]	training's rmse: 0.0625151	valid_1's rmse: 0.0825714
# [22140]	training's rmse: 0.0625066	valid_1's rmse: 0.0825677
# [22150]	training's rmse: 0.062502	valid_1's rmse: 0.0825663
# [22160]	training's rmse: 0.0624957	valid_1's rmse: 0.0825621
# [22170]	training's rmse: 0.0624895	valid_1's rmse: 0.082562
# [22180]	training's rmse: 0.0624818	valid_1's rmse: 0.0825587
# [22190]	training's rmse: 0.0624725	valid_1's rmse: 0.0825547
# [22200]	training's rmse: 0.0624609	valid_1's rmse: 0.082551
# [22210]	training's rmse: 0.0624533	valid_1's rmse: 0.0825472
# [22220]	training's rmse: 0.0624483	valid_1's rmse: 0.0825453
# [22230]	training's rmse: 0.0624404	valid_1's rmse: 0.0825422
# [22240]	training's rmse: 0.0624353	valid_1's rmse: 0.0825411
# [22250]	training's rmse: 0.0624289	valid_1's rmse: 0.0825401
# [22260]	training's rmse: 0.0624221	valid_1's rmse: 0.0825375
# [22270]	training's rmse: 0.0624143	valid_1's rmse: 0.082535
# [22280]	training's rmse: 0.0624073	valid_1's rmse: 0.0825335
# [22290]	training's rmse: 0.0624016	valid_1's rmse: 0.0825306
# [22300]	training's rmse: 0.0623929	valid_1's rmse: 0.0825273
# [22310]	training's rmse: 0.0623862	valid_1's rmse: 0.0825244
# [22320]	training's rmse: 0.0623817	valid_1's rmse: 0.0825245
# [22330]	training's rmse: 0.062377	valid_1's rmse: 0.0825233
# [22340]	training's rmse: 0.062369	valid_1's rmse: 0.0825175
# [22350]	training's rmse: 0.0623636	valid_1's rmse: 0.0825169
# [22360]	training's rmse: 0.0623583	valid_1's rmse: 0.0825155
# [22370]	training's rmse: 0.0623504	valid_1's rmse: 0.0825123
# [22380]	training's rmse: 0.0623418	valid_1's rmse: 0.0825079
# [22390]	training's rmse: 0.0623338	valid_1's rmse: 0.0825059
# [22400]	training's rmse: 0.0623278	valid_1's rmse: 0.0825033
# [22410]	training's rmse: 0.0623209	valid_1's rmse: 0.0825005
# [22420]	training's rmse: 0.062315	valid_1's rmse: 0.0824987
# [22430]	training's rmse: 0.0623087	valid_1's rmse: 0.0824967
# [22440]	training's rmse: 0.062302	valid_1's rmse: 0.0824939
# [22450]	training's rmse: 0.0622951	valid_1's rmse: 0.0824917
# [22460]	training's rmse: 0.0622893	valid_1's rmse: 0.0824902
# [22470]	training's rmse: 0.062283	valid_1's rmse: 0.0824894
# [22480]	training's rmse: 0.0622762	valid_1's rmse: 0.082487
# [22490]	training's rmse: 0.0622692	valid_1's rmse: 0.0824849
# [22500]	training's rmse: 0.0622599	valid_1's rmse: 0.0824822
# [22510]	training's rmse: 0.0622523	valid_1's rmse: 0.0824777
# [22520]	training's rmse: 0.0622452	valid_1's rmse: 0.0824737
# [22530]	training's rmse: 0.0622371	valid_1's rmse: 0.0824692
# [22540]	training's rmse: 0.0622299	valid_1's rmse: 0.0824663
# [22550]	training's rmse: 0.0622241	valid_1's rmse: 0.0824642
# [22560]	training's rmse: 0.062218	valid_1's rmse: 0.0824634
# [22570]	training's rmse: 0.0622106	valid_1's rmse: 0.0824623
# [22580]	training's rmse: 0.0622041	valid_1's rmse: 0.0824614
# [22590]	training's rmse: 0.062199	valid_1's rmse: 0.0824595
# [22600]	training's rmse: 0.0621904	valid_1's rmse: 0.0824543
# [22610]	training's rmse: 0.0621841	valid_1's rmse: 0.0824535
# [22620]	training's rmse: 0.0621765	valid_1's rmse: 0.0824521
# [22630]	training's rmse: 0.0621709	valid_1's rmse: 0.0824516
# [22640]	training's rmse: 0.0621639	valid_1's rmse: 0.0824501
# [22650]	training's rmse: 0.0621564	valid_1's rmse: 0.0824476
# [22660]	training's rmse: 0.0621518	valid_1's rmse: 0.0824457
# [22670]	training's rmse: 0.0621445	valid_1's rmse: 0.0824425
# [22680]	training's rmse: 0.0621376	valid_1's rmse: 0.0824406
# [22690]	training's rmse: 0.0621318	valid_1's rmse: 0.0824398
# [22700]	training's rmse: 0.0621243	valid_1's rmse: 0.0824341
# [22710]	training's rmse: 0.0621162	valid_1's rmse: 0.0824309
# [22720]	training's rmse: 0.062112	valid_1's rmse: 0.08243
# [22730]	training's rmse: 0.0621044	valid_1's rmse: 0.0824274
# [22740]	training's rmse: 0.0620995	valid_1's rmse: 0.0824283
# [22750]	training's rmse: 0.0620915	valid_1's rmse: 0.0824254
# [22760]	training's rmse: 0.062088	valid_1's rmse: 0.0824248
# [22770]	training's rmse: 0.0620838	valid_1's rmse: 0.0824246
# [22780]	training's rmse: 0.0620789	valid_1's rmse: 0.0824243
# [22790]	training's rmse: 0.0620752	valid_1's rmse: 0.082424
# [22800]	training's rmse: 0.0620715	valid_1's rmse: 0.0824239
# [22810]	training's rmse: 0.0620667	valid_1's rmse: 0.0824226
# [22820]	training's rmse: 0.0620615	valid_1's rmse: 0.0824218
# [22830]	training's rmse: 0.0620543	valid_1's rmse: 0.0824191
# [22840]	training's rmse: 0.0620444	valid_1's rmse: 0.0824164
# [22850]	training's rmse: 0.0620385	valid_1's rmse: 0.0824171
# [22860]	training's rmse: 0.062032	valid_1's rmse: 0.082419
# [22870]	training's rmse: 0.0620271	valid_1's rmse: 0.0824197
# [22880]	training's rmse: 0.0620225	valid_1's rmse: 0.0824217
# [22890]	training's rmse: 0.0620171	valid_1's rmse: 0.0824206
# Early stopping, best iteration is:
# [22839]	training's rmse: 0.0620449	valid_1's rmse: 0.0824162
# Fold 5 finished.

# %%
# 테스트 데이터에 대한 예측 수행
test_preds = np.zeros(len(test_df))
for model in models:
    test_preds += model.predict(test_df) / kf.n_splits

# 로그 변환된 예측값을 원래 값으로 변환
test_preds_original = np.expm1(test_preds)
test_preds_original = np.round(test_preds_original).astype(int)

# 예측 결과를 데이터프레임으로 저장
preds_df = pd.DataFrame(test_preds_original, columns=['target'])
print(preds_df.shape)
# Out:
# (9272, 1)

# %%
preds_df.to_csv('../my_submission.csv', index=False)

# %%
output = pd.read_csv("../output2.csv")

# %%
# 1개
plt.figure(figsize=(10, 6))
plt.plot(preds_df['target'])
plt.xlabel('Index')
plt.ylabel('Target')
plt.grid(True)
plt.show()


# 2개
plt.figure(figsize=(10, 6))
plt.plot(preds_df['target'], label='fs', marker='o')
plt.plot(output['target'], label='xgb', marker='x')
plt.xlabel('Index')
plt.ylabel('Target')
plt.grid(True)
plt.show()
