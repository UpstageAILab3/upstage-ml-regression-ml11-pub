# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import gc

from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error

import lightgbm as lgb

import joblib

# 맥에서 글씨 깨짐 방지
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumBarunGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) # 폰트 설정
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# * ver7 : 피쳐 줄이고 로그 변환(제출 횟수 때문에 패스)
# * ver6 : 피쳐 줄이고 스케일링 없이(lgbm 트리기반이어서 그냥 넣어봤습니다.)
# * ver5 : 피쳐 줄이고 outlier iqr
# * ver4 : 피쳐 줄이고 hold out
# * ver3 : 피쳐 줄이고 stafied k-fold
#
# ----
#
# * 줄인 피쳐
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', 'target', 'is_test', '가장 가까운 거리',
#        '가장 가까운 버스 정류장 거리', '건물나이'],
#
# * 데이터 셋:
# 홍석님이 슬랙에 올리신 것

# %% [markdown]
# # Data Load

# %%
df = pd.read_csv('/root/home_predict/dataset/22_subway_line.csv')
# Out:
# /tmp/ipykernel_620129/636612162.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/root/home_predict/dataset/22_subway_line.csv')

# %% [markdown]
# ## 결측치 제거

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# 시군구                           0
# 번지                          227
# 본번                           75
# 부번                           75
# 아파트명                          0
# 전용면적                          0
# 계약년월                          0
# 계약일                           0
# 층                             0
# 건축년도                          0
# 도로명                           0
# 해제사유발생일                 1121899
# 등기신청일자                        0
# 거래유형                          0
# 중개사소재지                        0
# k-단지분류(아파트,주상복합등등)       877273
# k-전화번호                   876850
# k-팩스번호                   879348
# 단지소개기존clob              1058958
# k-세대타입(분양형태)             876125
# k-관리방식                   876125
# k-복도유형                   876454
# k-난방방식                   876125
# k-전체동수                   877207
# k-전체세대수                  876125
# k-건설사(시공사)                    0
# k-시행사                    877834
# k-사용검사일-사용승인일            876259
# k-연면적                    876125
# k-주거전용면적                 876170
# k-관리비부과면적                876125
# k-전용면적별세대현황(60이하)        876170
# k-전용면적별세대현황(60~85이하)     876170
# k-85~135이하               876170
# k-135초과                 1127765
# k-홈페이지                  1013523
# k-등록일자                  1116386
# k-수정일자                   876170
# 고용보험관리번호                 920757
# 경비비관리형태                  877561
# 세대전기계약방법                 885389
# 청소비관리형태                  877751
# 건축면적                     876279
# 주차대수                     876277
# 기타/의무/임대/임의=1/2/3/4      876125
# 단지승인일                    876854
# 사용허가여부                   876125
# 관리비 업로드                  876125
# 좌표X                           0
# 좌표Y                           0
# 단지신청일                    876187
# target                     9272
# is_test                       0
# 시군구 번지                      227
# 좌표X,좌표Y                       0
# 가장 가까운 거리                     0
# index                         0
# 역사_ID                         0
# 역사명                           0
# 호선                            0
# 위도                            0
# 경도                            0
# 인근 지하철 역 개수                   0
# 가장 가까운 버스 정류장 거리              0
# 가장 가까운 버스 정류장 index           0
# 가장 가까운 버스 정류장 노드 ID           0
# 가장 가까운 버스 정류소번호               0
# 가장 가까운 버스 정류소명                0
# 가장 가까운 버스 정류소 타입              0
# 가장 가까운 버스 정류장 X좌표             0
# 가장 가까운 버스 정류장 Y좌표             0
# 인근 버스 정류장 개수                  0
# 계약년                           0
# 계약월                           0
# GDP                           0
# 한국은행 기준금리                     0
# 기대 인플레이션                      0
# 지가지수                          0
# 아파트 인허가                       0
# 미분양                           0
# 거래량                           0
# 건설사 랭킹                        0
# 구                             0
# 동                             0
# 구별 지가지수                       0
# 공시지가 평균                       0
# 매수우위지수                        0
# 건물나이                          0
# 30년이상50년이하                    0
# 구매력지수                         0
# 거래활발지수                        0
# 매매가격 지수 증감률                   0
# 매매 대비 전세가격 비율                 0
# 아파트 카테고리                      0
# 지하철 카테고리                      0
# dtype: int64

# %%
# Null값이 100만개 이상인 칼럼은 삭제해보도록 하겠습니다.
print('결측치가 100만개 이하인 변수들 :', list(df.columns[df.isnull().sum() <= 1000000])) # 남겨질 변수들은 아래와 같습니다.
print('결측치가 100만개 이상인 변수들 : ', list(df.columns[df.isnull().sum() >= 1000000]))
# Out:
# 결측치가 100만개 이하인 변수들 : ['시군구', '번지', '본번', '부번', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도', '도로명', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)', 'k-전화번호', 'k-팩스번호', 'k-세대타입(분양형태)', 'k-관리방식', 'k-복도유형', 'k-난방방식', 'k-전체동수', 'k-전체세대수', 'k-건설사(시공사)', 'k-시행사', 'k-사용검사일-사용승인일', 'k-연면적', 'k-주거전용면적', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)', 'k-전용면적별세대현황(60~85이하)', 'k-85~135이하', 'k-수정일자', '고용보험관리번호', '경비비관리형태', '세대전기계약방법', '청소비관리형태', '건축면적', '주차대수', '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드', '좌표X', '좌표Y', '단지신청일', 'target', 'is_test', '시군구 번지', '좌표X,좌표Y', '가장 가까운 거리', 'index', '역사_ID', '역사명', '호선', '위도', '경도', '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호', '가장 가까운 버스 정류소명', '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표', '가장 가까운 버스 정류장 Y좌표', '인근 버스 정류장 개수', '계약년', '계약월', 'GDP', '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양', '거래량', '건설사 랭킹', '구', '동', '구별 지가지수', '공시지가 평균', '매수우위지수', '건물나이', '30년이상50년이하', '구매력지수', '거래활발지수', '매매가격 지수 증감률', '매매 대비 전세가격 비율', '아파트 카테고리', '지하철 카테고리']
# 결측치가 100만개 이상인 변수들 :  ['해제사유발생일', '단지소개기존clob', 'k-135초과', 'k-홈페이지', 'k-등록일자']

# %%
df.drop(['해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)', 'k-전화번호',
         'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-복도유형', 'k-난방방식', 'k-전체동수', 'k-전체세대수',
         'k-사용검사일-사용승인일', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)', 'k-전용면적별세대현황(60~85이하)',
         'k-85~135이하', 'k-135초과', 'k-홈페이지', 'k-등록일자', 'k-수정일자', '고용보험관리번호', '경비비관리형태',
         '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드', '단지신청일'], axis=1, inplace=True)

# %%
df.drop(['시군구', '번지', '본번', '부번', '아파트명', '도로명', 'k-관리방식', 'k-건설사(시공사)', 'k-시행사', 'k-연면적', 'k-주거전용면적',
         '세대전기계약방법', '청소비관리형태', '건축면적', '주차대수', '시군구 번지', '좌표X,좌표Y', 'index', '역사_ID', '역사명', '위도', '경도',
         '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호', '가장 가까운 버스 정류소명',
         '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표', '가장 가까운 버스 정류장 Y좌표', '동', 
         ], axis=1, inplace=True)

# %%
df.drop(['호선', '인근 지하철 역 개수', '인근 버스 정류장 개수', '한국은행 기준금리', '기대 인플레이션', '지가지수', '아파트 인허가', '미분양',
       '거래량', '건설사 랭킹', '구', '구별 지가지수', '공시지가 평균', '매수우위지수','30년이상50년이하', '구매력지수', '거래활발지수', '매매가격 지수 증감률', '매매 대비 전세가격 비율',
       '아파트 카테고리', '지하철 카테고리','GDP'],axis = 1, inplace=True)

# %%
# 계약년월, 계약일, 건축년도, 계약년 변수 제거

df.drop(['계약년월', '계약일','계약년'], axis=1, inplace=True)

# %%
df.drop(['계약월_sin'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', 'target', 'is_test', '가장 가까운 거리',
#        '가장 가까운 버스 정류장 거리', '건물나이'],
#       dtype='object')

# %%
def scailing(col, scaler_type):
    if scaler_type == 'min_max': scaler = MinMaxScaler()
    else : scaler = StandardScaler()

    return scaler.fit_transform(df[[col]])

cols = ['전용면적', '층', '건축년도', '좌표X', '좌표Y', '가장 가까운 거리',
       '가장 가까운 버스 정류장 거리', '건물나이']

for col in cols:
    print(col)
    scaler_type = 'min_max'
    # if col == ['계약월_sin']: scaler_type = 'standard'

    df[[col]] = scailing(col, scaler_type)

# %% [markdown]
# ## train, test 분할

# %%
# 추가한 feature들 중 일부 제거
df_dropped = df.drop([], axis=1)

# %%
df_dropped.columns
# Out:
# Index(['전용면적', '층', '건축년도', '좌표X', '좌표Y', 'target', 'is_test', '가장 가까운 거리',
#        '가장 가까운 버스 정류장 거리', '건물나이'],
#       dtype='object')

# %%
train_df = df_dropped[df_dropped['is_test'] == 0]
test_df = df_dropped[df_dropped['is_test'] == 1]

# %%
train_df.drop(['is_test'], axis = 1, inplace=True)
test_df.drop(['is_test'], axis = 1, inplace=True)
# Out:
# /tmp/ipykernel_620129/3351882249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(['is_test'], axis = 1, inplace=True)
# /tmp/ipykernel_620129/3351882249.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(['is_test'], axis = 1, inplace=True)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (1118822, 9)
# (9272, 9)

# %%
train_X, valid_X, train_y, valid_y = train_test_split(train_X, train_y, train_size=0.95, test_size=0.05, random_state=74)

print(train_X.shape, train_y.shape)
print(valid_X.shape, valid_y.shape)
# Out:
# (1062880, 8) (1062880,)
# (55942, 8) (55942,)

# %%
params = {
    'n_estimators': 100000,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'metric_freq': 20,
    'device': 'gpu',
    'verbosity': 0
}

model = lgb.LGBMRegressor(n_estimators=100000,
                          metric='rmse', data_sample_strategy='goss'
                          )

model.fit(
    train_X, train_y,
    eval_set = [(train_X, train_y), (valid_X, valid_y)],
    eval_metric='rmse',
    callbacks=[lgb.early_stopping(stopping_rounds=60),
               lgb.log_evaluation(period=10, show_stdv=True)]
)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003550 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1465
# [LightGBM] [Info] Number of data points in the train set: 1062880, number of used features: 8
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 57982.908459
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 30239.2	valid_1's rmse: 30761.5
# [20]	training's rmse: 23903.6	valid_1's rmse: 24222.7
# [30]	training's rmse: 20530.1	valid_1's rmse: 20718.8
# [40]	training's rmse: 18328	valid_1's rmse: 18455.3
# [50]	training's rmse: 16747.8	valid_1's rmse: 16856.4
# [60]	training's rmse: 15727.1	valid_1's rmse: 15812.2
# [70]	training's rmse: 14990.3	valid_1's rmse: 15067.2
# [80]	training's rmse: 14473.3	valid_1's rmse: 14567.1
# [90]	training's rmse: 14034.2	valid_1's rmse: 14138.1
# [100]	training's rmse: 13667	valid_1's rmse: 13769.8
# [110]	training's rmse: 13347.5	valid_1's rmse: 13449.9
# [120]	training's rmse: 13095.6	valid_1's rmse: 13201.6
# [130]	training's rmse: 12880.9	valid_1's rmse: 13008.4
# [140]	training's rmse: 12649.2	valid_1's rmse: 12760.1
# [150]	training's rmse: 12487.6	valid_1's rmse: 12611.7
# [160]	training's rmse: 12324.4	valid_1's rmse: 12459.1
# [170]	training's rmse: 12168.9	valid_1's rmse: 12309.2
# [180]	training's rmse: 12018.8	valid_1's rmse: 12162.6
# [190]	training's rmse: 11881.5	valid_1's rmse: 12037.6
# [200]	training's rmse: 11759.1	valid_1's rmse: 11923.1
# [210]	training's rmse: 11663.9	valid_1's rmse: 11829.6
# [220]	training's rmse: 11552.5	valid_1's rmse: 11732.7
# [230]	training's rmse: 11456.1	valid_1's rmse: 11644
# [240]	training's rmse: 11341.4	valid_1's rmse: 11535.4
# [250]	training's rmse: 11230.5	valid_1's rmse: 11428
# [260]	training's rmse: 11148.5	valid_1's rmse: 11354.8
# [270]	training's rmse: 11054.9	valid_1's rmse: 11259.7
# [280]	training's rmse: 10977.6	valid_1's rmse: 11193.6
# [290]	training's rmse: 10880.5	valid_1's rmse: 11106.1
# [300]	training's rmse: 10816.1	valid_1's rmse: 11040.7
# [310]	training's rmse: 10740.8	valid_1's rmse: 10972.7
# [320]	training's rmse: 10660.6	valid_1's rmse: 10899.6
# [330]	training's rmse: 10591.4	valid_1's rmse: 10836.9
# [340]	training's rmse: 10541	valid_1's rmse: 10792.9
# [350]	training's rmse: 10472.2	valid_1's rmse: 10726.6
# [360]	training's rmse: 10402.5	valid_1's rmse: 10662.7
# [370]	training's rmse: 10333.2	valid_1's rmse: 10596
# [380]	training's rmse: 10259.6	valid_1's rmse: 10530.3
# [390]	training's rmse: 10208.2	valid_1's rmse: 10476.6
# [400]	training's rmse: 10154.8	valid_1's rmse: 10422.8
# [410]	training's rmse: 10108.3	valid_1's rmse: 10381
# [420]	training's rmse: 10063.6	valid_1's rmse: 10342.7
# [430]	training's rmse: 10008.7	valid_1's rmse: 10292.9
# [440]	training's rmse: 9956.88	valid_1's rmse: 10244.2
# [450]	training's rmse: 9906.47	valid_1's rmse: 10201
# [460]	training's rmse: 9853.21	valid_1's rmse: 10152
# [470]	training's rmse: 9801.4	valid_1's rmse: 10105.6
# [480]	training's rmse: 9754.98	valid_1's rmse: 10064.5
# [490]	training's rmse: 9716.31	valid_1's rmse: 10032.1
# [500]	training's rmse: 9670.3	valid_1's rmse: 9990.1
# [510]	training's rmse: 9626.96	valid_1's rmse: 9947.76
# [520]	training's rmse: 9591.69	valid_1's rmse: 9917.66
# [530]	training's rmse: 9548.4	valid_1's rmse: 9883.86
# [540]	training's rmse: 9511.47	valid_1's rmse: 9854.82
# [550]	training's rmse: 9465.46	valid_1's rmse: 9809.23
# [560]	training's rmse: 9426.9	valid_1's rmse: 9774.84
# [570]	training's rmse: 9394.3	valid_1's rmse: 9751.11
# [580]	training's rmse: 9360.02	valid_1's rmse: 9721.44
# [590]	training's rmse: 9326.7	valid_1's rmse: 9690.63
# [600]	training's rmse: 9287.68	valid_1's rmse: 9657.11
# [610]	training's rmse: 9262.68	valid_1's rmse: 9633.37
# [620]	training's rmse: 9229.12	valid_1's rmse: 9609.94
# [630]	training's rmse: 9187.86	valid_1's rmse: 9563.48
# [640]	training's rmse: 9156.85	valid_1's rmse: 9538.3
# [650]	training's rmse: 9122.7	valid_1's rmse: 9508.61
# [660]	training's rmse: 9086.72	valid_1's rmse: 9477.11
# [670]	training's rmse: 9060.74	valid_1's rmse: 9455.58
# [680]	training's rmse: 9031.66	valid_1's rmse: 9429.35
# [690]	training's rmse: 9006.17	valid_1's rmse: 9411.98
# [700]	training's rmse: 8977.94	valid_1's rmse: 9389.05
# [710]	training's rmse: 8947.68	valid_1's rmse: 9363.28
# [720]	training's rmse: 8921.92	valid_1's rmse: 9337.15
# [730]	training's rmse: 8886.92	valid_1's rmse: 9306.62
# [740]	training's rmse: 8864.38	valid_1's rmse: 9288.78
# [750]	training's rmse: 8835.02	valid_1's rmse: 9261.35
# [760]	training's rmse: 8812.65	valid_1's rmse: 9243.67
# [770]	training's rmse: 8786.54	valid_1's rmse: 9213.68
# [780]	training's rmse: 8759.99	valid_1's rmse: 9193.12
# [790]	training's rmse: 8734.39	valid_1's rmse: 9171.54
# [800]	training's rmse: 8713.75	valid_1's rmse: 9152.31
# [810]	training's rmse: 8690.85	valid_1's rmse: 9132.06
# [820]	training's rmse: 8667.49	valid_1's rmse: 9109.13
# [830]	training's rmse: 8639.89	valid_1's rmse: 9085.86
# [840]	training's rmse: 8618.67	valid_1's rmse: 9066.23
# [850]	training's rmse: 8598.88	valid_1's rmse: 9051.68
# [860]	training's rmse: 8578.62	valid_1's rmse: 9035.46
# [870]	training's rmse: 8552.17	valid_1's rmse: 9010.66
# [880]	training's rmse: 8531.02	valid_1's rmse: 8990.82
# [890]	training's rmse: 8510.72	valid_1's rmse: 8974.29
# [900]	training's rmse: 8491.13	valid_1's rmse: 8955.77
# [910]	training's rmse: 8465.32	valid_1's rmse: 8935.02
# [920]	training's rmse: 8443.65	valid_1's rmse: 8917.54
# [930]	training's rmse: 8426.78	valid_1's rmse: 8903.71
# [940]	training's rmse: 8406.56	valid_1's rmse: 8888.27
# [950]	training's rmse: 8386.15	valid_1's rmse: 8871.84
# [960]	training's rmse: 8364.25	valid_1's rmse: 8853.86
# [970]	training's rmse: 8347.05	valid_1's rmse: 8837.19
# [980]	training's rmse: 8333.14	valid_1's rmse: 8825.63
# [990]	training's rmse: 8314.24	valid_1's rmse: 8809.76
# [1000]	training's rmse: 8294.02	valid_1's rmse: 8796.9
# [1010]	training's rmse: 8270.29	valid_1's rmse: 8778.56
# [1020]	training's rmse: 8258.14	valid_1's rmse: 8769.85
# [1030]	training's rmse: 8235.2	valid_1's rmse: 8752.75
# [1040]	training's rmse: 8218.33	valid_1's rmse: 8737.53
# [1050]	training's rmse: 8202.84	valid_1's rmse: 8722.4
# [1060]	training's rmse: 8183.42	valid_1's rmse: 8705.18
# [1070]	training's rmse: 8163.88	valid_1's rmse: 8690.44
# [1080]	training's rmse: 8147.94	valid_1's rmse: 8676.79
# [1090]	training's rmse: 8129.65	valid_1's rmse: 8659.17
# [1100]	training's rmse: 8111.76	valid_1's rmse: 8642.45
# [1110]	training's rmse: 8097.16	valid_1's rmse: 8630.78
# [1120]	training's rmse: 8080.81	valid_1's rmse: 8616.96
# [1130]	training's rmse: 8064.54	valid_1's rmse: 8602.55
# [1140]	training's rmse: 8047.05	valid_1's rmse: 8589.9
# [1150]	training's rmse: 8032.57	valid_1's rmse: 8578.1
# [1160]	training's rmse: 8018.53	valid_1's rmse: 8567.13
# [1170]	training's rmse: 8005.07	valid_1's rmse: 8556.01
# [1180]	training's rmse: 7987.27	valid_1's rmse: 8539.78
# [1190]	training's rmse: 7969.05	valid_1's rmse: 8519.7
# [1200]	training's rmse: 7951.1	valid_1's rmse: 8503.06
# [1210]	training's rmse: 7938.16	valid_1's rmse: 8492.63
# [1220]	training's rmse: 7921.63	valid_1's rmse: 8478.05
# [1230]	training's rmse: 7903.8	valid_1's rmse: 8462.46
# [1240]	training's rmse: 7887.55	valid_1's rmse: 8449.22
# [1250]	training's rmse: 7870.05	valid_1's rmse: 8435.95
# [1260]	training's rmse: 7854.52	valid_1's rmse: 8423.39
# [1270]	training's rmse: 7841.09	valid_1's rmse: 8414.48
# [1280]	training's rmse: 7826.58	valid_1's rmse: 8399.99
# [1290]	training's rmse: 7810.96	valid_1's rmse: 8385.84
# [1300]	training's rmse: 7795.85	valid_1's rmse: 8374.4
# [1310]	training's rmse: 7786.11	valid_1's rmse: 8366.56
# [1320]	training's rmse: 7769.95	valid_1's rmse: 8355.37
# [1330]	training's rmse: 7757.88	valid_1's rmse: 8346.18
# [1340]	training's rmse: 7744.21	valid_1's rmse: 8333.68
# [1350]	training's rmse: 7734.03	valid_1's rmse: 8323.13
# [1360]	training's rmse: 7722.17	valid_1's rmse: 8313.99
# [1370]	training's rmse: 7712.14	valid_1's rmse: 8310.18
# [1380]	training's rmse: 7701.02	valid_1's rmse: 8300.04
# [1390]	training's rmse: 7687.29	valid_1's rmse: 8289.54
# [1400]	training's rmse: 7675.46	valid_1's rmse: 8280.87
# [1410]	training's rmse: 7664.55	valid_1's rmse: 8272.14
# [1420]	training's rmse: 7653.15	valid_1's rmse: 8265.18
# [1430]	training's rmse: 7641.44	valid_1's rmse: 8257.42
# [1440]	training's rmse: 7632.36	valid_1's rmse: 8251.81
# [1450]	training's rmse: 7619.99	valid_1's rmse: 8238.69
# [1460]	training's rmse: 7610.56	valid_1's rmse: 8231.13
# [1470]	training's rmse: 7600.31	valid_1's rmse: 8222.85
# [1480]	training's rmse: 7591.44	valid_1's rmse: 8219.3
# [1490]	training's rmse: 7580.17	valid_1's rmse: 8210.15
# [1500]	training's rmse: 7570.13	valid_1's rmse: 8201.61
# [1510]	training's rmse: 7558.92	valid_1's rmse: 8191.58
# [1520]	training's rmse: 7548.6	valid_1's rmse: 8177.37
# [1530]	training's rmse: 7535.44	valid_1's rmse: 8167.8
# [1540]	training's rmse: 7525.54	valid_1's rmse: 8158.44
# [1550]	training's rmse: 7514.34	valid_1's rmse: 8149.1
# [1560]	training's rmse: 7503.22	valid_1's rmse: 8141.2
# [1570]	training's rmse: 7493.52	valid_1's rmse: 8133.15
# [1580]	training's rmse: 7481.98	valid_1's rmse: 8124.28
# [1590]	training's rmse: 7472.12	valid_1's rmse: 8115.45
# [1600]	training's rmse: 7462.59	valid_1's rmse: 8105.88
# [1610]	training's rmse: 7452.42	valid_1's rmse: 8096.92
# [1620]	training's rmse: 7442.8	valid_1's rmse: 8091.58
# [1630]	training's rmse: 7433.43	valid_1's rmse: 8082.67
# [1640]	training's rmse: 7423.5	valid_1's rmse: 8074.25
# [1650]	training's rmse: 7413.94	valid_1's rmse: 8066
# [1660]	training's rmse: 7404.87	valid_1's rmse: 8061.17
# [1670]	training's rmse: 7393.08	valid_1's rmse: 8049.87
# [1680]	training's rmse: 7382.05	valid_1's rmse: 8043.47
# [1690]	training's rmse: 7373.83	valid_1's rmse: 8035.13
# [1700]	training's rmse: 7366	valid_1's rmse: 8032.43
# [1710]	training's rmse: 7355.55	valid_1's rmse: 8023.65
# [1720]	training's rmse: 7347.14	valid_1's rmse: 8016.05
# [1730]	training's rmse: 7337.72	valid_1's rmse: 8007.84
# [1740]	training's rmse: 7328.26	valid_1's rmse: 8000.75
# [1750]	training's rmse: 7319.12	valid_1's rmse: 7992.39
# [1760]	training's rmse: 7310.39	valid_1's rmse: 7984.83
# [1770]	training's rmse: 7303.28	valid_1's rmse: 7978.87
# [1780]	training's rmse: 7293.38	valid_1's rmse: 7971.42
# [1790]	training's rmse: 7280.36	valid_1's rmse: 7958.2
# [1800]	training's rmse: 7270.99	valid_1's rmse: 7950.32
# [1810]	training's rmse: 7261.53	valid_1's rmse: 7943.78
# [1820]	training's rmse: 7252.67	valid_1's rmse: 7937.76
# [1830]	training's rmse: 7243.14	valid_1's rmse: 7933.93
# [1840]	training's rmse: 7232.97	valid_1's rmse: 7925.85
# [1850]	training's rmse: 7225.84	valid_1's rmse: 7918.28
# [1860]	training's rmse: 7217.54	valid_1's rmse: 7912.5
# [1870]	training's rmse: 7208.67	valid_1's rmse: 7901.52
# [1880]	training's rmse: 7202.01	valid_1's rmse: 7895.88
# [1890]	training's rmse: 7195.05	valid_1's rmse: 7890.93
# [1900]	training's rmse: 7185.55	valid_1's rmse: 7887.17
# [1910]	training's rmse: 7180.08	valid_1's rmse: 7882.76
# [1920]	training's rmse: 7173.04	valid_1's rmse: 7877.08
# [1930]	training's rmse: 7165.93	valid_1's rmse: 7871.79
# [1940]	training's rmse: 7156.79	valid_1's rmse: 7867.53
# [1950]	training's rmse: 7148.89	valid_1's rmse: 7862.14
# [1960]	training's rmse: 7142.77	valid_1's rmse: 7858.67
# [1970]	training's rmse: 7136.8	valid_1's rmse: 7855.84
# [1980]	training's rmse: 7129.94	valid_1's rmse: 7850.72
# [1990]	training's rmse: 7122.69	valid_1's rmse: 7844.15
# [2000]	training's rmse: 7113.99	valid_1's rmse: 7841
# [2010]	training's rmse: 7107.51	valid_1's rmse: 7839.68
# [2020]	training's rmse: 7099.42	valid_1's rmse: 7834.23
# [2030]	training's rmse: 7093.1	valid_1's rmse: 7829.82
# [2040]	training's rmse: 7084.74	valid_1's rmse: 7824.45
# [2050]	training's rmse: 7078.02	valid_1's rmse: 7819.6
# [2060]	training's rmse: 7070.78	valid_1's rmse: 7811.88
# [2070]	training's rmse: 7063.58	valid_1's rmse: 7808.53
# [2080]	training's rmse: 7058.14	valid_1's rmse: 7804.66
# [2090]	training's rmse: 7050.52	valid_1's rmse: 7800.63
# [2100]	training's rmse: 7043.82	valid_1's rmse: 7796.09
# [2110]	training's rmse: 7037.05	valid_1's rmse: 7790.62
# [2120]	training's rmse: 7030.73	valid_1's rmse: 7784.87
# [2130]	training's rmse: 7022.99	valid_1's rmse: 7779.79
# [2140]	training's rmse: 7015.39	valid_1's rmse: 7775.14
# [2150]	training's rmse: 7008.17	valid_1's rmse: 7769.36
# [2160]	training's rmse: 7002.19	valid_1's rmse: 7764.45
# [2170]	training's rmse: 6996.29	valid_1's rmse: 7758.94
# [2180]	training's rmse: 6989.53	valid_1's rmse: 7751.24
# [2190]	training's rmse: 6984.86	valid_1's rmse: 7749.78
# [2200]	training's rmse: 6977.95	valid_1's rmse: 7743.49
# [2210]	training's rmse: 6971.13	valid_1's rmse: 7740.05
# [2220]	training's rmse: 6965.25	valid_1's rmse: 7735.07
# [2230]	training's rmse: 6959.47	valid_1's rmse: 7732.65
# [2240]	training's rmse: 6953.66	valid_1's rmse: 7728.11
# [2250]	training's rmse: 6947.12	valid_1's rmse: 7721.83
# [2260]	training's rmse: 6940.25	valid_1's rmse: 7716.05
# [2270]	training's rmse: 6934.94	valid_1's rmse: 7712.19
# [2280]	training's rmse: 6928.31	valid_1's rmse: 7705.15
# [2290]	training's rmse: 6922.39	valid_1's rmse: 7701.82
# [2300]	training's rmse: 6917.23	valid_1's rmse: 7698.42
# [2310]	training's rmse: 6909.21	valid_1's rmse: 7691.5
# [2320]	training's rmse: 6904.37	valid_1's rmse: 7687.66
# [2330]	training's rmse: 6898.73	valid_1's rmse: 7683.07
# [2340]	training's rmse: 6894.25	valid_1's rmse: 7679.62
# [2350]	training's rmse: 6888.85	valid_1's rmse: 7675.89
# [2360]	training's rmse: 6883.83	valid_1's rmse: 7674.36
# [2370]	training's rmse: 6877.21	valid_1's rmse: 7670.13
# [2380]	training's rmse: 6871.21	valid_1's rmse: 7665.16
# [2390]	training's rmse: 6863.6	valid_1's rmse: 7659.38
# [2400]	training's rmse: 6857.76	valid_1's rmse: 7654.77
# [2410]	training's rmse: 6852.86	valid_1's rmse: 7652.33
# [2420]	training's rmse: 6848.25	valid_1's rmse: 7647.84
# [2430]	training's rmse: 6841.51	valid_1's rmse: 7644.66
# [2440]	training's rmse: 6836.19	valid_1's rmse: 7640.85
# [2450]	training's rmse: 6830.07	valid_1's rmse: 7635.88
# [2460]	training's rmse: 6825.21	valid_1's rmse: 7632.39
# [2470]	training's rmse: 6819.09	valid_1's rmse: 7628.29
# [2480]	training's rmse: 6811.86	valid_1's rmse: 7624.2
# [2490]	training's rmse: 6807.42	valid_1's rmse: 7622.98
# [2500]	training's rmse: 6801.94	valid_1's rmse: 7619.12
# [2510]	training's rmse: 6797.58	valid_1's rmse: 7617.09
# [2520]	training's rmse: 6792.09	valid_1's rmse: 7615.06
# [2530]	training's rmse: 6786.07	valid_1's rmse: 7610.15
# [2540]	training's rmse: 6781.94	valid_1's rmse: 7606.74
# [2550]	training's rmse: 6777.6	valid_1's rmse: 7604.31
# [2560]	training's rmse: 6773.28	valid_1's rmse: 7601.4
# [2570]	training's rmse: 6768.36	valid_1's rmse: 7599.12
# [2580]	training's rmse: 6764.06	valid_1's rmse: 7596.93
# [2590]	training's rmse: 6759.06	valid_1's rmse: 7594.56
# [2600]	training's rmse: 6752.55	valid_1's rmse: 7589.65
# [2610]	training's rmse: 6748.91	valid_1's rmse: 7587.11
# [2620]	training's rmse: 6743.87	valid_1's rmse: 7583.18
# [2630]	training's rmse: 6739.3	valid_1's rmse: 7581.95
# [2640]	training's rmse: 6733.99	valid_1's rmse: 7576.51
# [2650]	training's rmse: 6728.43	valid_1's rmse: 7572.57
# [2660]	training's rmse: 6724.19	valid_1's rmse: 7569.87
# [2670]	training's rmse: 6719.95	valid_1's rmse: 7566.76
# [2680]	training's rmse: 6714.78	valid_1's rmse: 7561.83
# [2690]	training's rmse: 6710.1	valid_1's rmse: 7558.01
# [2700]	training's rmse: 6707.04	valid_1's rmse: 7556.83
# [2710]	training's rmse: 6701.95	valid_1's rmse: 7551.72
# [2720]	training's rmse: 6697.14	valid_1's rmse: 7549.86
# [2730]	training's rmse: 6691.72	valid_1's rmse: 7545.76
# [2740]	training's rmse: 6686.96	valid_1's rmse: 7544.62
# [2750]	training's rmse: 6683.23	valid_1's rmse: 7541.71
# [2760]	training's rmse: 6679.75	valid_1's rmse: 7538.98
# [2770]	training's rmse: 6674.14	valid_1's rmse: 7535.94
# [2780]	training's rmse: 6669.6	valid_1's rmse: 7531.19
# [2790]	training's rmse: 6665.95	valid_1's rmse: 7528.91
# [2800]	training's rmse: 6662.01	valid_1's rmse: 7526.21
# [2810]	training's rmse: 6658.72	valid_1's rmse: 7523.9
# [2820]	training's rmse: 6654.24	valid_1's rmse: 7519.99
# [2830]	training's rmse: 6650.15	valid_1's rmse: 7517.65
# [2840]	training's rmse: 6645.04	valid_1's rmse: 7514.82
# [2850]	training's rmse: 6639.35	valid_1's rmse: 7510.69
# [2860]	training's rmse: 6634.98	valid_1's rmse: 7509.16
# [2870]	training's rmse: 6630.9	valid_1's rmse: 7506.93
# [2880]	training's rmse: 6627.74	valid_1's rmse: 7504.39
# [2890]	training's rmse: 6623.36	valid_1's rmse: 7500.71
# [2900]	training's rmse: 6619.31	valid_1's rmse: 7497.7
# [2910]	training's rmse: 6615.37	valid_1's rmse: 7494.26
# [2920]	training's rmse: 6610.45	valid_1's rmse: 7490.87
# [2930]	training's rmse: 6605.54	valid_1's rmse: 7485.41
# [2940]	training's rmse: 6600.94	valid_1's rmse: 7482.32
# [2950]	training's rmse: 6596.89	valid_1's rmse: 7479.13
# [2960]	training's rmse: 6591.67	valid_1's rmse: 7475.78
# [2970]	training's rmse: 6586.56	valid_1's rmse: 7472.87
# [2980]	training's rmse: 6582.4	valid_1's rmse: 7470.99
# [2990]	training's rmse: 6578.2	valid_1's rmse: 7468.27
# [3000]	training's rmse: 6573.49	valid_1's rmse: 7465.41
# [3010]	training's rmse: 6569.43	valid_1's rmse: 7463.81
# [3020]	training's rmse: 6566.41	valid_1's rmse: 7462.15
# [3030]	training's rmse: 6562.7	valid_1's rmse: 7461.14
# [3040]	training's rmse: 6558.7	valid_1's rmse: 7459.18
# [3050]	training's rmse: 6555.1	valid_1's rmse: 7456.37
# [3060]	training's rmse: 6551.29	valid_1's rmse: 7453.38
# [3070]	training's rmse: 6547.12	valid_1's rmse: 7450
# [3080]	training's rmse: 6543.68	valid_1's rmse: 7447.32
# [3090]	training's rmse: 6539.59	valid_1's rmse: 7444.19
# [3100]	training's rmse: 6535.01	valid_1's rmse: 7440.2
# [3110]	training's rmse: 6531.51	valid_1's rmse: 7436.2
# [3120]	training's rmse: 6528.22	valid_1's rmse: 7433.95
# [3130]	training's rmse: 6523.95	valid_1's rmse: 7431.29
# [3140]	training's rmse: 6520.32	valid_1's rmse: 7429.45
# [3150]	training's rmse: 6516.09	valid_1's rmse: 7425.35
# [3160]	training's rmse: 6512.71	valid_1's rmse: 7422.16
# [3170]	training's rmse: 6509.12	valid_1's rmse: 7420.06
# [3180]	training's rmse: 6505.66	valid_1's rmse: 7416.75
# [3190]	training's rmse: 6502.15	valid_1's rmse: 7415.14
# [3200]	training's rmse: 6497.15	valid_1's rmse: 7411.88
# [3210]	training's rmse: 6493.5	valid_1's rmse: 7409.41
# [3220]	training's rmse: 6489.78	valid_1's rmse: 7407.6
# [3230]	training's rmse: 6485.58	valid_1's rmse: 7404.38
# [3240]	training's rmse: 6481.92	valid_1's rmse: 7403.51
# [3250]	training's rmse: 6478.09	valid_1's rmse: 7401.19
# [3260]	training's rmse: 6474.83	valid_1's rmse: 7399.82
# [3270]	training's rmse: 6470.91	valid_1's rmse: 7397.49
# [3280]	training's rmse: 6467.27	valid_1's rmse: 7395.05
# [3290]	training's rmse: 6462.88	valid_1's rmse: 7391.33
# [3300]	training's rmse: 6459.18	valid_1's rmse: 7388.53
# [3310]	training's rmse: 6456.17	valid_1's rmse: 7385.12
# [3320]	training's rmse: 6452.51	valid_1's rmse: 7383.37
# [3330]	training's rmse: 6448.54	valid_1's rmse: 7381.67
# [3340]	training's rmse: 6445.19	valid_1's rmse: 7379.81
# [3350]	training's rmse: 6441.8	valid_1's rmse: 7376.53
# [3360]	training's rmse: 6436.65	valid_1's rmse: 7373.17
# [3370]	training's rmse: 6433.71	valid_1's rmse: 7370.62
# [3380]	training's rmse: 6429.99	valid_1's rmse: 7367.29
# [3390]	training's rmse: 6426.92	valid_1's rmse: 7365.58
# [3400]	training's rmse: 6423.49	valid_1's rmse: 7363.52
# [3410]	training's rmse: 6421.06	valid_1's rmse: 7361.39
# [3420]	training's rmse: 6418.44	valid_1's rmse: 7359.03
# [3430]	training's rmse: 6414.05	valid_1's rmse: 7356.59
# [3440]	training's rmse: 6411.57	valid_1's rmse: 7355.93
# [3450]	training's rmse: 6407.66	valid_1's rmse: 7354.07
# [3460]	training's rmse: 6404.16	valid_1's rmse: 7352.24
# [3470]	training's rmse: 6400.79	valid_1's rmse: 7350.58
# [3480]	training's rmse: 6397.47	valid_1's rmse: 7348.65
# [3490]	training's rmse: 6394.49	valid_1's rmse: 7345.32
# [3500]	training's rmse: 6392.38	valid_1's rmse: 7344.45
# [3510]	training's rmse: 6388.38	valid_1's rmse: 7339.82
# [3520]	training's rmse: 6385.26	valid_1's rmse: 7337.66
# [3530]	training's rmse: 6381.72	valid_1's rmse: 7333.43
# [3540]	training's rmse: 6378.36	valid_1's rmse: 7330.45
# [3550]	training's rmse: 6375.18	valid_1's rmse: 7328.19
# [3560]	training's rmse: 6371.74	valid_1's rmse: 7325.05
# [3570]	training's rmse: 6369.06	valid_1's rmse: 7322.95
# [3580]	training's rmse: 6365.67	valid_1's rmse: 7320.71
# [3590]	training's rmse: 6361.63	valid_1's rmse: 7317.95
# [3600]	training's rmse: 6357.6	valid_1's rmse: 7315.6
# [3610]	training's rmse: 6354.75	valid_1's rmse: 7314.08
# [3620]	training's rmse: 6351.24	valid_1's rmse: 7312.28
# [3630]	training's rmse: 6348.5	valid_1's rmse: 7310.27
# [3640]	training's rmse: 6346.07	valid_1's rmse: 7308.59
# [3650]	training's rmse: 6343.5	valid_1's rmse: 7307.16
# [3660]	training's rmse: 6340.54	valid_1's rmse: 7305.9
# [3670]	training's rmse: 6337.53	valid_1's rmse: 7303.17
# [3680]	training's rmse: 6334.35	valid_1's rmse: 7301.25
# [3690]	training's rmse: 6331.75	valid_1's rmse: 7299.98
# [3700]	training's rmse: 6328.79	valid_1's rmse: 7298.8
# [3710]	training's rmse: 6326.18	valid_1's rmse: 7296.95
# [3720]	training's rmse: 6323.85	valid_1's rmse: 7295.05
# [3730]	training's rmse: 6321.02	valid_1's rmse: 7294.06
# [3740]	training's rmse: 6318.76	valid_1's rmse: 7292.61
# [3750]	training's rmse: 6315.81	valid_1's rmse: 7290.07
# [3760]	training's rmse: 6312.54	valid_1's rmse: 7288.42
# [3770]	training's rmse: 6310.01	valid_1's rmse: 7286.07
# [3780]	training's rmse: 6306.41	valid_1's rmse: 7283.63
# [3790]	training's rmse: 6303.29	valid_1's rmse: 7282.53
# [3800]	training's rmse: 6300.1	valid_1's rmse: 7280.4
# [3810]	training's rmse: 6296.9	valid_1's rmse: 7278.1
# [3820]	training's rmse: 6294.46	valid_1's rmse: 7276.1
# [3830]	training's rmse: 6291.33	valid_1's rmse: 7274.55
# [3840]	training's rmse: 6287.3	valid_1's rmse: 7272.5
# [3850]	training's rmse: 6284.59	valid_1's rmse: 7272.12
# [3860]	training's rmse: 6280.89	valid_1's rmse: 7270.74
# [3870]	training's rmse: 6277.05	valid_1's rmse: 7268.66
# [3880]	training's rmse: 6274.73	valid_1's rmse: 7267.43
# [3890]	training's rmse: 6271.71	valid_1's rmse: 7266.8
# [3900]	training's rmse: 6268.47	valid_1's rmse: 7264.89
# [3910]	training's rmse: 6265.5	valid_1's rmse: 7263.19
# [3920]	training's rmse: 6263.14	valid_1's rmse: 7262.17
# [3930]	training's rmse: 6260.56	valid_1's rmse: 7260.45
# [3940]	training's rmse: 6257.73	valid_1's rmse: 7256.8
# [3950]	training's rmse: 6255.3	valid_1's rmse: 7255.8
# [3960]	training's rmse: 6252.71	valid_1's rmse: 7254.13
# [3970]	training's rmse: 6250.07	valid_1's rmse: 7252.33
# [3980]	training's rmse: 6247.09	valid_1's rmse: 7250.52
# [3990]	training's rmse: 6243.99	valid_1's rmse: 7248.51
# [4000]	training's rmse: 6240.97	valid_1's rmse: 7245.61
# [4010]	training's rmse: 6238.76	valid_1's rmse: 7244.55
# [4020]	training's rmse: 6236.21	valid_1's rmse: 7242.57
# [4030]	training's rmse: 6234.17	valid_1's rmse: 7240.35
# [4040]	training's rmse: 6231.34	valid_1's rmse: 7238.95
# [4050]	training's rmse: 6229.05	valid_1's rmse: 7237.94
# [4060]	training's rmse: 6226.01	valid_1's rmse: 7235.87
# [4070]	training's rmse: 6223.82	valid_1's rmse: 7234.82
# [4080]	training's rmse: 6221.06	valid_1's rmse: 7232.93
# [4090]	training's rmse: 6218.9	valid_1's rmse: 7232.08
# [4100]	training's rmse: 6216.27	valid_1's rmse: 7232.24
# [4110]	training's rmse: 6213.43	valid_1's rmse: 7230.6
# [4120]	training's rmse: 6210.92	valid_1's rmse: 7227.54
# [4130]	training's rmse: 6208.07	valid_1's rmse: 7226.18
# [4140]	training's rmse: 6205.56	valid_1's rmse: 7225.11
# [4150]	training's rmse: 6202.72	valid_1's rmse: 7222.94
# [4160]	training's rmse: 6200.39	valid_1's rmse: 7221.97
# [4170]	training's rmse: 6198.31	valid_1's rmse: 7220.62
# [4180]	training's rmse: 6195.14	valid_1's rmse: 7219.25
# [4190]	training's rmse: 6192.44	valid_1's rmse: 7218.18
# [4200]	training's rmse: 6190.3	valid_1's rmse: 7216.47
# [4210]	training's rmse: 6187.46	valid_1's rmse: 7216.62
# [4220]	training's rmse: 6184.56	valid_1's rmse: 7214.48
# [4230]	training's rmse: 6181.51	valid_1's rmse: 7213.34
# [4240]	training's rmse: 6179.13	valid_1's rmse: 7212.15
# [4250]	training's rmse: 6176.73	valid_1's rmse: 7209.89
# [4260]	training's rmse: 6174.42	valid_1's rmse: 7209.6
# [4270]	training's rmse: 6172.57	valid_1's rmse: 7209.06
# [4280]	training's rmse: 6170.03	valid_1's rmse: 7207.28
# [4290]	training's rmse: 6167.34	valid_1's rmse: 7205.86
# [4300]	training's rmse: 6164.54	valid_1's rmse: 7203.86
# [4310]	training's rmse: 6162.36	valid_1's rmse: 7203.2
# [4320]	training's rmse: 6159.73	valid_1's rmse: 7201.59
# [4330]	training's rmse: 6156.14	valid_1's rmse: 7199.84
# [4340]	training's rmse: 6153.71	valid_1's rmse: 7198.6
# [4350]	training's rmse: 6151.5	valid_1's rmse: 7197.25
# [4360]	training's rmse: 6148.95	valid_1's rmse: 7195.43
# [4370]	training's rmse: 6147.07	valid_1's rmse: 7195.28
# [4380]	training's rmse: 6144.34	valid_1's rmse: 7194.41
# [4390]	training's rmse: 6141.6	valid_1's rmse: 7191.75
# [4400]	training's rmse: 6139.21	valid_1's rmse: 7190.39
# [4410]	training's rmse: 6137.31	valid_1's rmse: 7189.36
# [4420]	training's rmse: 6135.37	valid_1's rmse: 7189.09
# [4430]	training's rmse: 6132.96	valid_1's rmse: 7187.19
# [4440]	training's rmse: 6130.78	valid_1's rmse: 7185.39
# [4450]	training's rmse: 6128.52	valid_1's rmse: 7184.03
# [4460]	training's rmse: 6125.71	valid_1's rmse: 7182.61
# [4470]	training's rmse: 6122.66	valid_1's rmse: 7182.09
# [4480]	training's rmse: 6120.34	valid_1's rmse: 7180.94
# [4490]	training's rmse: 6117.95	valid_1's rmse: 7179.58
# [4500]	training's rmse: 6115.34	valid_1's rmse: 7178.07
# [4510]	training's rmse: 6113.1	valid_1's rmse: 7176.69
# [4520]	training's rmse: 6110.76	valid_1's rmse: 7175.1
# [4530]	training's rmse: 6108.36	valid_1's rmse: 7173.74
# [4540]	training's rmse: 6105.56	valid_1's rmse: 7172.73
# [4550]	training's rmse: 6103.8	valid_1's rmse: 7172.13
# [4560]	training's rmse: 6101.76	valid_1's rmse: 7171.39
# [4570]	training's rmse: 6098.89	valid_1's rmse: 7168.45
# [4580]	training's rmse: 6096.96	valid_1's rmse: 7167.53
# [4590]	training's rmse: 6094.42	valid_1's rmse: 7166.67
# [4600]	training's rmse: 6091.94	valid_1's rmse: 7165.45
# [4610]	training's rmse: 6089.29	valid_1's rmse: 7163.58
# [4620]	training's rmse: 6086.55	valid_1's rmse: 7162.36
# [4630]	training's rmse: 6084.22	valid_1's rmse: 7160.42
# [4640]	training's rmse: 6082.4	valid_1's rmse: 7158.91
# [4650]	training's rmse: 6080.41	valid_1's rmse: 7157.99
# [4660]	training's rmse: 6077.75	valid_1's rmse: 7154.95
# [4670]	training's rmse: 6075.99	valid_1's rmse: 7153.25
# [4680]	training's rmse: 6073.93	valid_1's rmse: 7152.38
# [4690]	training's rmse: 6071.73	valid_1's rmse: 7151.78
# [4700]	training's rmse: 6069.78	valid_1's rmse: 7150.36
# [4710]	training's rmse: 6067.79	valid_1's rmse: 7149.47
# [4720]	training's rmse: 6065.55	valid_1's rmse: 7148.86
# [4730]	training's rmse: 6063.48	valid_1's rmse: 7148.26
# [4740]	training's rmse: 6061.45	valid_1's rmse: 7148.11
# [4750]	training's rmse: 6058.92	valid_1's rmse: 7146.51
# [4760]	training's rmse: 6057	valid_1's rmse: 7145.3
# [4770]	training's rmse: 6054.61	valid_1's rmse: 7144.61
# [4780]	training's rmse: 6052.75	valid_1's rmse: 7142.99
# [4790]	training's rmse: 6050.89	valid_1's rmse: 7142.32
# [4800]	training's rmse: 6048.46	valid_1's rmse: 7140.54
# [4810]	training's rmse: 6046.57	valid_1's rmse: 7139.61
# [4820]	training's rmse: 6044.76	valid_1's rmse: 7139.02
# [4830]	training's rmse: 6043.3	valid_1's rmse: 7138.37
# [4840]	training's rmse: 6041.65	valid_1's rmse: 7138.2
# [4850]	training's rmse: 6039.36	valid_1's rmse: 7134.83
# [4860]	training's rmse: 6036.83	valid_1's rmse: 7134.08
# [4870]	training's rmse: 6034.95	valid_1's rmse: 7132.53
# [4880]	training's rmse: 6032.57	valid_1's rmse: 7131
# [4890]	training's rmse: 6030.76	valid_1's rmse: 7129.81
# [4900]	training's rmse: 6028.46	valid_1's rmse: 7129
# [4910]	training's rmse: 6026.67	valid_1's rmse: 7127.31
# [4920]	training's rmse: 6024.5	valid_1's rmse: 7126.15
# [4930]	training's rmse: 6022.26	valid_1's rmse: 7125.4
# [4940]	training's rmse: 6020.22	valid_1's rmse: 7124.7
# [4950]	training's rmse: 6017.84	valid_1's rmse: 7124.65
# [4960]	training's rmse: 6015.76	valid_1's rmse: 7123.42
# [4970]	training's rmse: 6014.01	valid_1's rmse: 7122.16
# [4980]	training's rmse: 6011.89	valid_1's rmse: 7120.42
# [4990]	training's rmse: 6010.23	valid_1's rmse: 7119.43
# [5000]	training's rmse: 6007.6	valid_1's rmse: 7116.73
# [5010]	training's rmse: 6005.62	valid_1's rmse: 7115.87
# [5020]	training's rmse: 6003.68	valid_1's rmse: 7114.23
# [5030]	training's rmse: 6001.2	valid_1's rmse: 7112.71
# [5040]	training's rmse: 5999.69	valid_1's rmse: 7111.52
# [5050]	training's rmse: 5998.2	valid_1's rmse: 7110.03
# [5060]	training's rmse: 5996.08	valid_1's rmse: 7108.46
# [5070]	training's rmse: 5993.64	valid_1's rmse: 7105.96
# [5080]	training's rmse: 5991.82	valid_1's rmse: 7104.99
# [5090]	training's rmse: 5989.96	valid_1's rmse: 7104.77
# [5100]	training's rmse: 5988.41	valid_1's rmse: 7104.28
# [5110]	training's rmse: 5986.37	valid_1's rmse: 7102.86
# [5120]	training's rmse: 5984.63	valid_1's rmse: 7101.57
# [5130]	training's rmse: 5982.55	valid_1's rmse: 7099.93
# [5140]	training's rmse: 5980.92	valid_1's rmse: 7099.53
# [5150]	training's rmse: 5978.97	valid_1's rmse: 7099.02
# [5160]	training's rmse: 5977.32	valid_1's rmse: 7098.4
# [5170]	training's rmse: 5975.49	valid_1's rmse: 7098.47
# [5180]	training's rmse: 5973.71	valid_1's rmse: 7097.25
# [5190]	training's rmse: 5971.72	valid_1's rmse: 7096.21
# [5200]	training's rmse: 5970.06	valid_1's rmse: 7094.67
# [5210]	training's rmse: 5968.21	valid_1's rmse: 7094.32
# [5220]	training's rmse: 5966.7	valid_1's rmse: 7093.44
# [5230]	training's rmse: 5964.94	valid_1's rmse: 7092.39
# [5240]	training's rmse: 5963.36	valid_1's rmse: 7092.13
# [5250]	training's rmse: 5961.53	valid_1's rmse: 7090.88
# [5260]	training's rmse: 5959.18	valid_1's rmse: 7089.55
# [5270]	training's rmse: 5957.65	valid_1's rmse: 7088.94
# [5280]	training's rmse: 5956.2	valid_1's rmse: 7088.49
# [5290]	training's rmse: 5954.43	valid_1's rmse: 7087.64
# [5300]	training's rmse: 5952.97	valid_1's rmse: 7086.88
# [5310]	training's rmse: 5950.98	valid_1's rmse: 7086.15
# [5320]	training's rmse: 5949.48	valid_1's rmse: 7085.86
# [5330]	training's rmse: 5947.96	valid_1's rmse: 7085.48
# [5340]	training's rmse: 5945.98	valid_1's rmse: 7084.01
# [5350]	training's rmse: 5944.07	valid_1's rmse: 7082.73
# [5360]	training's rmse: 5942.28	valid_1's rmse: 7081.26
# [5370]	training's rmse: 5940.1	valid_1's rmse: 7081.08
# [5380]	training's rmse: 5938.22	valid_1's rmse: 7080.21
# [5390]	training's rmse: 5936.47	valid_1's rmse: 7079.26
# [5400]	training's rmse: 5934.88	valid_1's rmse: 7078.35
# [5410]	training's rmse: 5933.26	valid_1's rmse: 7077.58
# [5420]	training's rmse: 5931.09	valid_1's rmse: 7076.36
# [5430]	training's rmse: 5929.44	valid_1's rmse: 7074.8
# [5440]	training's rmse: 5927.85	valid_1's rmse: 7072.96
# [5450]	training's rmse: 5925.98	valid_1's rmse: 7072.1
# [5460]	training's rmse: 5923.96	valid_1's rmse: 7071.39
# [5470]	training's rmse: 5922.54	valid_1's rmse: 7071.18
# [5480]	training's rmse: 5921.22	valid_1's rmse: 7070.54
# [5490]	training's rmse: 5919.51	valid_1's rmse: 7069.44
# [5500]	training's rmse: 5917.81	valid_1's rmse: 7068.68
# [5510]	training's rmse: 5916.27	valid_1's rmse: 7067.75
# [5520]	training's rmse: 5914.72	valid_1's rmse: 7066.77
# [5530]	training's rmse: 5913.17	valid_1's rmse: 7065.47
# [5540]	training's rmse: 5911.83	valid_1's rmse: 7064.41
# [5550]	training's rmse: 5910.16	valid_1's rmse: 7063.05
# [5560]	training's rmse: 5908.45	valid_1's rmse: 7062.09
# [5570]	training's rmse: 5906.67	valid_1's rmse: 7061.24
# [5580]	training's rmse: 5905.13	valid_1's rmse: 7060.31
# [5590]	training's rmse: 5903.55	valid_1's rmse: 7059.14
# [5600]	training's rmse: 5902.32	valid_1's rmse: 7059.93
# [5610]	training's rmse: 5900.49	valid_1's rmse: 7059.42
# [5620]	training's rmse: 5898.95	valid_1's rmse: 7058.83
# [5630]	training's rmse: 5897.01	valid_1's rmse: 7057.72
# [5640]	training's rmse: 5895.31	valid_1's rmse: 7057.17
# [5650]	training's rmse: 5894.02	valid_1's rmse: 7056.34
# [5660]	training's rmse: 5892.27	valid_1's rmse: 7055.63
# [5670]	training's rmse: 5890.75	valid_1's rmse: 7054.86
# [5680]	training's rmse: 5888.49	valid_1's rmse: 7053.63
# [5690]	training's rmse: 5886.91	valid_1's rmse: 7053.08
# [5700]	training's rmse: 5885.49	valid_1's rmse: 7053.15
# [5710]	training's rmse: 5884.05	valid_1's rmse: 7052.51
# [5720]	training's rmse: 5882.31	valid_1's rmse: 7051.54
# [5730]	training's rmse: 5880.43	valid_1's rmse: 7051.48
# [5740]	training's rmse: 5879.05	valid_1's rmse: 7051.17
# [5750]	training's rmse: 5877.22	valid_1's rmse: 7050.61
# [5760]	training's rmse: 5875.07	valid_1's rmse: 7049.54
# [5770]	training's rmse: 5873.18	valid_1's rmse: 7049.8
# [5780]	training's rmse: 5871.41	valid_1's rmse: 7049.46
# [5790]	training's rmse: 5869.97	valid_1's rmse: 7049.42
# [5800]	training's rmse: 5868.43	valid_1's rmse: 7048.6
# [5810]	training's rmse: 5866.8	valid_1's rmse: 7047.77
# [5820]	training's rmse: 5864.81	valid_1's rmse: 7046.95
# [5830]	training's rmse: 5863.57	valid_1's rmse: 7046.55
# [5840]	training's rmse: 5861.77	valid_1's rmse: 7045.86
# [5850]	training's rmse: 5860.1	valid_1's rmse: 7044.7
# [5860]	training's rmse: 5858.13	valid_1's rmse: 7042.43
# [5870]	training's rmse: 5856.31	valid_1's rmse: 7041.58
# [5880]	training's rmse: 5855.22	valid_1's rmse: 7040.94
# [5890]	training's rmse: 5853.99	valid_1's rmse: 7039.65
# [5900]	training's rmse: 5852.35	valid_1's rmse: 7039.31
# [5910]	training's rmse: 5851.11	valid_1's rmse: 7038.71
# [5920]	training's rmse: 5849.54	valid_1's rmse: 7038.19
# [5930]	training's rmse: 5848.11	valid_1's rmse: 7037.43
# [5940]	training's rmse: 5846.68	valid_1's rmse: 7036.7
# [5950]	training's rmse: 5845.37	valid_1's rmse: 7036.02
# [5960]	training's rmse: 5844.07	valid_1's rmse: 7035.21
# [5970]	training's rmse: 5842.75	valid_1's rmse: 7034.85
# [5980]	training's rmse: 5841.49	valid_1's rmse: 7033.73
# [5990]	training's rmse: 5840.38	valid_1's rmse: 7034.06
# [6000]	training's rmse: 5838.76	valid_1's rmse: 7033.69
# [6010]	training's rmse: 5836.97	valid_1's rmse: 7032.58
# [6020]	training's rmse: 5835.59	valid_1's rmse: 7031.91
# [6030]	training's rmse: 5833.99	valid_1's rmse: 7031.13
# [6040]	training's rmse: 5832.56	valid_1's rmse: 7031.08
# [6050]	training's rmse: 5831.59	valid_1's rmse: 7030.61
# [6060]	training's rmse: 5829.9	valid_1's rmse: 7029.23
# [6070]	training's rmse: 5828.35	valid_1's rmse: 7028.2
# [6080]	training's rmse: 5826.92	valid_1's rmse: 7027.36
# [6090]	training's rmse: 5825.47	valid_1's rmse: 7027.26
# [6100]	training's rmse: 5823.94	valid_1's rmse: 7026.25
# [6110]	training's rmse: 5822.22	valid_1's rmse: 7026.87
# [6120]	training's rmse: 5820.32	valid_1's rmse: 7025.07
# [6130]	training's rmse: 5819.14	valid_1's rmse: 7024.31
# [6140]	training's rmse: 5817.85	valid_1's rmse: 7023.39
# [6150]	training's rmse: 5816.34	valid_1's rmse: 7022.95
# [6160]	training's rmse: 5814.67	valid_1's rmse: 7023.08
# [6170]	training's rmse: 5813.08	valid_1's rmse: 7023.38
# [6180]	training's rmse: 5811.33	valid_1's rmse: 7022.89
# [6190]	training's rmse: 5809.5	valid_1's rmse: 7021.63
# [6200]	training's rmse: 5808.12	valid_1's rmse: 7021.2
# [6210]	training's rmse: 5806.52	valid_1's rmse: 7021.44
# [6220]	training's rmse: 5805.01	valid_1's rmse: 7020.85
# [6230]	training's rmse: 5803.6	valid_1's rmse: 7020.22
# [6240]	training's rmse: 5802.23	valid_1's rmse: 7019.72
# [6250]	training's rmse: 5800.92	valid_1's rmse: 7018.69
# [6260]	training's rmse: 5799.6	valid_1's rmse: 7018.86
# [6270]	training's rmse: 5797.63	valid_1's rmse: 7017.38
# [6280]	training's rmse: 5796	valid_1's rmse: 7016.27
# [6290]	training's rmse: 5794.85	valid_1's rmse: 7016.71
# [6300]	training's rmse: 5793.54	valid_1's rmse: 7016.25
# [6310]	training's rmse: 5792.19	valid_1's rmse: 7015.83
# [6320]	training's rmse: 5790.77	valid_1's rmse: 7015.98
# [6330]	training's rmse: 5789.6	valid_1's rmse: 7015.51
# [6340]	training's rmse: 5788.42	valid_1's rmse: 7015.1
# [6350]	training's rmse: 5787.01	valid_1's rmse: 7014.1
# [6360]	training's rmse: 5785.5	valid_1's rmse: 7013.59
# [6370]	training's rmse: 5783.87	valid_1's rmse: 7013.34
# [6380]	training's rmse: 5782.33	valid_1's rmse: 7013.03
# [6390]	training's rmse: 5780.73	valid_1's rmse: 7012.22
# [6400]	training's rmse: 5779.09	valid_1's rmse: 7010.97
# [6410]	training's rmse: 5777.79	valid_1's rmse: 7010.54
# [6420]	training's rmse: 5776.74	valid_1's rmse: 7009.88
# [6430]	training's rmse: 5775.32	valid_1's rmse: 7008.34
# [6440]	training's rmse: 5774.01	valid_1's rmse: 7008.29
# [6450]	training's rmse: 5772.78	valid_1's rmse: 7008.03
# [6460]	training's rmse: 5771.32	valid_1's rmse: 7007.52
# [6470]	training's rmse: 5770.35	valid_1's rmse: 7006.93
# [6480]	training's rmse: 5768.93	valid_1's rmse: 7006.08
# [6490]	training's rmse: 5767.38	valid_1's rmse: 7005.2
# [6500]	training's rmse: 5765.9	valid_1's rmse: 7004.83
# [6510]	training's rmse: 5764.51	valid_1's rmse: 7004.34
# [6520]	training's rmse: 5763.03	valid_1's rmse: 7002.86
# [6530]	training's rmse: 5761.86	valid_1's rmse: 7002.5
# [6540]	training's rmse: 5760.49	valid_1's rmse: 7002.01
# [6550]	training's rmse: 5759	valid_1's rmse: 7000.77
# [6560]	training's rmse: 5757.56	valid_1's rmse: 7000.35
# [6570]	training's rmse: 5755.58	valid_1's rmse: 6998.33
# [6580]	training's rmse: 5754.24	valid_1's rmse: 6998.61
# [6590]	training's rmse: 5752.6	valid_1's rmse: 6997.76
# [6600]	training's rmse: 5751.7	valid_1's rmse: 6997.59
# [6610]	training's rmse: 5750.35	valid_1's rmse: 6997.14
# [6620]	training's rmse: 5749.03	valid_1's rmse: 6996.27
# [6630]	training's rmse: 5747.59	valid_1's rmse: 6994.87
# [6640]	training's rmse: 5745.58	valid_1's rmse: 6994.09
# [6650]	training's rmse: 5744.53	valid_1's rmse: 6993.46
# [6660]	training's rmse: 5743.36	valid_1's rmse: 6992.73
# [6670]	training's rmse: 5741.77	valid_1's rmse: 6991.14
# [6680]	training's rmse: 5739.92	valid_1's rmse: 6990.51
# [6690]	training's rmse: 5738.67	valid_1's rmse: 6989.31
# [6700]	training's rmse: 5737.17	valid_1's rmse: 6988.86
# [6710]	training's rmse: 5735.73	valid_1's rmse: 6988.85
# [6720]	training's rmse: 5734.27	valid_1's rmse: 6989.34
# [6730]	training's rmse: 5733.04	valid_1's rmse: 6988.58
# [6740]	training's rmse: 5731.82	valid_1's rmse: 6988.13
# [6750]	training's rmse: 5730.08	valid_1's rmse: 6987.73
# [6760]	training's rmse: 5728.68	valid_1's rmse: 6986.91
# [6770]	training's rmse: 5727.63	valid_1's rmse: 6986.79
# [6780]	training's rmse: 5726.22	valid_1's rmse: 6986.19
# [6790]	training's rmse: 5725	valid_1's rmse: 6986.05
# [6800]	training's rmse: 5723.79	valid_1's rmse: 6985.14
# [6810]	training's rmse: 5722.36	valid_1's rmse: 6984.59
# [6820]	training's rmse: 5721.24	valid_1's rmse: 6983.58
# [6830]	training's rmse: 5719.94	valid_1's rmse: 6983.22
# [6840]	training's rmse: 5718.81	valid_1's rmse: 6982.42
# [6850]	training's rmse: 5717.5	valid_1's rmse: 6982.24
# [6860]	training's rmse: 5716.02	valid_1's rmse: 6982
# [6870]	training's rmse: 5714.46	valid_1's rmse: 6982.08
# [6880]	training's rmse: 5713.49	valid_1's rmse: 6981.99
# [6890]	training's rmse: 5712.66	valid_1's rmse: 6982.04
# [6900]	training's rmse: 5711.43	valid_1's rmse: 6981.16
# [6910]	training's rmse: 5710.27	valid_1's rmse: 6981.91
# [6920]	training's rmse: 5709.07	valid_1's rmse: 6981.88
# [6930]	training's rmse: 5707.65	valid_1's rmse: 6981.39
# [6940]	training's rmse: 5706.4	valid_1's rmse: 6980.81
# [6950]	training's rmse: 5705.09	valid_1's rmse: 6981.15
# [6960]	training's rmse: 5703.96	valid_1's rmse: 6980.66
# [6970]	training's rmse: 5702.83	valid_1's rmse: 6980.35
# [6980]	training's rmse: 5701.62	valid_1's rmse: 6979.93
# [6990]	training's rmse: 5700.05	valid_1's rmse: 6979.52
# [7000]	training's rmse: 5699	valid_1's rmse: 6979.38
# [7010]	training's rmse: 5697.54	valid_1's rmse: 6979.1
# [7020]	training's rmse: 5696.22	valid_1's rmse: 6978.58
# [7030]	training's rmse: 5695.28	valid_1's rmse: 6978.34
# [7040]	training's rmse: 5694.28	valid_1's rmse: 6978.06
# [7050]	training's rmse: 5693.29	valid_1's rmse: 6977.74
# [7060]	training's rmse: 5692.15	valid_1's rmse: 6977.18
# [7070]	training's rmse: 5690.99	valid_1's rmse: 6977
# [7080]	training's rmse: 5689.85	valid_1's rmse: 6976.55
# [7090]	training's rmse: 5688.72	valid_1's rmse: 6976.38
# [7100]	training's rmse: 5687.25	valid_1's rmse: 6976.41
# [7110]	training's rmse: 5685.75	valid_1's rmse: 6976.04
# [7120]	training's rmse: 5684.71	valid_1's rmse: 6975.26
# [7130]	training's rmse: 5683.56	valid_1's rmse: 6974.56
# [7140]	training's rmse: 5682.4	valid_1's rmse: 6974.07
# [7150]	training's rmse: 5681.53	valid_1's rmse: 6973.99
# [7160]	training's rmse: 5680.2	valid_1's rmse: 6974.17
# [7170]	training's rmse: 5679.28	valid_1's rmse: 6973.39
# [7180]	training's rmse: 5677.87	valid_1's rmse: 6973.03
# [7190]	training's rmse: 5676.61	valid_1's rmse: 6971.96
# [7200]	training's rmse: 5675.42	valid_1's rmse: 6971.71
# [7210]	training's rmse: 5674.49	valid_1's rmse: 6971.63
# [7220]	training's rmse: 5673.28	valid_1's rmse: 6970.2
# [7230]	training's rmse: 5672.21	valid_1's rmse: 6970.12
# [7240]	training's rmse: 5671.08	valid_1's rmse: 6969.95
# [7250]	training's rmse: 5669.85	valid_1's rmse: 6969.25
# [7260]	training's rmse: 5668.74	valid_1's rmse: 6968.41
# [7270]	training's rmse: 5667.56	valid_1's rmse: 6967.74
# [7280]	training's rmse: 5665.98	valid_1's rmse: 6965.77
# [7290]	training's rmse: 5664.72	valid_1's rmse: 6965.48
# [7300]	training's rmse: 5663.5	valid_1's rmse: 6965.42
# [7310]	training's rmse: 5662.54	valid_1's rmse: 6964.44
# [7320]	training's rmse: 5661.36	valid_1's rmse: 6963.83
# [7330]	training's rmse: 5660.12	valid_1's rmse: 6963.19
# [7340]	training's rmse: 5659.22	valid_1's rmse: 6962.57
# [7350]	training's rmse: 5657.98	valid_1's rmse: 6962.01
# [7360]	training's rmse: 5656.53	valid_1's rmse: 6961.79
# [7370]	training's rmse: 5655.12	valid_1's rmse: 6961.79
# [7380]	training's rmse: 5653.78	valid_1's rmse: 6960.77
# [7390]	training's rmse: 5652.78	valid_1's rmse: 6961.34
# [7400]	training's rmse: 5651.67	valid_1's rmse: 6961.74
# [7410]	training's rmse: 5650.65	valid_1's rmse: 6961.77
# [7420]	training's rmse: 5649.73	valid_1's rmse: 6961.03
# [7430]	training's rmse: 5648.72	valid_1's rmse: 6960.56
# [7440]	training's rmse: 5647.74	valid_1's rmse: 6960.4
# [7450]	training's rmse: 5646.67	valid_1's rmse: 6960.28
# [7460]	training's rmse: 5645.78	valid_1's rmse: 6961.03
# [7470]	training's rmse: 5644.78	valid_1's rmse: 6960.79
# [7480]	training's rmse: 5643.56	valid_1's rmse: 6960.61
# [7490]	training's rmse: 5642.15	valid_1's rmse: 6959.89
# [7500]	training's rmse: 5640.92	valid_1's rmse: 6959.24
# [7510]	training's rmse: 5639.93	valid_1's rmse: 6958.76
# [7520]	training's rmse: 5639.03	valid_1's rmse: 6958.05
# [7530]	training's rmse: 5637.83	valid_1's rmse: 6957.71
# [7540]	training's rmse: 5636.86	valid_1's rmse: 6956.98
# [7550]	training's rmse: 5635.53	valid_1's rmse: 6956.15
# [7560]	training's rmse: 5634.28	valid_1's rmse: 6955.3
# [7570]	training's rmse: 5633.36	valid_1's rmse: 6954.96
# [7580]	training's rmse: 5632.28	valid_1's rmse: 6954.71
# [7590]	training's rmse: 5631.32	valid_1's rmse: 6954.35
# [7600]	training's rmse: 5630.36	valid_1's rmse: 6953.65
# [7610]	training's rmse: 5629.21	valid_1's rmse: 6953
# [7620]	training's rmse: 5628.33	valid_1's rmse: 6952.53
# [7630]	training's rmse: 5627.18	valid_1's rmse: 6952.25
# [7640]	training's rmse: 5625.91	valid_1's rmse: 6951.98
# [7650]	training's rmse: 5624.96	valid_1's rmse: 6951.49
# [7660]	training's rmse: 5624	valid_1's rmse: 6951.07
# [7670]	training's rmse: 5622.99	valid_1's rmse: 6950.83
# [7680]	training's rmse: 5622.15	valid_1's rmse: 6950.15
# [7690]	training's rmse: 5621.05	valid_1's rmse: 6949.51
# [7700]	training's rmse: 5620.17	valid_1's rmse: 6949.54
# [7710]	training's rmse: 5619.06	valid_1's rmse: 6949.09
# [7720]	training's rmse: 5618.15	valid_1's rmse: 6948.55
# [7730]	training's rmse: 5616.9	valid_1's rmse: 6948.17
# [7740]	training's rmse: 5615.95	valid_1's rmse: 6947.91
# [7750]	training's rmse: 5615.01	valid_1's rmse: 6947.2
# [7760]	training's rmse: 5613.73	valid_1's rmse: 6946.54
# [7770]	training's rmse: 5612.95	valid_1's rmse: 6946.53
# [7780]	training's rmse: 5611.81	valid_1's rmse: 6945.83
# [7790]	training's rmse: 5610.96	valid_1's rmse: 6945.62
# [7800]	training's rmse: 5609.89	valid_1's rmse: 6944.04
# [7810]	training's rmse: 5608.36	valid_1's rmse: 6943.81
# [7820]	training's rmse: 5607.3	valid_1's rmse: 6943.14
# [7830]	training's rmse: 5606.41	valid_1's rmse: 6942.29
# [7840]	training's rmse: 5605.31	valid_1's rmse: 6941.98
# [7850]	training's rmse: 5604.22	valid_1's rmse: 6941.97
# [7860]	training's rmse: 5603.21	valid_1's rmse: 6941.54
# [7870]	training's rmse: 5602.02	valid_1's rmse: 6940.99
# [7880]	training's rmse: 5601.13	valid_1's rmse: 6940.84
# [7890]	training's rmse: 5600.23	valid_1's rmse: 6941.05
# [7900]	training's rmse: 5599.06	valid_1's rmse: 6940.79
# [7910]	training's rmse: 5598.12	valid_1's rmse: 6940.49
# [7920]	training's rmse: 5597.06	valid_1's rmse: 6940.18
# [7930]	training's rmse: 5596.02	valid_1's rmse: 6940.02
# [7940]	training's rmse: 5594.99	valid_1's rmse: 6939.84
# [7950]	training's rmse: 5593.9	valid_1's rmse: 6939.11
# [7960]	training's rmse: 5593.06	valid_1's rmse: 6938.55
# [7970]	training's rmse: 5592.17	valid_1's rmse: 6937.85
# [7980]	training's rmse: 5591.24	valid_1's rmse: 6937.17
# [7990]	training's rmse: 5590.35	valid_1's rmse: 6936.75
# [8000]	training's rmse: 5589.41	valid_1's rmse: 6936.12
# [8010]	training's rmse: 5588.19	valid_1's rmse: 6935.09
# [8020]	training's rmse: 5587.04	valid_1's rmse: 6934.48
# [8030]	training's rmse: 5586.12	valid_1's rmse: 6933.93
# [8040]	training's rmse: 5585.13	valid_1's rmse: 6933.41
# [8050]	training's rmse: 5584.02	valid_1's rmse: 6932.87
# [8060]	training's rmse: 5583.12	valid_1's rmse: 6932.6
# [8070]	training's rmse: 5581.86	valid_1's rmse: 6931.77
# [8080]	training's rmse: 5581.29	valid_1's rmse: 6931.79
# [8090]	training's rmse: 5580.43	valid_1's rmse: 6931.34
# [8100]	training's rmse: 5579.59	valid_1's rmse: 6931.03
# [8110]	training's rmse: 5578.45	valid_1's rmse: 6930.41
# [8120]	training's rmse: 5577.62	valid_1's rmse: 6930.2
# [8130]	training's rmse: 5576.51	valid_1's rmse: 6928.53
# [8140]	training's rmse: 5575.73	valid_1's rmse: 6928.26
# [8150]	training's rmse: 5574.93	valid_1's rmse: 6928.05
# [8160]	training's rmse: 5574.18	valid_1's rmse: 6928.26
# [8170]	training's rmse: 5573.26	valid_1's rmse: 6928.22
# [8180]	training's rmse: 5572.34	valid_1's rmse: 6928.12
# [8190]	training's rmse: 5571.37	valid_1's rmse: 6927.83
# [8200]	training's rmse: 5570.13	valid_1's rmse: 6927.5
# [8210]	training's rmse: 5569.32	valid_1's rmse: 6927.22
# [8220]	training's rmse: 5568.33	valid_1's rmse: 6926.57
# [8230]	training's rmse: 5567.06	valid_1's rmse: 6925.93
# [8240]	training's rmse: 5566.14	valid_1's rmse: 6925.53
# [8250]	training's rmse: 5565.11	valid_1's rmse: 6924.63
# [8260]	training's rmse: 5564.32	valid_1's rmse: 6924.98
# [8270]	training's rmse: 5562.98	valid_1's rmse: 6923.52
# [8280]	training's rmse: 5561.77	valid_1's rmse: 6922.91
# [8290]	training's rmse: 5560.89	valid_1's rmse: 6922.64
# [8300]	training's rmse: 5559.87	valid_1's rmse: 6922.65
# [8310]	training's rmse: 5559.21	valid_1's rmse: 6922.76
# [8320]	training's rmse: 5558.03	valid_1's rmse: 6922.6
# [8330]	training's rmse: 5557.19	valid_1's rmse: 6922.77
# [8340]	training's rmse: 5556.14	valid_1's rmse: 6922.2
# [8350]	training's rmse: 5555.27	valid_1's rmse: 6922.53
# [8360]	training's rmse: 5554.54	valid_1's rmse: 6922.93
# [8370]	training's rmse: 5553.68	valid_1's rmse: 6922.67
# [8380]	training's rmse: 5552.91	valid_1's rmse: 6922.37
# [8390]	training's rmse: 5551.9	valid_1's rmse: 6922.57
# [8400]	training's rmse: 5550.64	valid_1's rmse: 6922.85
# Early stopping, best iteration is:
# [8345]	training's rmse: 5555.78	valid_1's rmse: 6922.09
# LGBMRegressor(data_sample_strategy='goss', metric='rmse', n_estimators=100000)

# %%
importances = pd.Series(model.feature_importances_, index=list(train_X.columns))
importances = importances.sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.title("Feature Importances")
sns.barplot(x=importances, y=importances.index)
plt.show()

# %%
preds = model.predict(test_df)

# %%
preds = np.round(preds).astype(int)

# %%
preds_df = pd.DataFrame(preds, columns=['target'])

# %%
preds_df.to_csv('../pred.csv', index=False)
