# %% [markdown]
# # 31. 아파트 매매가격지수

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import MinMaxScaler

# 맥에서 글씨 깨짐 방지
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel('../data/added_features/월간 아파트 매매가격지수_20240717.xlsx')

# %%
df
# Out:
#         지역명 1986-01-01 09:00:52 1986-02-01 09:00:52 1986-03-01 09:00:52  \
# 0        전국           15.910037           15.910037           15.880737
# 1        서울           12.634687           12.656584           12.634687
# 2    강북14개구           17.654568           17.625626           17.596684
# 3       종로구                   -                   -                   -
# 4        중구                   -                   -                   -
# ..      ...                 ...                 ...                 ...
# 273     무주군                   -                   -                   -
# 274     임실군                   -                   -                   -
# 275     순창군                   -                   -                   -
# 276     고창군                   -                   -                   -
# 277     부안군                   -                   -                   -
#
#     1986-04-01 09:00:52 1986-05-01 09:00:52 1986-06-01 09:00:52  \
# 0             15.792836           15.675635           15.587735
# 1             12.547098           12.481406           12.350023
# 2             17.480916           17.249381           17.249381
# 3                     -                   -                   -
# 4                     -                   -                   -
# ..                  ...                 ...                 ...
# 273                   -                   -                   -
# 274                   -                   -                   -
# 275                   -                   -                   -
# 276                   -                   -                   -
# 277                   -                   -                   -
#
#     1986-07-01 09:00:52 1986-08-01 09:00:52 1986-09-01 09:00:52  ...  \
# 0             15.499834           15.470534           15.499834  ...
# 1             12.306228           12.306228           12.328126  ...
# 2             17.249381           17.249381           17.307265  ...
# 3                     -                   -                   -  ...
# 4                     -                   -                   -  ...
# ..                  ...                 ...                 ...  ...
# 273                   -                   -                   -  ...
# 274                   -                   -                   -  ...
# 275                   -                   -                   -  ...
# 276                   -                   -                   -  ...
# 277                   -                   -                   -  ...
#
#     2023-09-01 09:00:52 2023-10-01 09:00:52 2023-11-01 09:00:52  \
# 0             90.088355           90.171682           90.177104
# 1             90.577885           90.786965           90.821491
# 2             88.564576           88.646116           88.599421
# 3              97.51826           97.668012           97.824401
# 4             92.560336           92.681998           92.697369
# ..                  ...                 ...                 ...
# 273          100.471974          100.865982          100.865982
# 274          104.540715          104.540715          104.540715
# 275                   -                   -                   -
# 276          113.541742          113.541742          113.630492
# 277          109.481185          109.481185          109.447434
#
#     2023-12-01 09:00:52 2024-01-01 09:00:52 2024-02-01 09:00:52  \
# 0             90.080022           89.940106           89.842256
# 1             90.725487           90.551125           90.442043
# 2             88.469239           88.295146           88.166386
# 3             97.840228           97.749291           97.721400
# 4             92.850743           92.961422           92.875528
# ..                  ...                 ...                 ...
# 273          100.865982          100.865982           98.809108
# 274          104.540715          104.540715          104.540715
# 275                   -                   -           98.786649
# 276          113.668445          113.711387          113.668124
# 277          109.874824          110.153536          110.656740
#
#     2024-03-01 09:00:52 2024-04-01 09:00:52 2024-05-01 09:00:52  \
# 0             89.697577           89.503353           89.387179
# 1             90.307675           90.158002           90.129838
# 2             88.016196           87.819360           87.738587
# 3             97.576362           97.635306           97.546511
# 4             92.924594           92.707253           92.651911
# ..                  ...                 ...                 ...
# 273           97.003559           97.003559           97.003559
# 274          104.540715          104.540715          104.540715
# 275           98.786649           98.786649           98.786649
# 276          115.349433          117.355832          117.967587
# 277          112.104266          112.377129          112.581604
#
#     2024-06-01 09:00:52
# 0             89.302354
# 1             90.241606
# 2             87.822147
# 3             97.806351
# 4             92.971540
# ..                  ...
# 273           97.003559
# 274          102.830430
# 275           98.786649
# 276          118.421120
# 277          113.368614
#
# [278 rows x 463 columns]

# %%
cols = df.columns
cols = [int(str(col)[:10].replace('-', '')[:6]) for col in cols[1:]]

# %%
cols.insert(0, '지역명')
cols
# Out:
# ['지역명',
#  198601,
#  198602,
#  198603,
#  198604,
#  198605,
#  198606,
#  198607,
#  198608,
#  198609,
#  198610,
#  198611,
#  198612,
#  198701,
#  198702,
#  198703,
#  198704,
#  198705,
#  198706,
#  198707,
#  198708,
#  198709,
#  198710,
#  198711,
#  198712,
#  198801,
#  198802,
#  198803,
#  198804,
#  198805,
#  198806,
#  198807,
#  198808,
#  198809,
#  198810,
#  198811,
#  198812,
#  198901,
#  198902,
#  198903,
#  198904,
#  198905,
#  198906,
#  198907,
#  198908,
#  198909,
#  198910,
#  198911,
#  198912,
#  199001,
#  199002,
#  199003,
#  199004,
#  199005,
#  199006,
#  199007,
#  199008,
#  199009,
#  199010,
#  199011,
#  199012,
#  199101,
#  199102,
#  199103,
#  199104,
#  199105,
#  199106,
#  199107,
#  199108,
#  199109,
#  199110,
#  199111,
#  199112,
#  199201,
#  199202,
#  199203,
#  199204,
#  199205,
#  199206,
#  199207,
#  199208,
#  199209,
#  199210,
#  199211,
#  199212,
#  199301,
#  199302,
#  199303,
#  199304,
#  199305,
#  199306,
#  199307,
#  199308,
#  199309,
#  199310,
#  199311,
#  199312,
#  199401,
#  199402,
#  199403,
#  199404,
#  199405,
#  199406,
#  199407,
#  199408,
#  199409,
#  199410,
#  199411,
#  199412,
#  199501,
#  199502,
#  199503,
#  199504,
#  199505,
#  199506,
#  199507,
#  199508,
#  199509,
#  199510,
#  199511,
#  199512,
#  199601,
#  199602,
#  199603,
#  199604,
#  199605,
#  199606,
#  199607,
#  199608,
#  199609,
#  199610,
#  199611,
#  199612,
#  199701,
#  199702,
#  199703,
#  199704,
#  199705,
#  199706,
#  199707,
#  199708,
#  199709,
#  199710,
#  199711,
#  199712,
#  199801,
#  199802,
#  199803,
#  199804,
#  199805,
#  199806,
#  199807,
#  199808,
#  199809,
#  199810,
#  199811,
#  199812,
#  199901,
#  199902,
#  199903,
#  199904,
#  199905,
#  199906,
#  199907,
#  199908,
#  199909,
#  199910,
#  199911,
#  199912,
#  200001,
#  200002,
#  200003,
#  200004,
#  200005,
#  200006,
#  200007,
#  200008,
#  200009,
#  200010,
#  200011,
#  200012,
#  200101,
#  200102,
#  200103,
#  200104,
#  200105,
#  200106,
#  200107,
#  200108,
#  200109,
#  200110,
#  200111,
#  200112,
#  200201,
#  200202,
#  200203,
#  200204,
#  200205,
#  200206,
#  200207,
#  200208,
#  200209,
#  200210,
#  200211,
#  200212,
#  200301,
#  200302,
#  200303,
#  200304,
#  200305,
#  200306,
#  200307,
#  200308,
#  200309,
#  200310,
#  200311,
#  200312,
#  200401,
#  200402,
#  200403,
#  200404,
#  200405,
#  200406,
#  200407,
#  200408,
#  200409,
#  200410,
#  200411,
#  200412,
#  200501,
#  200502,
#  200503,
#  200504,
#  200505,
#  200506,
#  200507,
#  200508,
#  200509,
#  200510,
#  200511,
#  200512,
#  200601,
#  200602,
#  200603,
#  200604,
#  200605,
#  200606,
#  200607,
#  200608,
#  200609,
#  200610,
#  200611,
#  200612,
#  200701,
#  200702,
#  200703,
#  200704,
#  200705,
#  200706,
#  200707,
#  200708,
#  200709,
#  200710,
#  200711,
#  200712,
#  200801,
#  200802,
#  200803,
#  200804,
#  200805,
#  200806,
#  200807,
#  200808,
#  200809,
#  200810,
#  200811,
#  200812,
#  200901,
#  200902,
#  200903,
#  200904,
#  200905,
#  200906,
#  200907,
#  200908,
#  200909,
#  200910,
#  200911,
#  200912,
#  201001,
#  201002,
#  201003,
#  201004,
#  201005,
#  201006,
#  201007,
#  201008,
#  201009,
#  201010,
#  201011,
#  201012,
#  201101,
#  201102,
#  201103,
#  201104,
#  201105,
#  201106,
#  201107,
#  201108,
#  201109,
#  201110,
#  201111,
#  201112,
#  201201,
#  201202,
#  201203,
#  201204,
#  201205,
#  201206,
#  201207,
#  201208,
#  201209,
#  201210,
#  201211,
#  201212,
#  201301,
#  201302,
#  201303,
#  201304,
#  201305,
#  201306,
#  201307,
#  201308,
#  201309,
#  201310,
#  201311,
#  201312,
#  201401,
#  201402,
#  201403,
#  201404,
#  201405,
#  201406,
#  201407,
#  201408,
#  201409,
#  201410,
#  201411,
#  201412,
#  201501,
#  201502,
#  201503,
#  201504,
#  201505,
#  201506,
#  201507,
#  201508,
#  201509,
#  201510,
#  201511,
#  201512,
#  201601,
#  201602,
#  201603,
#  201604,
#  201605,
#  201606,
#  201607,
#  201608,
#  201609,
#  201610,
#  201611,
#  201612,
#  201701,
#  201702,
#  201703,
#  201704,
#  201705,
#  201706,
#  201707,
#  201708,
#  201709,
#  201710,
#  201711,
#  201712,
#  201801,
#  201802,
#  201803,
#  201804,
#  201805,
#  201806,
#  201807,
#  201808,
#  201809,
#  201810,
#  201811,
#  201812,
#  201901,
#  201902,
#  201903,
#  201904,
#  201905,
#  201906,
#  201907,
#  201908,
#  201909,
#  201910,
#  201911,
#  201912,
#  202001,
#  202002,
#  202003,
#  202004,
#  202005,
#  202006,
#  202007,
#  202008,
#  202009,
#  202010,
#  202011,
#  202012,
#  202101,
#  202102,
#  202103,
#  202104,
#  202105,
#  202106,
#  202107,
#  202108,
#  202109,
#  202110,
#  202111,
#  202112,
#  202201,
#  202202,
#  202203,
#  202204,
#  202205,
#  202206,
#  202207,
#  202208,
#  202209,
#  202210,
#  202211,
#  202212,
#  202301,
#  202302,
#  202303,
#  202304,
#  202305,
#  202306,
#  202307,
#  202308,
#  202309,
#  202310,
#  202311,
#  202312,
#  202401,
#  202402,
#  202403,
#  202404,
#  202405,
#  202406]

# %%
df.columns = cols

# %%
df
# Out:
#         지역명     198601     198602     198603     198604     198605     198606  \
# 0        전국  15.910037  15.910037  15.880737  15.792836  15.675635  15.587735
# 1        서울  12.634687  12.656584  12.634687  12.547098  12.481406  12.350023
# 2    강북14개구  17.654568  17.625626  17.596684  17.480916  17.249381  17.249381
# 3       종로구          -          -          -          -          -          -
# 4        중구          -          -          -          -          -          -
# ..      ...        ...        ...        ...        ...        ...        ...
# 273     무주군          -          -          -          -          -          -
# 274     임실군          -          -          -          -          -          -
# 275     순창군          -          -          -          -          -          -
# 276     고창군          -          -          -          -          -          -
# 277     부안군          -          -          -          -          -          -
#
#         198607     198608     198609  ...      202309      202310      202311  \
# 0    15.499834  15.470534  15.499834  ...   90.088355   90.171682   90.177104
# 1    12.306228  12.306228  12.328126  ...   90.577885   90.786965   90.821491
# 2    17.249381  17.249381  17.307265  ...   88.564576   88.646116   88.599421
# 3            -          -          -  ...    97.51826   97.668012   97.824401
# 4            -          -          -  ...   92.560336   92.681998   92.697369
# ..         ...        ...        ...  ...         ...         ...         ...
# 273          -          -          -  ...  100.471974  100.865982  100.865982
# 274          -          -          -  ...  104.540715  104.540715  104.540715
# 275          -          -          -  ...           -           -           -
# 276          -          -          -  ...  113.541742  113.541742  113.630492
# 277          -          -          -  ...  109.481185  109.481185  109.447434
#
#          202312      202401      202402      202403      202404      202405  \
# 0     90.080022   89.940106   89.842256   89.697577   89.503353   89.387179
# 1     90.725487   90.551125   90.442043   90.307675   90.158002   90.129838
# 2     88.469239   88.295146   88.166386   88.016196   87.819360   87.738587
# 3     97.840228   97.749291   97.721400   97.576362   97.635306   97.546511
# 4     92.850743   92.961422   92.875528   92.924594   92.707253   92.651911
# ..          ...         ...         ...         ...         ...         ...
# 273  100.865982  100.865982   98.809108   97.003559   97.003559   97.003559
# 274  104.540715  104.540715  104.540715  104.540715  104.540715  104.540715
# 275           -           -   98.786649   98.786649   98.786649   98.786649
# 276  113.668445  113.711387  113.668124  115.349433  117.355832  117.967587
# 277  109.874824  110.153536  110.656740  112.104266  112.377129  112.581604
#
#          202406
# 0     89.302354
# 1     90.241606
# 2     87.822147
# 3     97.806351
# 4     92.971540
# ..          ...
# 273   97.003559
# 274  102.830430
# 275   98.786649
# 276  118.421120
# 277  113.368614
#
# [278 rows x 463 columns]

# %%
origin_df = pd.read_csv('../data/preprocessed/27_school_district.csv')
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/2769093726.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   origin_df = pd.read_csv('../data/preprocessed/27_school_district.csv')

# %%
district_list = origin_df['구'].unique().tolist()
print(len(district_list))
district_list
# Out:
# 25
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %% [markdown]
# # 구별로 데이터 프레임을 따로 추출한다.

# %%
df_list = []

for district in district_list:
    df_list.append(df[df['지역명']==district])

# %%
for i in range(25):
    tmp = df_list[i].drop(['지역명'], axis=1)
    tmp = pd.DataFrame(tmp.iloc[0])
    tmp.reset_index(inplace=True)
    tmp.columns = ['년도월', '매매가격 지수']
    df_list[i] = tmp

# %%
for i in range(25):
    df_list[i] = df_list[i].iloc[252:].reset_index(drop=True)

# %%
df_list[0]
# Out:
#         년도월    매매가격 지수
# 0    200701  62.971521
# 1    200702  62.873459
# 2    200703  62.755302
# 3    200704  62.210519
# 4    200705  61.760044
# ..      ...        ...
# 205  202402  97.183768
# 206  202403  97.107117
# 207  202404  97.108001
# 208  202405  97.224005
# 209  202406  97.482532
#
# [210 rows x 2 columns]

# %%
plt.figure(figsize=(15, 10))
for i in range(25):
    df_list[i]['매매가격 지수'].plot()
plt.grid(True)

# %% [markdown]
# # 원본에 적용

# %%
origin_df_split_list = []

for district in district_list:
    origin_df_split_list.append(origin_df[origin_df['구'] == district])

# %%
origin_df_split_list[0]
# Out:
#                    시군구     번지     본번   부번      아파트명   전용면적    계약년월  계약일  층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201712    8  3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201712   22  4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  54.98  201712   28  5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201801    3  4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201801    8  2
# ...                ...    ...    ...  ...       ...    ...     ...  ... ..
# 1123928  서울특별시 강남구 일원동    742  742.0  0.0  디에이치포레센트  84.94  202308   12  7
# 1123929  서울특별시 강남구 일원동    742  742.0  0.0  디에이치포레센트  84.94  202308   19  6
# 1123930  서울특별시 강남구 일원동    742  742.0  0.0  디에이치포레센트  84.94  202308   31  9
# 1123931  서울특별시 강남구 일원동    734  734.0  0.0       상록수  74.54  202307    7  3
# 1123932  서울특별시 강남구 일원동    734  734.0  0.0       상록수  84.95  202308   26  1
#
#          건축년도  ... 아파트 카테고리  지하철 카테고리 구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리  \
# 0        1987  ...       기타       분당선    강남구       기타    5581.622466
# 1        1987  ...       기타       분당선    강남구       기타    5581.622466
# 2        1987  ...       기타       분당선    강남구       기타    5581.622466
# 3        1987  ...       기타       분당선    강남구       기타    5581.622466
# 4        1987  ...       기타       분당선    강남구       기타    5581.622466
# ...       ...  ...      ...       ...    ...      ...            ...
# 1123928  2021  ...       포레       3호선    강남구       현대    3984.052508
# 1123929  2021  ...       포레       3호선    강남구       현대    3984.052508
# 1123930  2021  ...       포레       3호선    강남구       현대    3984.052508
# 1123931  1993  ...       기타       3호선    강남구       대우    4839.238469
# 1123932  1993  ...       기타       3호선    강남구       대우    4839.238469
#
#         가장 가까운 다리 index 가장 가까운 다리 인근 한강다리 개수  인근 다리 개수 1개이상 3개 이하   학군
# 0                  17.0      청담대교        0.0                    0  8.0
# 1                  17.0      청담대교        0.0                    0  8.0
# 2                  17.0      청담대교        0.0                    0  8.0
# 3                  17.0      청담대교        0.0                    0  8.0
# 4                  17.0      청담대교        0.0                    0  8.0
# ...                 ...       ...        ...                  ...  ...
# 1123928            18.0      잠실대교        0.0                    0  8.0
# 1123929            18.0      잠실대교        0.0                    0  8.0
# 1123930            18.0      잠실대교        0.0                    0  8.0
# 1123931            18.0      잠실대교        0.0                    0  8.0
# 1123932            18.0      잠실대교        0.0                    0  8.0
#
# [69656 rows x 103 columns]

# %%
def mapping(one_of_df, one_of_origin_df):
    mapping_ = pd.Series({ym: value for ym, value in zip(one_of_df['년도월'], one_of_df['매매가격 지수'])})

    one_of_origin_df['매매가격 지수'] = np.nan
    one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)

    return one_of_origin_df

# %%
for i in range(25):
    origin_df_split_list[i] = mapping(df_list[i], origin_df_split_list[i])
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = np.nan
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_26417/1074140007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_of_origin_df['매매가격 지수'] = one_of_origin_df['매매가격 지수'].fillna(one_of_origin_df['계약년월']).map(mapping_)

# %%
origin_df_split_list[0]
# Out:
#                    시군구     번지     본번   부번      아파트명   전용면적    계약년월  계약일  층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201712    8  3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201712   22  4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  54.98  201712   28  5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201801    3  4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성  79.97  201801    8  2
# ...                ...    ...    ...  ...       ...    ...     ...  ... ..
# 1123928  서울특별시 강남구 일원동    742  742.0  0.0  디에이치포레센트  84.94  202308   12  7
# 1123929  서울특별시 강남구 일원동    742  742.0  0.0  디에이치포레센트  84.94  202308   19  6
# 1123930  서울특별시 강남구 일원동    742  742.0  0.0  디에이치포레센트  84.94  202308   31  9
# 1123931  서울특별시 강남구 일원동    734  734.0  0.0       상록수  74.54  202307    7  3
# 1123932  서울특별시 강남구 일원동    734  734.0  0.0       상록수  84.95  202308   26  1
#
#          건축년도  ... 지하철 카테고리  구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리 가장 가까운 다리 index  \
# 0        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 1        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 2        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 3        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 4        1987  ...      분당선     강남구       기타    5581.622466            17.0
# ...       ...  ...      ...     ...      ...            ...             ...
# 1123928  2021  ...      3호선     강남구       현대    3984.052508            18.0
# 1123929  2021  ...      3호선     강남구       현대    3984.052508            18.0
# 1123930  2021  ...      3호선     강남구       현대    3984.052508            18.0
# 1123931  1993  ...      3호선     강남구       대우    4839.238469            18.0
# 1123932  1993  ...      3호선     강남구       대우    4839.238469            18.0
#
#         가장 가까운 다리 인근 한강다리 개수 인근 다리 개수 1개이상 3개 이하   학군    매매가격 지수
# 0            청담대교        0.0                   0  8.0  67.392545
# 1            청담대교        0.0                   0  8.0  67.392545
# 2            청담대교        0.0                   0  8.0  67.392545
# 3            청담대교        0.0                   0  8.0  69.049924
# 4            청담대교        0.0                   0  8.0  69.049924
# ...           ...        ...                 ...  ...        ...
# 1123928      잠실대교        0.0                   0  8.0  95.993766
# 1123929      잠실대교        0.0                   0  8.0  95.993766
# 1123930      잠실대교        0.0                   0  8.0  95.993766
# 1123931      잠실대교        0.0                   0  8.0  95.482886
# 1123932      잠실대교        0.0                   0  8.0  95.993766
#
# [69656 rows x 104 columns]

# %%
origin_df = pd.concat([one_of_origin_df for one_of_origin_df in origin_df_split_list]).sort_index()

# %%
origin_df
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ... 지하철 카테고리  구 카테고리 건설사 카테고리 가장 가까운 다리와의 거리 가장 가까운 다리 index  \
# 0        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 1        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 2        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 3        1987  ...      분당선     강남구       기타    5581.622466            17.0
# 4        1987  ...      분당선     강남구       기타    5581.622466            17.0
# ...       ...  ...      ...     ...      ...            ...             ...
# 1128089  2014  ...       기타      기타       기타    5918.624352            23.0
# 1128090  2014  ...       기타      기타       기타    5918.624352            23.0
# 1128091  2014  ...       기타      기타       기타    5918.624352            23.0
# 1128092  2014  ...       기타      기타       기타    5918.624352            23.0
# 1128093  2014  ...       기타      기타       기타    5918.624352            23.0
#
#         가장 가까운 다리 인근 한강다리 개수 인근 다리 개수 1개이상 3개 이하   학군    매매가격 지수
# 0            청담대교        0.0                   0  8.0  67.392545
# 1            청담대교        0.0                   0  8.0  67.392545
# 2            청담대교        0.0                   0  8.0  67.392545
# 3            청담대교        0.0                   0  8.0  69.049924
# 4            청담대교        0.0                   0  8.0  69.049924
# ...           ...        ...                 ...  ...        ...
# 1128089    구리암사대교        0.0                   0  1.0  91.623694
# 1128090    구리암사대교        0.0                   0  1.0  91.623694
# 1128091    구리암사대교        0.0                   0  1.0  91.066919
# 1128092    구리암사대교        0.0                   0  1.0  90.861265
# 1128093    구리암사대교        0.0                   0  1.0  90.861265
#
# [1128094 rows x 104 columns]

# %%
origin_df.to_csv('../data/preprocessed/32_selling_point.csv', index=False)
